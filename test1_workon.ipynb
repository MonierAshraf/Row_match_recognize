# %%
from src.parser.match_recognize_extractor import parse_full_query

if __name__ == "__main__":
    sample_query = """
       SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    A.totalprice AS starting_price,
                    LAST(B.totalprice) AS bottom_price
                ONE ROW PER MATCH
                PATTERN (A B+)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """



    components = parse_full_query(sample_query)
    print(components)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, LAST(B.totalprice) AS bottom_price ONE ROW PER MATCH PATTERN (A B+) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+'], 'base_variables': ['A', 'B']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+', metadata={'variables': ['A', 'B+'], 'base_variables': ['A', 'B']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+'], 'base_variables': ['A', 'B']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(B.totalprice)': ['B']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(B.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A B+', metadata={'variables': ['A', 'B+'], 'base_variables': ['A', 'B']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )

# %%
from src.parser.match_recognize_extractor import parse_full_query
from src.ast.ast_nodes import FullQueryAST

# Define a list of test queries to cover edge cases and full coverage
test_queries = [
    # 1. Basic ONE ROW PER MATCH
    {
        "name": "Basic One Row Per Match",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    A.totalprice AS starting_price,
                    LAST(B.totalprice) AS bottom_price
                ONE ROW PER MATCH
                PATTERN (A B+)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 2. ALL ROWS PER MATCH with SHOW EMPTY MATCHES, SUBSET clause and union variable
    {
        "name": "All Rows Per Match - Show Empty Matches",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    A.totalprice AS starting_price,
                    LAST(B.totalprice) AS bottom_price,
                    LAST(U.totalprice) AS top_price
                ALL ROWS PER MATCH SHOW EMPTY MATCHES
                PATTERN (A | B | C | D)
                SUBSET U = (C, D)
                DEFINE
                    B AS totalprice < PREV(totalprice),
                    C AS totalprice > PREV(totalprice) AND totalprice <= A.totalprice,
                    D AS totalprice > PREV(totalprice)
            );
        """
    },
    # 3. ALL ROWS PER MATCH with OMIT EMPTY MATCHES
    {
        "name": "All Rows Per Match - Omit Empty Matches",
        "query": """
            SELECT * FROM transactions MATCH_RECOGNIZE(
                PARTITION BY account_id
                ORDER BY transaction_date
                MEASURES
                    A.amount AS start_amount,
                    C.amount AS final_amount
                ALL ROWS PER MATCH OMIT EMPTY MATCHES
                PATTERN (A | B |C)
                DEFINE
                    B AS amount < PREV(amount),
                    C AS amount > PREV(amount)
            );
        """
    },
    # 4. ALL ROWS PER MATCH WITH UNMATCHED ROWS
    {
        "name": "All Rows Per Match - With Unmatched Rows",
        "query": """
            SELECT * FROM sales MATCH_RECOGNIZE(
                PARTITION BY region
                ORDER BY sale_date
                MEASURES
                    A.price AS initial_price,
                    D.price AS final_price,
                    MATCH_NUMBER() AS match_id
                ALL ROWS PER MATCH WITH UNMATCHED ROWS
                PATTERN (A B C D)
                DEFINE
                    B AS price < PREV(price),
                    C AS price > PREV(price),
                    D AS price > A.price
            );
        """
    },
    # 5. Nested Pattern: union variables and repeated groups with WITH UNMATCHED ROWS
    {
        "name": "Nested Pattern with Unmatched Rows",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    A.totalprice AS starting_price,
                    F.totalprice AS ending_price
                ALL ROWS PER MATCH WITH UNMATCHED ROWS
                PATTERN (A (B C | D E)+ F)
                DEFINE
                    B AS totalprice < PREV(totalprice),
                    C AS totalprice > PREV(totalprice),
                    D AS totalprice = PREV(totalprice),
                    E AS totalprice >= PREV(totalprice)
            );
        """
    },
    # 6. Using Classifier() and MATCH_NUMBER() functions
    {
        "name": "Classifier and Match Number Functions",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    CLASSIFIER() AS pattern_type,
                    MATCH_NUMBER() AS match_id,
                    A.totalprice AS starting_price,
                    LAST(B.totalprice) AS bottom_price
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 7. Running vs Final Semantics in MEASURES
    {
        "name": "Running vs Final Semantics in Measures",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    RUNNING LAST(A.totalprice) AS running_last_price,
                    FINAL LAST(A.totalprice) AS final_last_price
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 8. Aggregates with Running vs Final semantics (avg and count)
    {
        "name": "Running Avg vs Final Count Functions",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    RUNNING avg(A.totalprice) AS running_avg,
                    FINAL count(A.*) AS final_count
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 9. Empty Match: pattern that produces an empty match for every row
    {
        "name": "Empty Match and Unmatched Rows",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    A.totalprice AS starting_price,
                    MATCH_NUMBER() AS match_id
                ONE ROW PER MATCH
                PATTERN (())
            );
        """
    },
    # 10. Physical Navigation Functions: PREV() and NEXT()
    {
        "name": "Physical Navigation Functions",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    PREV(A.totalprice, 2) AS prev_price,
                    NEXT(A.totalprice, 1) AS next_price
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 11. Nested Navigation Function
    {
        "name": "Nested Navigation Function",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    PREV(FIRST(A.totalprice, 3), 2) AS nested_nav_price
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # --- Additional Edge Cases ---
    # 12. Unconventional Whitespace and Nested Functions in Complex Pattern
    {
        "name": "Complex Pattern with Unconventional Whitespace",
        "query": """
            SELECT *
            FROM   orders
            MATCH_RECOGNIZE(
                PARTITION BY   custkey
                ORDER BY   orderdate
                MEASURES
                  PREV(  FIRST( A.totalprice , 3 )  , 2 ) AS nested_nav_price
                ONE ROW PER MATCH
                PATTERN (  A   B+   C )
                DEFINE
                  B AS    totalprice < PREV(  totalprice )
            );
        """
    },
    # 13. Missing ORDER BY clause (should raise an error)
    {
        "name": "Error: Missing ORDER BY Clause",
        "query": """
            SELECT *
            FROM orders
            MATCH_RECOGNIZE(
                PARTITION BY custkey
                MEASURES
                    A.totalprice AS starting_price
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 14. Missing PATTERN clause when DEFINE is provided (should raise an error)
    {
        "name": "Error: Missing PATTERN Clause",
        "query": """
            SELECT *
            FROM orders
            MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    A.totalprice AS starting_price
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 15. Malformed PATTERN clause (missing closing parenthesis)
    {
        "name": "Error: Malformed PATTERN Clause",
        "query": """
            SELECT *
            FROM orders
            MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    A.totalprice AS starting_price
                ONE ROW PER MATCH
                PATTERN (A B+ C
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 16. Malformed DEFINE clause (missing 'AS' keyword)
    {
        "name": "Error: Malformed DEFINE Clause",
        "query": """
            SELECT *
            FROM orders
            MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    A.totalprice AS starting_price
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B totalprice < PREV(totalprice)
            );
        """
    }
]

# Run all test cases and print the resulting AST or error message
for test in test_queries:
    print(f"🔹 Running Test: {test['name']}")
    try:
        query_ast = parse_full_query(test["query"])
        print(query_ast)
    except Exception as e:
        print(f"Error: {e}")
    print("=" * 80)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, LAST(B.totalprice) AS bottom_price ONE ROW PER MATCH PATTERN (A B+) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+'], 'base_variables': ['A', 'B']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+', metadata={'variables': ['A', 'B+'], 'base_variables': ['A', 'B']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+'], 'base_variables': ['A', 'B']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(B.totalprice)': ['B']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(B.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, LAST(B.totalprice) AS bottom_price, LAST(U.totalprice) AS top_price ALL ROWS PER MATCH SHOW EMPTY MATCHES PATTERN (A | B | C | D) SUBSET U = (C, D) DEFINE B AS totalprice < PREV(totalprice), C AS totalprice > PREV(totalprice) AND totalprice <= A.totalprice, D AS totalprice > PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALLROWSPERMATCHSHOWEMPTYMATCHES
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH SHOW EMPTY MATCHES
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A | B | C | D
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A | B | C | D', metadata={'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']})
# DEBUG:src.parser.match_recognize_extractor:Extracted SUBSET: [SubsetClause(subset_text='U=(C,D)')]
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice>PREV(totalprice)ANDtotalprice<=A.totalprice'), Define(variable='D', condition='totalprice>PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A | B | C | D
# DEBUG:src.parser.match_recognize_extractor:Extracted subset mapping: U -> ['C', 'D']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(B.totalprice)': ['B']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(U.totalprice)': ['U']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from subset 'U=(C,D)': ['C', 'D']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>PREV(totalprice)ANDtotalprice<=A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B', 'C', 'D'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A', 'U', 'B', 'C', 'D'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B', 'C', 'D'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {'U': ['C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(B.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(U.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM transactions MATCH_RECOGNIZE( PARTITION BY account_id ORDER BY transaction_date MEASURES A.amount AS start_amount, C.amount AS final_amount ALL ROWS PER MATCH OMIT EMPTY MATCHES PATTERN (A | B |C) DEFINE B AS amount < PREV(amount), C AS amount > PREV(amount) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='transactions')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['account_id'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='transaction_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.amount', alias='start_amount', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='C.amount', alias='final_amount', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALLROWSPERMATCHOMITEMPTYMATCHES
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH OMIT EMPTY MATCHES
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A | B |C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A | B |C', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='amount<PREV(amount)'), Define(variable='C', condition='amount>PREV(amount)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A | B |C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.amount': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'C.amount': ['C']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'amount<PREV(amount)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'amount>PREV(amount)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.amount
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: C.amount
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM sales MATCH_RECOGNIZE( PARTITION BY region ORDER BY sale_date MEASURES A.price AS initial_price, D.price AS final_price, MATCH_NUMBER() AS match_id ALL ROWS PER MATCH WITH UNMATCHED ROWS PATTERN (A B C D) DEFINE B AS price < PREV(price), C AS price > PREV(price), D AS price > A.price );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='sales')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['region'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='sale_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.price', alias='initial_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='D.price', alias='final_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_id', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALLROWSPERMATCHWITHUNMATCHEDROWS
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH WITH UNMATCHED ROWS
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B C D
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B C D', metadata={'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='price<PREV(price)'), Define(variable='C', condition='price>PREV(price)'), Define(variable='D', condition='price>A.price')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B C D
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.price': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'D.price': ['D']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'MATCH_NUMBER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'price<PREV(price)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'price>PREV(price)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'price>A.price': ['A']
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B', 'C', 'D'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A', 'D'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B', 'C', 'D'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.price
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: D.price
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, F.totalprice AS ending_price ALL ROWS PER MATCH WITH UNMATCHED ROWS PATTERN (A (B C | D E)+ F) DEFINE B AS totalprice < PREV(totalprice), C AS totalprice > PREV(totalprice), D AS totalprice = PREV(totalprice), E AS totalprice >= PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='F.totalprice', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALLROWSPERMATCHWITHUNMATCHEDROWS
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH WITH UNMATCHED ROWS
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D', 'E', 'F'], 'base_variables': ['A', 'B', 'C', 'D', 'E', 'F']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A (B C | D E)+ F
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A (B C | D E)+ F', metadata={'variables': ['A', 'B', 'C', 'D', 'E', 'F'], 'base_variables': ['A', 'B', 'C', 'D', 'E', 'F']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice>PREV(totalprice)'), Define(variable='D', condition='totalprice=PREV(totalprice)'), Define(variable='E', condition='totalprice>=PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D', 'E', 'F'], 'base_variables': ['A', 'B', 'C', 'D', 'E', 'F']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A (B C | D E)+ F
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'F.totalprice': ['F']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice=PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>=PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'F', 'E', 'B', 'C', 'D'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A', 'F'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'E', 'B', 'C', 'D'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: F.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES CLASSIFIER() AS pattern_type, MATCH_NUMBER() AS match_id, A.totalprice AS starting_price, LAST(B.totalprice) AS bottom_price ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_type', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_id', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'CLASSIFIER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'MATCH_NUMBER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(B.totalprice)': ['B']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(B.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES RUNNING LAST(A.totalprice) AS running_last_price, FINAL LAST(A.totalprice) AS final_last_price ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='RUNNINGLAST(A.totalprice)', alias='running_last_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='FINALLAST(A.totalprice)', alias='final_last_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'RUNNINGLAST(A.totalprice)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'FINALLAST(A.totalprice)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: RUNNINGLAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: FINALLAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES RUNNING avg(A.totalprice) AS running_avg, FINAL count(A.*) AS final_count ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='RUNNINGavg(A.totalprice)', alias='running_avg', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='FINALcount(A.*)', alias='final_count', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'RUNNINGavg(A.totalprice)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'FINALcount(A.*)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: RUNNINGavg(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: FINALcount(A.*)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES PREV(A.totalprice, 2) AS prev_price, NEXT(A.totalprice, 1) AS next_price ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='PREV(A.totalprice,2)', alias='prev_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='NEXT(A.totalprice,1)', alias='next_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'PREV(A.totalprice,2)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'NEXT(A.totalprice,1)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: PREV(A.totalprice,2)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: NEXT(A.totalprice,1)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES PREV(FIRST(A.totalprice, 3), 2) AS nested_nav_price ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='PREV(FIRST(A.totalprice,3),2)', alias='nested_nav_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'PREV(FIRST(A.totalprice,3),2)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: PREV(FIRST(A.totalprice,3),2)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES PREV( FIRST( A.totalprice , 3 ) , 2 ) AS nested_nav_price ONE ROW PER MATCH PATTERN ( A B+ C ) DEFINE B AS totalprice < PREV( totalprice ) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='PREV(FIRST(A.totalprice,3),2)', alias='nested_nav_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A   B+   C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A   B+   C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A   B+   C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'PREV(FIRST(A.totalprice,3),2)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: PREV(FIRST(A.totalprice,3),2)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey MEASURES A.totalprice AS starting_price ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# 🔹 Running Test: Basic One Row Per Match
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A B+', metadata={'variables': ['A', 'B+'], 'base_variables': ['A', 'B']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: All Rows Per Match - Show Empty Matches
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ALL ROWS PER MATCH SHOW EMPTY MATCHES,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A | B | C | D', metadata={'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}),
#   subset=[SubsetClause(subset_text='U=(C,D)')],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice>PREV(totalprice)ANDtotalprice<=A.totalprice'), Define(variable='D', condition='totalprice>PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: All Rows Per Match - Omit Empty Matches
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='transactions'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['account_id']),
#   order_by=OrderByClause(sort_items=[SortItem(column='transaction_date', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.amount', alias='start_amount', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='C.amount', alias='final_amount', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ALL ROWS PER MATCH OMIT EMPTY MATCHES,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A | B |C', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='amount<PREV(amount)'), Define(variable='C', condition='amount>PREV(amount)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: All Rows Per Match - With Unmatched Rows
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='sales'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['region']),
#   order_by=OrderByClause(sort_items=[SortItem(column='sale_date', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.price', alias='initial_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='D.price', alias='final_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_id', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True)]),
#   rows_per_match=ALL ROWS PER MATCH WITH UNMATCHED ROWS,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A B C D', metadata={'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='price<PREV(price)'), Define(variable='C', condition='price>PREV(price)'), Define(variable='D', condition='price>A.price')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Nested Pattern with Unmatched Rows
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='F.totalprice', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ALL ROWS PER MATCH WITH UNMATCHED ROWS,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A (B C | D E)+ F', metadata={'variables': ['A', 'B', 'C', 'D', 'E', 'F'], 'base_variables': ['A', 'B', 'C', 'D', 'E', 'F']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice>PREV(totalprice)'), Define(variable='D', condition='totalprice=PREV(totalprice)'), Define(variable='E', condition='totalprice>=PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Classifier and Match Number Functions
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_type', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_id', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Running vs Final Semantics in Measures
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='RUNNINGLAST(A.totalprice)', alias='running_last_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='FINALLAST(A.totalprice)', alias='final_last_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Running Avg vs Final Count Functions
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='RUNNINGavg(A.totalprice)', alias='running_avg', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='FINALcount(A.*)', alias='final_count', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Empty Match and Unmatched Rows
# Error: Syntax error at line 9, column 12: mismatched input ')' expecting {'DEFINE', 'SUBSET'}. Please verify your MATCH_RECOGNIZE clause syntax according to the specification. (Line: 9, Column: 12)
# Snippet: SELECT * FROM orders MATCH_RECOGNIZE(
#                 PARTITION BY custkey
#                 ORDER BY orderdate
#                 MEASURES
#                     A.totalprice AS starting_price,
#                     MATCH_NUMBER() AS match_id
#                 ONE ROW PER MATCH
#                 PATTERN (())
#             );
# ================================================================================
# 🔹 Running Test: Physical Navigation Functions
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='PREV(A.totalprice,2)', alias='prev_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='NEXT(A.totalprice,1)', alias='next_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Nested Navigation Function
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='PREV(FIRST(A.totalprice,3),2)', alias='nested_nav_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Complex Pattern with Unconventional Whitespace
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='PREV(FIRST(A.totalprice,3),2)', alias='nested_nav_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A   B+   C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Error: Missing ORDER BY Clause
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=None,
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Error: Missing PATTERN Clause
# Error: Syntax error at line 8, column 16: mismatched input 'DEFINE' expecting {'AFTER', 'ALL', 'INITIAL', 'ONE', 'PATTERN', 'SEEK', ','}. Please verify your MATCH_RECOGNIZE clause syntax according to the specification. (Line: 8, Column: 16)
# Snippet: SELECT *
#             FROM orders
#             MATCH_RECOGNIZE(
#                 PARTITION BY custkey
#                 ORDER BY orderdate
#                 MEASURES
#                     A.totalprice AS starting_price
#                 DEFINE
#                     B AS totalprice < PREV(totalprice)
#             );
# ================================================================================
# 🔹 Running Test: Error: Malformed PATTERN Clause
# Error: Syntax error at line 11, column 22: mismatched input 'AS' expecting ')'. Please verify your MATCH_RECOGNIZE clause syntax according to the specification. (Line: 11, Column: 22)
# Snippet: SELECT *
#             FROM orders
#             MATCH_RECOGNIZE(
#                 PARTITION BY custkey
#                 ORDER BY orderdate
#                 MEASURES
#                     A.totalprice AS starting_price
#                 ONE ROW PER MATCH
#                 PATTERN (A B+ C
#                 DEFINE
#                     B AS totalprice < PREV(totalprice)
#             );
# ================================================================================
# 🔹 Running Test: Error: Malformed DEFINE Clause
# Error: Syntax error at line 11, column 22: missing 'AS' at 'totalprice'. Please verify your MATCH_RECOGNIZE clause syntax according to the specification. (Line: 11, Column: 22)
# Snippet: SELECT *
#             FROM orders
#             MATCH_RECOGNIZE(
#                 PARTITION BY custkey
#                 ORDER BY orderdate
#                 MEASURES
#                     A.totalprice AS starting_price
#                 ONE ROW PER MATCH
#                 PATTERN (A B+ C)
#                 DEFINE
#                     B totalprice < PREV(totalprice)
#             );
# ================================================================================

# %%
testing

# %%
from src.parser.match_recognize_extractor import parse_full_query

# Define a list of test cases with descriptions and query strings.
sample_queries = [
    {
        "description": "Simple pattern with whitespace",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN (A b+ c*)
    DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100
);
"""
    },
    {
        "description": "Pattern without whitespace",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN (Ab+c*)
    DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100
);
"""
    },
    {
        "description": "Single word pattern (one token)",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES vfggf.totalprice AS starting_price
    PATTERN (vfggf)
    DEFINE vfggf AS totalprice > 0
);
"""
    },
    {
        "description": "Pattern with PERMUTE construct",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES LAST(U.totalprice) AS top_price
    PATTERN (PERMUTE(A,B,C))
    SUBSET U = (A,B,C)
    DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
);
"""
    },
    {
        "description": "Pattern with grouping and quantifiers",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN ((A B+ C+))
    DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
);
"""
    },
    {
        "description": "Mixed pattern: whitespace vs. no whitespace",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN (A b+ c*)
    DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100
);
"""
    },
    {
        "description": "Pattern with quantifiers (greedy)",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price
    PATTERN (A{2,4})
    DEFINE A AS totalprice > 0
);
"""
    },
    {
        "description": "Pattern with quantifiers (reluctant)",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price
    PATTERN (A{2,4}?)
    DEFINE A AS totalprice > 0
);
"""
    },
    {
        "description": "Empty PATTERN clause (allowed as empty match)",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES NULL AS starting_price
    PATTERN ()
    DEFINE A AS totalprice > 0
);
"""
    },
    {
        "description": "Pattern with irregular whitespace and tabs",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY   custkey
    ORDER BY    orderdate
    MEASURES   A.totalprice   AS   starting_price
    PATTERN (   A   \t   b+   \t  c*   )
    DEFINE   A   AS totalprice > 0,   b   AS totalprice < PREV(totalprice),   c   AS totalprice < 100
);
"""
    },
    {
        "description": "Error: Undefined variable in DEFINE (missing c)",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN (A b+ c*)
    DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice)
);
"""
    },
    {
        "description": "Error: Extra variable in DEFINE (c extra)",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    PATTERN (A b+)
    DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100
);
"""
    },
    {
        "description": "Pattern with bounded quantifiers preserving commas",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN (A{2,4} B+)
    DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice)
);
"""
    },
    {
        "description": "Complex nested grouping with mixed quantifiers",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN (((AB+)(CD{2,4}?))E+)
    DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice > 50, D AS totalprice < 100, E AS totalprice BETWEEN 50 AND 150
);
"""
    },
    {
        "description": "Error: Undefined variable in DEFINE (extra variable missing in pattern)",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    PATTERN (A b+ c*)
    DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice)
);
"""
    }
]

# Run test cases
for test in sample_queries:
    print(f"--- Running Test: {test['description']} ---")
    try:
        result = parse_full_query(test["query"])
        print("Test Passed: Query parsed successfully.")
        print(result)
    except Exception as e:
        print("Test Failed with error:")
        print(e)
    print("=" * 80)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN (A b+ c*) DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: Ab+c*
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='Ab+c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: Ab+c*
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<100': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN (Ab+c*) DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: Ab+c*
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='Ab+c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: Ab+c*
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<100': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES vfggf.totalprice AS starting_price PATTERN (vfggf) DEFINE vfggf AS totalprice > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='vfggf.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['vfggf'], 'base_variables': ['vfggf']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: vfggf
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='vfggf', metadata={'variables': ['vfggf'], 'base_variables': ['vfggf']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='vfggf', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['vfggf'], 'base_variables': ['vfggf']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: vfggf
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'vfggf.totalprice': ['vfggf']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'vfggf'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'vfggf'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'vfggf'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: vfggf.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES LAST(U.totalprice) AS top_price PATTERN (PERMUTE(A,B,C)) SUBSET U = (A,B,C) DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A,B,C)
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A,B,C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted SUBSET: [SubsetClause(subset_text='U=(A,B,C)')]
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A,B,C)
# DEBUG:src.parser.match_recognize_extractor:Extracted subset mapping: U -> ['A', 'B', 'C']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(U.totalprice)': ['U']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from subset 'U=(A,B,C)': ['A', 'B', 'C']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<100': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'U', 'A', 'B', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A', 'B', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {'U': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(U.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN ((A B+ C+)) DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='AB+C+', metadata={'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C+
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<100': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A', 'B', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN (A b+ c*) DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: Ab+c*
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='Ab+c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: Ab+c*
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<100': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price PATTERN (A{2,4}) DEFINE A AS totalprice > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A{2,4}'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A{2,4}
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A{2,4}', metadata={'variables': ['A{2,4}'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A{2,4}'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A{2,4}
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(A.totalprice)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price PATTERN (A{2,4}?) DEFINE A AS totalprice > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A{2,4}?'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A{2,4}?
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A{2,4}?', metadata={'variables': ['A{2,4}?'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A{2,4}?'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A{2,4}?
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(A.totalprice)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN ( A b+ c* ) DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: Ab+c*
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='Ab+c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: Ab+c*
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<100': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN (A b+ c*) DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: Ab+c*
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='Ab+c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: Ab+c*
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate PATTERN (A b+) DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN (A{2,4} B+) DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A{2,4}', 'B+'], 'base_variables': ['A', 'B']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A{2,4}B+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A{2,4}B+', metadata={'variables': ['A{2,4}', 'B+'], 'base_variables': ['A', 'B']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A{2,4}', 'B+'], 'base_variables': ['A', 'B']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A{2,4}B+
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN (((AB+)(CD{2,4}?))E+) DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice > 50, D AS totalprice < 100, E AS totalprice BETWEEN 50 AND 150 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C', 'D{2,4}?', 'E+'], 'base_variables': ['A', 'B', 'C', 'D', 'E']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: ((AB+)(CD{2,4}?))E+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='((AB+)(CD{2,4}?))E+', metadata={'variables': ['A', 'B+', 'C', 'D{2,4}?', 'E+'], 'base_variables': ['A', 'B', 'C', 'D', 'E']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice>50'), Define(variable='D', condition='totalprice<100'), Define(variable='E', condition='totalpriceBETWEEN50AND150')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C', 'D{2,4}?', 'E+'], 'base_variables': ['A', 'B', 'C', 'D', 'E']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: ((AB+)(CD{2,4}?))E+
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>50': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<100': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalpriceBETWEEN50AND150': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'E', 'B', 'D', 'A', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'E', 'B', 'D', 'A', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate PATTERN (A b+ c*) DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: Ab+c*
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='Ab+c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: Ab+c*
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: set()
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# --- Running Test: Simple pattern with whitespace ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='Ab+c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Pattern without whitespace ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='Ab+c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Single word pattern (one token) ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='vfggf.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='vfggf', metadata={'variables': ['vfggf'], 'base_variables': ['vfggf']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='vfggf', condition='totalprice>0')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Pattern with PERMUTE construct ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='PERMUTE(A,B,C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[SubsetClause(subset_text='U=(A,B,C)')],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Pattern with grouping and quantifiers ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='AB+C+', metadata={'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Mixed pattern: whitespace vs. no whitespace ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='Ab+c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Pattern with quantifiers (greedy) ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A{2,4}', metadata={'variables': ['A{2,4}'], 'base_variables': ['A']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Pattern with quantifiers (reluctant) ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A{2,4}?', metadata={'variables': ['A{2,4}?'], 'base_variables': ['A']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Empty PATTERN clause (allowed as empty match) ---
# Test Failed with error:
# Syntax error at line 5, column 13: extraneous input ')' expecting {'ABSENT', 'ADD', 'ADMIN', 'AFTER', 'ALL', 'ANALYZE', 'ANY', 'ARRAY', 'ASC', 'AT', 'AUTHORIZATION', 'BEGIN', 'BERNOULLI', 'BOTH', 'CALL', 'CALLED', 'CASCADE', 'CATALOG', 'CATALOGS', 'COLUMN', 'COLUMNS', 'COMMENT', 'COMMIT', 'COMMITTED', 'CONDITIONAL', 'COUNT', 'COPARTITION', 'CURRENT', 'DATA', 'DATE', 'DAY', 'DECLARE', 'DEFAULT', 'DEFINE', 'DEFINER', 'DENY', 'DESC', 'DESCRIPTOR', 'DETERMINISTIC', 'DISTRIBUTED', 'DO', 'DOUBLE', 'EMPTY', 'ELSEIF', 'ENCODING', 'ERROR', 'EXCLUDING', 'EXPLAIN', 'FETCH', 'FILTER', 'FINAL', 'FIRST', 'FOLLOWING', 'FORMAT', 'FUNCTION', 'FUNCTIONS', 'GRACE', 'GRANT', 'GRANTED', 'GRANTS', 'GRAPHVIZ', 'GROUPS', 'HOUR', 'IF', 'IGNORE', 'IMMEDIATE', 'INCLUDING', 'INITIAL', 'INPUT', 'INTERVAL', 'INVOKER', 'IO', 'ISOLATION', 'ITERATE', 'JSON', 'KEEP', 'KEY', 'KEYS', 'LANGUAGE', 'LAST', 'LATERAL', 'LEADING', 'LEAVE', 'LEVEL', 'LIMIT', 'LOCAL', 'LOGICAL', 'LOOP', 'MAP', 'MATCH', 'MATCHED', 'MATCHES', 'MATCH_RECOGNIZE', 'MATERIALIZED', 'MEASURES', 'MERGE', 'MINUTE', 'MONTH', 'NESTED', 'NEXT', 'NFC', 'NFD', 'NFKC', 'NFKD', 'NO', 'NONE', 'NULLIF', 'NULLS', 'OBJECT', 'OF', 'OFFSET', 'OMIT', 'ONE', 'ONLY', 'OPTION', 'ORDINALITY', 'OUTPUT', 'OVER', 'OVERFLOW', 'PARTITION', 'PARTITIONS', 'PASSING', 'PAST', 'PATH', 'PATTERN', 'PER', 'PERIOD', 'PERMUTE', 'PLAN', 'POSITION', 'PRECEDING', 'PRECISION', 'PRIVILEGES', 'PROPERTIES', 'PRUNE', 'QUOTES', 'RANGE', 'READ', 'REFRESH', 'RENAME', 'REPEAT', 'REPEATABLE', 'REPLACE', 'RESET', 'RESPECT', 'RESTRICT', 'RETURN', 'RETURNING', 'RETURNS', 'REVOKE', 'ROLE', 'ROLES', 'ROLLBACK', 'ROW', 'ROWS', 'RUNNING', 'SCALAR', 'SCHEMA', 'SCHEMAS', 'SECOND', 'SECURITY', 'SEEK', 'SERIALIZABLE', 'SESSION', 'SET', 'SETS', 'SHOW', 'SOME', 'START', 'STATS', 'SUBSET', 'SUBSTRING', 'SYSTEM', 'TABLES', 'TABLESAMPLE', 'TEXT', 'STRING', 'TIES', 'TIME', 'TIMESTAMP', 'TO', 'TRAILING', 'TRANSACTION', 'TRUNCATE', 'TRY_CAST', 'TYPE', 'UNBOUNDED', 'UNCOMMITTED', 'UNCONDITIONAL', 'UNIQUE', 'UNKNOWN', 'UNMATCHED', 'UNTIL', 'UPDATE', 'USE', 'USER', 'UTF16', 'UTF32', 'UTF8', 'VALIDATE', 'VALUE', 'VERBOSE', 'VERSION', 'VIEW', 'WHILE', 'WINDOW', 'WITHIN', 'WITHOUT', 'WORK', 'WRAPPER', 'WRITE', 'YEAR', 'ZONE', '(', '{-', '$', '^', IDENTIFIER_, DIGIT_IDENTIFIER_, QUOTED_IDENTIFIER_, BACKQUOTED_IDENTIFIER_}. Please verify your MATCH_RECOGNIZE clause syntax according to the specification. (Line: 5, Column: 13)
# Snippet: SELECT * FROM orders MATCH_RECOGNIZE(
#     PARTITION BY custkey
#     ORDER BY orderdate
#     MEASURES NULL AS starting_price
#     PATTERN ()
#     DEFINE A AS totalprice > 0
# );
# ================================================================================
# --- Running Test: Pattern with irregular whitespace and tabs ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='Ab+c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Error: Undefined variable in DEFINE (missing c) ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='Ab+c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Error: Extra variable in DEFINE (c extra) ---
# Test Failed with error:
# Defined variables {'c'} not found in pattern
# ================================================================================
# --- Running Test: Pattern with bounded quantifiers preserving commas ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A{2,4}B+', metadata={'variables': ['A{2,4}', 'B+'], 'base_variables': ['A', 'B']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Complex nested grouping with mixed quantifiers ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='((AB+)(CD{2,4}?))E+', metadata={'variables': ['A', 'B+', 'C', 'D{2,4}?', 'E+'], 'base_variables': ['A', 'B', 'C', 'D', 'E']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice>50'), Define(variable='D', condition='totalprice<100'), Define(variable='E', condition='totalpriceBETWEEN50AND150')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Error: Undefined variable in DEFINE (extra variable missing in pattern) ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=None,
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='Ab+c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================

# %%
from src.parser.match_recognize_extractor import parse_full_query

def run_test(query, description):
    print(f"--- Running Test: {description} ---")
    try:
        ast = parse_full_query(query)
        print("Test Passed: Query parsed successfully.")
        print(ast)
    except Exception as e:
        print("Test Failed with error:")
        print(e)
    print("="*80)

if __name__ == "__main__":
    # 1. Alternation using '|' operator
    test_query1 = """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN (A | B | C)
    DEFINE A AS totalprice > 100, B AS totalprice < 50, C AS totalprice BETWEEN 50 AND 100
);
"""
    run_test(test_query1, "Alternate forms: Alternation using '|' operator")

    # 2. Grouping
    test_query2 = """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN ((A B) C)
    DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
);
"""
    run_test(test_query2, "Alternate forms: Grouping")

    # 3. Permutation
    test_query3 = """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES LAST(U.totalprice) AS top_price
    PATTERN (PERMUTE(A, B, C))
    SUBSET U = (A, B, C)
    DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
);
"""
    run_test(test_query3, "Alternate forms: Permutation")

    # 4. Quantifiers with bounds (Greedy)
    test_query4a = """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price
    PATTERN (A{2,4})
    DEFINE A AS totalprice > 0
);
"""
    run_test(test_query4a, "Quantifiers with bounds: Greedy")

    # 4. Quantifiers with bounds (Reluctant)
    test_query4b = """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price
    PATTERN (A{2,4}?)
    DEFINE A AS totalprice > 0
);
"""
    run_test(test_query4b, "Quantifiers with bounds: Reluctant")

    # 5. Valid Navigation and Aggregates
    test_query5 = """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES LAST(A.totalprice) AS final_price, avg(A.totalprice) AS avg_price
    PATTERN (A+)
    DEFINE A AS totalprice > 0
);
"""
    run_test(test_query5, "Valid Navigation and Aggregates")

    # 6. Invalid Navigation Function (should fail)
    test_query6 = """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES LAST(1) AS invalid_nav
    PATTERN (A+)
    DEFINE A AS totalprice > 0
);
"""
    run_test(test_query6, "Invalid Navigation Function (should fail)")

    # 7. Invalid Nested Aggregate in Navigation (should fail)
    test_query7 = """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES FIRST(avg(A.totalprice),2) AS invalid_agg_nav
    PATTERN (A+)
    DEFINE A AS totalprice > 0
);
"""
    run_test(test_query7, "Invalid Nested Aggregate in Navigation (should fail)")

    # 8. Case-sensitive identifier validation
    test_query8 = """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN (A b+ c)
    DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100
);
"""
    run_test(test_query8, "Case-sensitive identifier validation")

    # 9. Grouping with Quantifiers
    test_query9 = """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN ((A B+ C+))
    DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
);
"""
    run_test(test_query9, "Alternate forms: Grouping with quantifiers")

    # 10. Aggregate with inconsistent variable references (should fail)
    test_query10 = """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES max_by(A.totalprice, B.totalprice) AS invalid_agg
    PATTERN (A B+ C)
    DEFINE B AS totalprice < PREV(totalprice)
);
"""
    run_test(test_query10, "Aggregate with inconsistent variable references (should fail)")

    # 11. Aggregate with consistent variable references
    test_query11 = """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES avg(A.totalprice) AS avg_price, count(A.*) AS count_price
    PATTERN (A B+ C)
    DEFINE B AS totalprice < PREV(totalprice)
);
"""
    run_test(test_query11, "Aggregate with consistent variable references")

    # 12. Navigation and Aggregate with MATCH_NUMBER and avg
    test_query12 = """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES MATCH_NUMBER() AS match_id, avg(A.totalprice) AS avg_price
    PATTERN (A B+ C)
    DEFINE B AS totalprice < PREV(totalprice)
);
"""
    run_test(test_query12, "MATCH_NUMBER with aggregates")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN (A | B | C) DEFINE A AS totalprice > 100, B AS totalprice < 50, C AS totalprice BETWEEN 50 AND 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A | B | C', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>100'), Define(variable='B', condition='totalprice<50'), Define(variable='C', condition='totalpriceBETWEEN50AND100')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A | B | C
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN ((A B) C) DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='(A B) C', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: (A B) C
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES LAST(U.totalprice) AS top_price PATTERN (PERMUTE(A, B, C)) SUBSET U = (A, B, C) DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B, C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted SUBSET: [SubsetClause(subset_text='U=(A,B,C)')]
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(U.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price PATTERN (A{2,4}) DEFINE A AS totalprice > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A{2,4}', metadata={'variables': ['A{2,4}'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A{2,4}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price PATTERN (A{2,4}?) DEFINE A AS totalprice > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A{2,4}?', metadata={'variables': ['A{2,4}?'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A{2,4}?
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES LAST(A.totalprice) AS final_price, avg(A.totalprice) AS avg_price PATTERN (A+) DEFINE A AS totalprice > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='LAST(A.totalprice)', alias='final_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='avg(A.totalprice)', alias='avg_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A+', metadata={'variables': ['A+'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: avg(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES LAST(1) AS invalid_nav PATTERN (A+) DEFINE A AS totalprice > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='LAST(1)', alias='invalid_nav', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A+', metadata={'variables': ['A+'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES FIRST(avg(A.totalprice),2) AS invalid_agg_nav PATTERN (A+) DEFINE A AS totalprice > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='FIRST(avg(A.totalprice),2)', alias='invalid_agg_nav', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A+', metadata={'variables': ['A+'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN (A b+ c) DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A b+ c', metadata={'variables': ['A', 'b+', 'c'], 'base_variables': ['A', 'b', 'c']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A b+ c
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN ((A B+ C+)) DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='(A B+ C+)', metadata={'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: (A B+ C+)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES max_by(A.totalprice, B.totalprice) AS invalid_agg PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='max_by(A.totalprice,B.totalprice)', alias='invalid_agg', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES avg(A.totalprice) AS avg_price, count(A.*) AS count_price PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='avg(A.totalprice)', alias='avg_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='count(A.*)', alias='count_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES MATCH_NUMBER() AS match_id, avg(A.totalprice) AS avg_price PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='MATCH_NUMBER()', alias='match_id', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='avg(A.totalprice)', alias='avg_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# --- Running Test: Alternate forms: Alternation using '|' operator ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A | B | C', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>100'), Define(variable='B', condition='totalprice<50'), Define(variable='C', condition='totalpriceBETWEEN50AND100')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Alternate forms: Grouping ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='(A B) C', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Alternate forms: Permutation ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='PERMUTE(A, B, C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[SubsetClause(subset_text='U=(A,B,C)')],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Quantifiers with bounds: Greedy ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A{2,4}', metadata={'variables': ['A{2,4}'], 'base_variables': ['A']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Quantifiers with bounds: Reluctant ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A{2,4}?', metadata={'variables': ['A{2,4}?'], 'base_variables': ['A']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Valid Navigation and Aggregates ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='LAST(A.totalprice)', alias='final_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='avg(A.totalprice)', alias='avg_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A+', metadata={'variables': ['A+'], 'base_variables': ['A']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Invalid Navigation Function (should fail) ---
# Test Failed with error:
# Invalid usage of LAST in measure: LAST(1) (Line: 1, Column: 14)
# Snippet: ordersMATCH_RECOGNIZE(PARTITIONBYcustkeyORDERBYorderdateMEASURESLAST(1)ASinvalid_navPATTERN(A+)DEFINEAAStotalprice>0)
# ================================================================================
# --- Running Test: Invalid Nested Aggregate in Navigation (should fail) ---
# Test Failed with error:
# Invalid usage of FIRST in measure: FIRST(avg(A.totalprice),2) (Line: 1, Column: 14)
# Snippet: ordersMATCH_RECOGNIZE(PARTITIONBYcustkeyORDERBYorderdateMEASURESFIRST(avg(A.totalprice),2)ASinvalid_agg_navPATTERN(A+)DEFINEAAStotalprice>0)
# ================================================================================
# --- Running Test: Case-sensitive identifier validation ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A b+ c', metadata={'variables': ['A', 'b+', 'c'], 'base_variables': ['A', 'b', 'c']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Alternate forms: Grouping with quantifiers ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='(A B+ C+)', metadata={'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Aggregate with inconsistent variable references (should fail) ---
# Test Failed with error:
# All pattern variables must be explicitly defined. Missing definitions for: {'A', 'C'} (Line: 1, Column: 14)
# Snippet: ordersMATCH_RECOGNIZE(PARTITIONBYcustkeyORDERBYorderdateMEASURESmax_by(A.totalprice,B.totalprice)ASinvalid_aggPATTERN(AB+C)DEFINEBAStotalprice<PREV(totalprice))
# ================================================================================
# --- Running Test: Aggregate with consistent variable references ---
# Test Failed with error:
# All pattern variables must be explicitly defined. Missing definitions for: {'A', 'C'} (Line: 1, Column: 14)
# Snippet: ordersMATCH_RECOGNIZE(PARTITIONBYcustkeyORDERBYorderdateMEASURESavg(A.totalprice)ASavg_price,count(A.*)AScount_pricePATTERN(AB+C)DEFINEBAStotalprice<PREV(totalprice))
# ================================================================================
# --- Running Test: MATCH_NUMBER with aggregates ---
# Test Failed with error:
# All pattern variables must be explicitly defined. Missing definitions for: {'A', 'C'} (Line: 1, Column: 14)
# Snippet: ordersMATCH_RECOGNIZE(PARTITIONBYcustkeyORDERBYorderdateMEASURESMATCH_NUMBER()ASmatch_id,avg(A.totalprice)ASavg_pricePATTERN(AB+C)DEFINEBAStotalprice<PREV(totalprice))
# ================================================================================

# %%
from src.parser.match_recognize_extractor import parse_full_query

def run_test(query: str, description: str):
    print(f"--- Running Test: {description} ---")
    try:
        ast = parse_full_query(query)
        print("Test Passed: Query parsed successfully.")
        print(ast)
    except Exception as e:
        print("Test Failed with error:")
        print(e)
    print("=" * 80)

if __name__ == "__main__":
    # 1. Alternate forms: Alternation using '|' operator
    query1 = """
    SELECT * FROM orders MATCH_RECOGNIZE(
        PARTITION BY custkey
        ORDER BY orderdate
        MEASURES A.totalprice AS starting_price
        PATTERN (A | B | C)
        DEFINE A AS totalprice > 100, B AS totalprice < 50, C AS totalprice BETWEEN 50 AND 100
    );
    """
    run_test(query1, "Alternate forms: Alternation using '|' operator")

    # 2. Alternate forms: Grouping (using parentheses)
    query2 = """
    SELECT * FROM orders MATCH_RECOGNIZE(
        PARTITION BY custkey
        ORDER BY orderdate
        MEASURES A.totalprice AS starting_price
        PATTERN ((A B C))
        DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
    );
    """
    run_test(query2, "Alternate forms: Grouping")

    # 3. Alternate forms: Permutation
    query3 = """
    SELECT * FROM orders MATCH_RECOGNIZE(
        PARTITION BY custkey
        ORDER BY orderdate
        MEASURES LAST(U.totalprice) AS top_price
        PATTERN (PERMUTE(A, B, C))
        SUBSET U = (A, B, C)
        DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
    );
    """
    run_test(query3, "Alternate forms: Permutation")

    # 4a. Quantifiers with bounds: Greedy
    query4a = """
    SELECT * FROM orders MATCH_RECOGNIZE(
        PARTITION BY custkey
        ORDER BY orderdate
        MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price
        PATTERN (A{2,4})
        DEFINE A AS totalprice > 0
    );
    """
    run_test(query4a, "Quantifiers with bounds: Greedy")

    # 4b. Quantifiers with bounds: Reluctant
    query4b = """
    SELECT * FROM orders MATCH_RECOGNIZE(
        PARTITION BY custkey
        ORDER BY orderdate
        MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price
        PATTERN (A{2,4}?)
        DEFINE A AS totalprice > 0
    );
    """
    run_test(query4b, "Quantifiers with bounds: Reluctant")

    # 5. Valid Navigation and Aggregates
    query5 = """
    SELECT * FROM orders MATCH_RECOGNIZE(
        PARTITION BY custkey
        ORDER BY orderdate
        MEASURES LAST(A.totalprice) AS final_price, avg(A.totalprice) AS avg_price
        PATTERN (A+)
        DEFINE A AS totalprice > 0
    );
    """
    run_test(query5, "Valid Navigation and Aggregates")

    # 6. Invalid Navigation Function (should fail)
    query6 = """
    SELECT * FROM orders MATCH_RECOGNIZE(
        PARTITION BY custkey
        ORDER BY orderdate
        MEASURES LAST(1) AS invalid_nav
        PATTERN (A+)
        DEFINE A AS totalprice > 0
    );
    """
    run_test(query6, "Invalid Navigation Function (should fail)")

    # 7. Invalid Nested Aggregate in Navigation (should fail)
    query7 = """
    SELECT * FROM orders MATCH_RECOGNIZE(
        PARTITION BY custkey
        ORDER BY orderdate
        MEASURES FIRST(avg(A.totalprice),2) AS invalid_agg_nav
        PATTERN (A+)
        DEFINE A AS totalprice > 0
    );
    """
    run_test(query7, "Invalid Nested Aggregate in Navigation (should fail)")

    # 8. Case-Sensitive Identifier Validation
    query8 = """
    SELECT * FROM orders MATCH_RECOGNIZE(
        PARTITION BY custkey
        ORDER BY orderdate
        MEASURES A.totalprice AS starting_price
        PATTERN (A b+ c)
        DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100
    );
    """
    run_test(query8, "Case-Sensitive Identifier Validation")

    # 9. Grouping with Quantifiers
    query9 = """
    SELECT * FROM orders MATCH_RECOGNIZE(
        PARTITION BY custkey
        ORDER BY orderdate
        MEASURES A.totalprice AS starting_price
        PATTERN ((A B+ C+))
        DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
    );
    """
    run_test(query9, "Grouping with Quantifiers")

    # 10. Aggregate with inconsistent variable references (should fail)
    query10 = """
    SELECT * FROM orders MATCH_RECOGNIZE(
        PARTITION BY custkey
        ORDER BY orderdate
        MEASURES max_by(A.totalprice, B.totalprice) AS invalid_agg
        PATTERN (A B+ C)
        DEFINE B AS totalprice < PREV(totalprice)
    );
    """
    run_test(query10, "Aggregate with Inconsistent Variable References (should fail)")

    # 11. Aggregate with consistent variable references
    query11 = """
    SELECT * FROM orders MATCH_RECOGNIZE(
        PARTITION BY custkey
        ORDER BY orderdate
        MEASURES avg(A.totalprice) AS avg_price, count(A.*) AS count_price
        PATTERN (A B+ C)
        DEFINE B AS totalprice < PREV(totalprice), A AS TRUE, C AS TRUE
    );
    """
    run_test(query11, "Aggregate with Consistent Variable References")

    # 12. MATCH_NUMBER with aggregates
    query12 = """
    SELECT * FROM orders MATCH_RECOGNIZE(
        PARTITION BY custkey
        ORDER BY orderdate
        MEASURES MATCH_NUMBER() AS match_id, avg(A.totalprice) AS avg_price
        PATTERN (A B+ C)
        DEFINE B AS totalprice < PREV(totalprice), A AS TRUE, C AS TRUE
    );
    """
    run_test(query12, "MATCH_NUMBER with Aggregates")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN (A | B | C) DEFINE A AS totalprice > 100, B AS totalprice < 50, C AS totalprice BETWEEN 50 AND 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause via robust splitting: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause via regex: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A | B | C', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>100'), Define(variable='B', condition='totalprice<50'), Define(variable='C', condition='totalpriceBETWEEN50AND100')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A | B | C
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN ((A B C)) DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause via robust splitting: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause via regex: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='(A B C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: (A B C)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES LAST(U.totalprice) AS top_price PATTERN (PERMUTE(A, B, C)) SUBSET U = (A, B, C) DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause via robust splitting: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause via regex: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B, C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted SUBSET: [SubsetClause(subset_text='U=(A,B,C)')]
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(U.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price PATTERN (A{2,4}) DEFINE A AS totalprice > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause via robust splitting: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause via regex: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A{2,4}', metadata={'variables': ['A{2,4}'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A{2,4}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price PATTERN (A{2,4}?) DEFINE A AS totalprice > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause via robust splitting: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause via regex: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A{2,4}?', metadata={'variables': ['A{2,4}?'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A{2,4}?
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES LAST(A.totalprice) AS final_price, avg(A.totalprice) AS avg_price PATTERN (A+) DEFINE A AS totalprice > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause via robust splitting: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause via regex: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='LAST(A.totalprice)', alias='final_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='avg(A.totalprice)', alias='avg_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A+', metadata={'variables': ['A+'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: avg(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES LAST(1) AS invalid_nav PATTERN (A+) DEFINE A AS totalprice > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause via robust splitting: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause via regex: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='LAST(1)', alias='invalid_nav', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A+', metadata={'variables': ['A+'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES FIRST(avg(A.totalprice),2) AS invalid_agg_nav PATTERN (A+) DEFINE A AS totalprice > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause via robust splitting: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause via regex: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='FIRST(avg(A.totalprice),2)', alias='invalid_agg_nav', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A+', metadata={'variables': ['A+'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN (A b+ c) DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause via robust splitting: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause via regex: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A b+ c', metadata={'variables': ['A', 'b+', 'c'], 'base_variables': ['A', 'b', 'c']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A b+ c
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN ((A B+ C+)) DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause via robust splitting: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause via regex: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='(A B+ C+)', metadata={'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: (A B+ C+)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES max_by(A.totalprice, B.totalprice) AS invalid_agg PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause via robust splitting: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause via regex: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='max_by(A.totalprice,B.totalprice)', alias='invalid_agg', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES avg(A.totalprice) AS avg_price, count(A.*) AS count_price PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice), A AS TRUE, C AS TRUE );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause via robust splitting: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause via regex: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='avg(A.totalprice)', alias='avg_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='count(A.*)', alias='count_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='A', condition='TRUE'), Define(variable='C', condition='TRUE')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: avg(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: count(A.*)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES MATCH_NUMBER() AS match_id, avg(A.totalprice) AS avg_price PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice), A AS TRUE, C AS TRUE );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause via robust splitting: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause via regex: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='MATCH_NUMBER()', alias='match_id', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='avg(A.totalprice)', alias='avg_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='A', condition='TRUE'), Define(variable='C', condition='TRUE')])
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A B+ C
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: avg(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# --- Running Test: Alternate forms: Alternation using '|' operator ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A | B | C', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>100'), Define(variable='B', condition='totalprice<50'), Define(variable='C', condition='totalpriceBETWEEN50AND100')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Alternate forms: Grouping ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='(A B C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Alternate forms: Permutation ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='PERMUTE(A, B, C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[SubsetClause(subset_text='U=(A,B,C)')],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Quantifiers with bounds: Greedy ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A{2,4}', metadata={'variables': ['A{2,4}'], 'base_variables': ['A']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Quantifiers with bounds: Reluctant ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A{2,4}?', metadata={'variables': ['A{2,4}?'], 'base_variables': ['A']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Valid Navigation and Aggregates ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='LAST(A.totalprice)', alias='final_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='avg(A.totalprice)', alias='avg_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A+', metadata={'variables': ['A+'], 'base_variables': ['A']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Invalid Navigation Function (should fail) ---
# Test Failed with error:
# Invalid usage of LAST in measure: LAST(1) (Line: 1, Column: 14)
# Snippet: ordersMATCH_RECOGNIZE(PARTITIONBYcustkeyORDERBYorderdateMEASURESLAST(1)ASinvalid_navPATTERN(A+)DEFINEAAStotalprice>0)
# ================================================================================
# --- Running Test: Invalid Nested Aggregate in Navigation (should fail) ---
# Test Failed with error:
# Invalid usage of FIRST in measure: FIRST(avg(A.totalprice),2) (Line: 1, Column: 14)
# Snippet: ordersMATCH_RECOGNIZE(PARTITIONBYcustkeyORDERBYorderdateMEASURESFIRST(avg(A.totalprice),2)ASinvalid_agg_navPATTERN(A+)DEFINEAAStotalprice>0)
# ================================================================================
# --- Running Test: Case-Sensitive Identifier Validation ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A b+ c', metadata={'variables': ['A', 'b+', 'c'], 'base_variables': ['A', 'b', 'c']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Grouping with Quantifiers ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='(A B+ C+)', metadata={'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: Aggregate with Inconsistent Variable References (should fail) ---
# Test Failed with error:
# All pattern variables must be explicitly defined. Missing definitions for: {'A', 'C'} (Line: 1, Column: 14)
# Snippet: ordersMATCH_RECOGNIZE(PARTITIONBYcustkeyORDERBYorderdateMEASURESmax_by(A.totalprice,B.totalprice)ASinvalid_aggPATTERN(AB+C)DEFINEBAStotalprice<PREV(totalprice))
# ================================================================================
# --- Running Test: Aggregate with Consistent Variable References ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='avg(A.totalprice)', alias='avg_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='count(A.*)', alias='count_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='A', condition='TRUE'), Define(variable='C', condition='TRUE')])
# ),
#   metadata={}
# )
# ================================================================================
# --- Running Test: MATCH_NUMBER with Aggregates ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='MATCH_NUMBER()', alias='match_id', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='avg(A.totalprice)', alias='avg_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A B+ C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='A', condition='TRUE'), Define(variable='C', condition='TRUE')])
# ),
#   metadata={}
# )
# ================================================================================

# %%
from src.parser.match_recognize_extractor import parse_match_recognize_query

# Define a list of test cases with a description and query string.
sample_queries = [
    {
        "description": "Simple pattern with whitespace",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN (A b+ c*)
    DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100
);
"""
    },
    {
        "description": "Pattern without whitespace",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN (Ab+c*)
    DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100
);
"""
    },
    {
        "description": "Single word pattern (one token)",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES vfggf.totalprice AS starting_price
    PATTERN (vfggf)
    DEFINE vfggf AS totalprice > 0
);
"""
    },
    {
        "description": "Pattern with PERMUTE construct",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES LAST(U.totalprice) AS top_price
    PATTERN (PERMUTE(A,B,C))
    SUBSET U = (A,B,C)
    DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
);
"""
    },
    {
        "description": "Pattern with grouping and quantifiers",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN ((A B+ C+))
    DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
);
"""
    },
    {
        "description": "Mixed pattern: whitespace vs. no whitespace",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN (A b+ c*)
    DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100
);
"""
    },
    {
        "description": "Pattern with quantifiers (greedy)",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price
    PATTERN (A{2,4})
    DEFINE A AS totalprice > 0
);
"""
    },
    {
        "description": "Pattern with quantifiers (reluctant)",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price
    PATTERN (A{2,4}?)
    DEFINE A AS totalprice > 0
);
"""
    }
]

# Iterate over each test case.
for test in sample_queries:
    print(f"--- Running Test: {test['description']} ---")
    try:
        result = parse_match_recognize_query(test["query"])
        print("Test Passed: Query parsed successfully.")
        print(result)
    except Exception as e:
        print("Test Failed with error:")
        print(e)
    print("=" * 80)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A b+ c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A b+ c*
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='Ab+c*', metadata={'variables': ['Ab+', 'c*'], 'base_variables': ['Ab', 'c']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: Ab+c*
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='vfggf.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='vfggf', metadata={'variables': ['vfggf'], 'base_variables': ['vfggf']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='vfggf', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['vfggf'], 'base_variables': ['vfggf']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: vfggf
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: vfggf.totalprice
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A,B,C)', metadata={'variables': ['ABC'], 'base_variables': ['ABC']})
# DEBUG:src.parser.match_recognize_extractor:Extracted SUBSET: [SubsetClause(subset_text='U=(A,B,C)')]
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A,B,C)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(U.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='(A B+ C+)', metadata={'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: (A B+ C+)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A b+ c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A b+ c*
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A{2,4}', metadata={'variables': [], 'base_variables': []})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A{2,4}'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A{2,4}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A{2,4}?', metadata={'variables': [], 'base_variables': []})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A{2,4}?'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A{2,4}?
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.totalprice)
# --- Running Test: Simple pattern with whitespace ---
# Test Passed: Query parsed successfully.
# MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A b+ c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# )
# ================================================================================
# --- Running Test: Pattern without whitespace ---
# Test Passed: Query parsed successfully.
# MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='Ab+c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# )
# ================================================================================
# --- Running Test: Single word pattern (one token) ---
# Test Passed: Query parsed successfully.
# MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='vfggf.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='vfggf', metadata={'variables': ['vfggf'], 'base_variables': ['vfggf']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='vfggf', condition='totalprice>0')])
# )
# ================================================================================
# --- Running Test: Pattern with PERMUTE construct ---
# Test Passed: Query parsed successfully.
# MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='PERMUTE(A,B,C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[SubsetClause(subset_text='U=(A,B,C)')],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# )
# ================================================================================
# --- Running Test: Pattern with grouping and quantifiers ---
# Test Passed: Query parsed successfully.
# MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='(A B+ C+)', metadata={'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# )
# ================================================================================
# --- Running Test: Mixed pattern: whitespace vs. no whitespace ---
# Test Passed: Query parsed successfully.
# MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A b+ c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# )
# ================================================================================
# --- Running Test: Pattern with quantifiers (greedy) ---
# Test Passed: Query parsed successfully.
# MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A{2,4}', metadata={'variables': ['A{2,4}'], 'base_variables': ['A']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# )
# ================================================================================
# --- Running Test: Pattern with quantifiers (reluctant) ---
# Test Passed: Query parsed successfully.
# MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A{2,4}?', metadata={'variables': ['A{2,4}?'], 'base_variables': ['A']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# )
# ================================================================================

# %%
from src.parser.match_recognize_extractor import parse_match_recognize_query

sample_queries = [
    {
        "description": "Simple pattern with whitespace",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN (A b+ c*)
    DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100
);
"""
    },
    {
        "description": "Pattern without whitespace",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN (AB+C*)
    DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
);
"""
    },
    {
        "description": "Single word pattern (one token)",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES vfggf.totalprice AS starting_price
    PATTERN (vfggf)
    DEFINE vfggf AS totalprice > 0
);
"""
    },
    {
        "description": "Pattern with PERMUTE construct",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES LAST(U.totalprice) AS top_price
    PATTERN (PERMUTE(A,B,C))
    SUBSET U = (A,B,C)
    DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
);
"""
    },
    {
        "description": "Pattern with grouping and quantifiers",
        "query": """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN ((A B+ C+))
    DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
);
"""
    }
]

for test in sample_queries:
    print(f"--- Running Test: {test['description']} ---")
    try:
        result = parse_match_recognize_query(test["query"])
        print("Test Passed: Query parsed successfully.")
        print(result)
    except Exception as e:
        print("Test Failed with error:")
        print(e)
    print("=" * 80)
# Out:
# --- Running Test: Simple pattern with whitespace ---
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A b+ c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A b+ c*
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='AB+C*', metadata={'variables': ['AB+', 'C*'], 'base_variables': ['AB', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C*'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C*
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='vfggf.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='vfggf', metadata={'variables': ['vfggf'], 'base_variables': ['vfggf']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='vfggf', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['vfggf'], 'base_variables': ['vfggf']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: vfggf
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: vfggf.totalprice
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A,B,C)', metadata={'variables': ['ABC'], 'base_variables': ['ABC']})
# DEBUG:src.parser.match_recognize_extractor:Extracted SUBSET: [SubsetClause(subset_text='U=(A,B,C)')]
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A,B,C)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(U.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='(A B+ C+)', metadata={'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: (A B+ C+)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# Test Passed: Query parsed successfully.
# MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A b+ c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# )
# ================================================================================
# --- Running Test: Pattern without whitespace ---
# Test Passed: Query parsed successfully.
# MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='AB+C*', metadata={'variables': ['A', 'B+', 'C*'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# )
# ================================================================================
# --- Running Test: Single word pattern (one token) ---
# Test Passed: Query parsed successfully.
# MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='vfggf.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='vfggf', metadata={'variables': ['vfggf'], 'base_variables': ['vfggf']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='vfggf', condition='totalprice>0')])
# )
# ================================================================================
# --- Running Test: Pattern with PERMUTE construct ---
# Test Passed: Query parsed successfully.
# MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='PERMUTE(A,B,C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[SubsetClause(subset_text='U=(A,B,C)')],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# )
# ================================================================================
# --- Running Test: Pattern with grouping and quantifiers ---
# Test Passed: Query parsed successfully.
# MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='(A B+ C+)', metadata={'variables': ['A', 'B+', 'C+'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# )
# ================================================================================

# %%
from src.parser.match_recognize_extractor import parse_match_recognize_query

if __name__ == "__main__":
    sample_query = """
SELECT * FROM orders MATCH_RECOGNIZE(
    PARTITION BY custkey
    ORDER BY orderdate
    MEASURES A.totalprice AS starting_price
    PATTERN (PERMUTE(A,B*,C))
    DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
);

    """

    components = parse_match_recognize_query(sample_query)
    print(components)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A,B*,C)', metadata={'variables': ['AB*', 'C'], 'base_variables': ['AB', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B*', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A,B*,C)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='PERMUTE(A,B*,C)', metadata={'variables': ['A', 'B*', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# )

# %%
from src.parser.match_recognize_extractor import parse_full_query
import logging

logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger(__name__)

test_queries = [
    {
        "description": "Simple pattern with wildcard",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES A.totalprice AS starting_price
                PATTERN (A b+ c*)
                DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100
            );
        """
    },
    {
        "description": "Pattern without whitespace in pattern",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES A.totalprice AS starting_price
                PATTERN (AB+C)
                DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
            );
        """
    },
    {
        "description": "Pattern with PERMUTE, grouping, and quantifiers",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES LAST(U.totalprice) AS top_price
                PATTERN (PERMUTE(A,B,C))
                SUBSET U = (A,B,C)
                DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
            );
        """
    },
    {
        "description": "Select specific columns",
        "query": """
            SELECT orderid, custkey, orderdate FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES A.totalprice AS starting_price
                PATTERN (A b+ c*)
                DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100
            );
        """
    },
    {
        "description": "Select with aliasing",
        "query": """
            SELECT orderid AS id, totalprice AS price FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES LAST(A.totalprice) AS ending_price
                PATTERN (A{2,4}?)
                DEFINE A AS totalprice > 0
            );
        """
    },
    {
        "description": "Select with DISTINCT",
        "query": """
            SELECT DISTINCT orderid, totalprice FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES A.totalprice AS starting_price
                PATTERN (A b+ c*)
                DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100
            );
        """
    },
    {
        "description": "Select with function calls",
        "query": """
            SELECT MAX(totalprice) AS max_price, MIN(totalprice) AS min_price FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES A.totalprice AS starting_price
                PATTERN (A b+ c*)
                DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100
            );
        """
    },
    {
        "description": "Pattern with quantifiers (greedy and reluctant)",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price
                PATTERN (A{2,4}? )
                DEFINE A AS totalprice > 0
            );
        """
    },
]


def run_tests():
    for test in test_queries:
        print("\n--- Running Test: {} ---".format(test["description"]))
        try:
            ast = parse_full_query(test["query"])
            print("Test Passed: Query parsed successfully.")
            print(ast)
        except Exception as e:
            print("Test Failed with error:")
            print(e)
            print("Query:")
            print(test["query"])

if __name__ == "__main__":
    run_tests()

# %%
import logging

# Import your SQL parser function here; adjust the import as needed.
from src.parser.match_recognize_extractor import parse_full_query

logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger(__name__)

# A comprehensive list of test queries covering various SQL components after SELECT.
test_queries = [
    {
        "description": "Wildcard Column Selection",
        "query": "SELECT * FROM orders;"
    },
    {
        "description": "Specific Column Selection",
        "query": "SELECT orderid, custkey, orderdate FROM orders;"
    },
    {
        "description": "Expressions & Aliases",
        "query": "SELECT orderid, totalprice * 0.9 AS discounted_price FROM orders;"
    },
    {
        "description": "Aggregate Functions",
        "query": "SELECT COUNT(*) AS total_orders, SUM(totalprice) AS total_sales FROM orders;"
    },
    {
        "description": "WHERE Clause",
        "query": "SELECT orderid, totalprice FROM orders WHERE totalprice > 100;"
    },
    {
        "description": "ORDER BY Clause",
        "query": "SELECT orderid, orderdate FROM orders ORDER BY orderdate DESC;"
    },
    {
        "description": "GROUP BY & HAVING Clauses",
        "query": "SELECT custkey, COUNT(*) AS order_count FROM orders GROUP BY custkey HAVING COUNT(*) > 5;"
    },
    {
        "description": "LIMIT & OFFSET",
        "query": "SELECT * FROM orders LIMIT 10 OFFSET 20;"
    },
    {
        "description": "DISTINCT",
        "query": "SELECT DISTINCT custkey FROM orders;"
    },
    {
        "description": "JOIN",
        "query": "SELECT o.orderid, c.custname FROM orders o JOIN customers c ON o.custkey = c.custkey;"
    },
    {
        "description": "Subquery",
        "query": "SELECT orderid FROM orders WHERE totalprice > (SELECT AVG(totalprice) FROM orders);"
    },
    {
        "description": "UNION / UNION ALL",
        "query": "SELECT orderid FROM orders_2024 UNION ALL SELECT orderid FROM orders_2025;"
    },
    {
        "description": "CASE Expression",
        "query": "SELECT orderid, CASE WHEN totalprice > 1000 THEN 'High' ELSE 'Low' END AS price_category FROM orders;"
    }
]

def run_tests():
    for test in test_queries:
        print("\n--- Running Test: {} ---".format(test["description"]))
        try:
            ast = parse_full_query(test["query"])
            print("Test Passed: Query parsed successfully.")
            print("AST:", ast)
        except Exception as e:
            print("Test Failed with error:")
            print(e)
            print("Query:")
            print(test["query"])

if __name__ == "__main__":
    run_tests()
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders;
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT orderid, custkey, orderdate FROM orders;
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=orderid, metadata={}), SelectItem(expression=custkey, metadata={}), SelectItem(expression=orderdate, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT orderid, totalprice * 0.9 AS discounted_price FROM orders;
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=orderid, metadata={}), SelectItem(expression=totalprice * 0.9, alias=discounted_price, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT COUNT(*) AS total_orders, SUM(totalprice) AS total_sales FROM orders;
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=COUNT(*), alias=total_orders, metadata={}), SelectItem(expression=SUM(totalprice), alias=total_sales, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT orderid, totalprice FROM orders WHERE totalprice > 100;
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=orderid, metadata={}), SelectItem(expression=totalprice, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT orderid, orderdate FROM orders ORDER BY orderdate DESC;
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=orderid, metadata={}), SelectItem(expression=orderdate, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT custkey, COUNT(*) AS order_count FROM orders GROUP BY custkey HAVING COUNT(*) > 5;
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=custkey, metadata={}), SelectItem(expression=COUNT(*), alias=order_count, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT DISTINCT custkey FROM orders;
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=DISTINCT custkey, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT o.orderid, c.custname FROM orders o JOIN customers c ON o.custkey = c.custkey;
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=o.orderid, metadata={}), SelectItem(expression=c.custname, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT orderid FROM orders WHERE totalprice > (SELECT AVG(totalprice) FROM orders);
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=orderid, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT orderid FROM orders_2024 UNION ALL SELECT orderid FROM orders_2025;
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=orderid, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders_2024')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT orderid, CASE WHEN totalprice > 1000 THEN 'High' ELSE 'Low' END AS price_category FROM orders;
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=orderid, metadata={}), SelectItem(expression=CASE WHEN totalprice > 1000 THEN 'High' ELSE 'Low' END, alias=price_category, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# --- Running Test: Wildcard Column Selection ---
# Test Passed: Query parsed successfully.
# AST: FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=None,
#   order_by=None,
#   measures=None,
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=None,
#   subset=[],
#   define=None
# ),
#   metadata={}
# )
#
# --- Running Test: Specific Column Selection ---
# Test Passed: Query parsed successfully.
# AST: FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=orderid, metadata={}), SelectItem(expression=custkey, metadata={}), SelectItem(expression=orderdate, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=None,
#   order_by=None,
#   measures=None,
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=None,
#   subset=[],
#   define=None
# ),
#   metadata={}
# )
#
# --- Running Test: Expressions & Aliases ---
# Test Passed: Query parsed successfully.
# AST: FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=orderid, metadata={}), SelectItem(expression=totalprice * 0.9, alias=discounted_price, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=None,
#   order_by=None,
#   measures=None,
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=None,
#   subset=[],
#   define=None
# ),
#   metadata={}
# )
#
# --- Running Test: Aggregate Functions ---
# Test Passed: Query parsed successfully.
# AST: FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=COUNT(*), alias=total_orders, metadata={}), SelectItem(expression=SUM(totalprice), alias=total_sales, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=None,
#   order_by=None,
#   measures=None,
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=None,
#   subset=[],
#   define=None
# ),
#   metadata={}
# )
#
# --- Running Test: WHERE Clause ---
# Test Passed: Query parsed successfully.
# AST: FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=orderid, metadata={}), SelectItem(expression=totalprice, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=None,
#   order_by=None,
#   measures=None,
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=None,
#   subset=[],
#   define=None
# ),
#   metadata={}
# )
#
# --- Running Test: ORDER BY Clause ---
# Test Passed: Query parsed successfully.
# AST: FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=orderid, metadata={}), SelectItem(expression=orderdate, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=None,
#   order_by=None,
#   measures=None,
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=None,
#   subset=[],
#   define=None
# ),
#   metadata={}
# )
#
# --- Running Test: GROUP BY & HAVING Clauses ---
# Test Passed: Query parsed successfully.
# AST: FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=custkey, metadata={}), SelectItem(expression=COUNT(*), alias=order_count, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=None,
#   order_by=None,
#   measures=None,
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=None,
#   subset=[],
#   define=None
# ),
#   metadata={}
# )
#
# --- Running Test: LIMIT & OFFSET ---
# Test Failed with error:
# Syntax error at line 1, column 30: missing ';' at 'OFFSET'. Please verify your MATCH_RECOGNIZE clause syntax according to the specification. (Line: 1, Column: 30)
# Snippet: SELECT * FROM orders LIMIT 10 OFFSET 20;
# Query:
# SELECT * FROM orders LIMIT 10 OFFSET 20;
#
# --- Running Test: DISTINCT ---
# Test Passed: Query parsed successfully.
# AST: FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=DISTINCT custkey, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=None,
#   order_by=None,
#   measures=None,
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=None,
#   subset=[],
#   define=None
# ),
#   metadata={}
# )
#
# --- Running Test: JOIN ---
# Test Passed: Query parsed successfully.
# AST: FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=o.orderid, metadata={}), SelectItem(expression=c.custname, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=None,
#   order_by=None,
#   measures=None,
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=None,
#   subset=[],
#   define=None
# ),
#   metadata={}
# )
#
# --- Running Test: Subquery ---
# Test Passed: Query parsed successfully.
# AST: FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=orderid, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=None,
#   order_by=None,
#   measures=None,
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=None,
#   subset=[],
#   define=None
# ),
#   metadata={}
# )
#
# --- Running Test: UNION / UNION ALL ---
# Test Passed: Query parsed successfully.
# AST: FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=orderid, metadata={})]),
#   from_clause=FromClause(table='orders_2024'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=None,
#   order_by=None,
#   measures=None,
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=None,
#   subset=[],
#   define=None
# ),
#   metadata={}
# )
#
# --- Running Test: CASE Expression ---
# Test Passed: Query parsed successfully.
# AST: FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=orderid, metadata={}), SelectItem(expression=CASE WHEN totalprice > 1000 THEN 'High' ELSE 'Low' END, alias=price_category, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=None,
#   order_by=None,
#   measures=None,
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=None,
#   subset=[],
#   define=None
# ),
#   metadata={}
# )

# %%
from src.parser.match_recognize_extractor import parse_match_recognize_query
import logging

logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger(__name__)

test_queries = [
    {
        "description": "Simple pattern with whitespace",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES A.totalprice AS starting_price
                PATTERN (A b+ c*)
                DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100
            );
        """
    },
    {
        "description": "Pattern without whitespace",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES A.totalprice AS starting_price
                PATTERN (AB+C)
                DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
            );
        """
    },
    {
        "description": "Pattern with PERMUTE, grouping, and quantifiers",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES LAST(U.totalprice) AS top_price
                PATTERN (PERMUTE(A,B,C))
                SUBSET U = (A,B,C)
                DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100
            );
        """
    },
    {
        "description": "Mixed pattern: whitespace vs. no whitespace",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES A.totalprice AS starting_price
                PATTERN (A b+ c*)
                DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100
            );
        """
    },
    {
        "description": "Pattern with quantifiers (greedy and reluctant)",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price
                PATTERN (A{2,4}? )
                DEFINE A AS totalprice > 0
            );
        """
    },
]

def run_tests():
    for test in test_queries:
        print("\n--- Running Test: {} ---".format(test["description"]))
        try:
            ast = parse_match_recognize_query(test["query"])
            print("Test Passed: Query parsed successfully.")
            print(ast)
        except Exception as e:
            print("Test Failed with error:")
            print(e)
            print("Query:")
            print(test["query"])

if __name__ == "__main__":
    run_tests()
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN (A b+ c*) DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A b+ c*
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A b+ c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A b+ c*
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<100': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN (AB+C) DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<100': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'B', 'A', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B', 'A', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES LAST(U.totalprice) AS top_price PATTERN (PERMUTE(A,B,C)) SUBSET U = (A,B,C) DEFINE A AS totalprice > 0, B AS totalprice < PREV(totalprice), C AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A,B,C)
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A,B,C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted SUBSET: [SubsetClause(subset_text='U=(A,B,C)')]
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A,B,C)
# DEBUG:src.parser.match_recognize_extractor:Extracted subset mapping: U -> ['A', 'B', 'C']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(U.totalprice)': ['U']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from subset 'U=(A,B,C)': ['A', 'B', 'C']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<100': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'B', 'A', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'U', 'A', 'B', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B', 'A', 'C'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {'U': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(U.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT orderid, custkey, orderdate FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN (A b+ c*) DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=orderid, metadata={}), SelectItem(expression=custkey, metadata={}), SelectItem(expression=orderdate, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A b+ c*
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A b+ c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A b+ c*
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<100': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT orderid AS id, totalprice AS price FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES LAST(A.totalprice) AS ending_price PATTERN (A{2,4}?) DEFINE A AS totalprice > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=orderid, alias=id, metadata={}), SelectItem(expression=totalprice, alias=price, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A{2,4}?'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A{2,4}?
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A{2,4}?', metadata={'variables': ['A{2,4}?'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A{2,4}?'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A{2,4}?
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(A.totalprice)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT DISTINCT orderid, totalprice FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN (A b+ c*) DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=DISTINCT orderid, metadata={}), SelectItem(expression=totalprice, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A b+ c*
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A b+ c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A b+ c*
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<100': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT MAX(totalprice) AS max_price, MIN(totalprice) AS min_price FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price PATTERN (A b+ c*) DEFINE A AS totalprice > 0, b AS totalprice < PREV(totalprice), c AS totalprice < 100 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=MAX(totalprice), alias=max_price, metadata={}), SelectItem(expression=MIN(totalprice), alias=min_price, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A b+ c*
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A b+ c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A b+ c*
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<100': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'c', 'A', 'b'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, LAST(A.totalprice) AS ending_price PATTERN (A{2,4}? ) DEFINE A AS totalprice > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A{2,4}?'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A{2,4}?
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A{2,4}?', metadata={'variables': ['A{2,4}?'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A{2,4}?'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A{2,4}?
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(A.totalprice)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>0': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# --- Running Test: Simple pattern with wildcard ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A b+ c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# ),
#   metadata={}
# )
#
# --- Running Test: Pattern without whitespace in pattern ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# ),
#   metadata={}
# )
#
# --- Running Test: Pattern with PERMUTE, grouping, and quantifiers ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='PERMUTE(A,B,C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[SubsetClause(subset_text='U=(A,B,C)')],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice<100')])
# ),
#   metadata={}
# )
#
# --- Running Test: Select specific columns ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=orderid, metadata={}), SelectItem(expression=custkey, metadata={}), SelectItem(expression=orderdate, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A b+ c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# ),
#   metadata={}
# )
#
# --- Running Test: Select with aliasing ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=orderid, alias=id, metadata={}), SelectItem(expression=totalprice, alias=price, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A{2,4}?', metadata={'variables': ['A{2,4}?'], 'base_variables': ['A']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# ),
#   metadata={}
# )
#
# --- Running Test: Select with DISTINCT ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=DISTINCT orderid, metadata={}), SelectItem(expression=totalprice, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A b+ c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# ),
#   metadata={}
# )
#
# --- Running Test: Select with function calls ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=MAX(totalprice), alias=max_price, metadata={}), SelectItem(expression=MIN(totalprice), alias=min_price, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A b+ c*', metadata={'variables': ['A', 'b+', 'c*'], 'base_variables': ['A', 'b', 'c']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0'), Define(variable='b', condition='totalprice<PREV(totalprice)'), Define(variable='c', condition='totalprice<100')])
# ),
#   metadata={}
# )
#
# --- Running Test: Pattern with quantifiers (greedy and reluctant) ---
# Test Passed: Query parsed successfully.
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.totalprice)', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=None,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A{2,4}?', metadata={'variables': ['A{2,4}?'], 'base_variables': ['A']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='A', condition='totalprice>0')])
# ),
#   metadata={}
# )

# %%
# Out:
# usage: ipykernel_launcher.py [-h] [-v] [-q] [--locals] [--durations N] [-f]
#                              [-c] [-b] [-k TESTNAMEPATTERNS]
#                              [tests ...]
# ipykernel_launcher.py: error: argument -f/--failfast: ignored explicit argument '/run/user/1000/jupyter/runtime/kernel-v3affc58adf2dafecf2238112aa7beb336f44801ee.json'
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /home/monierashraf/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# !python -m unittest src/tests/test_enhanced_features.py
# Out:
# E
# ======================================================================
# ERROR: src/tests/test_enhanced_features (unittest.loader._FailedTest.src/tests/test_enhanced_features)
# ----------------------------------------------------------------------
# ImportError: Failed to import test module: src/tests/test_enhanced_features
# Traceback (most recent call last):
#   File "/home/monierashraf/anaconda3/lib/python3.12/unittest/loader.py", line 137, in loadTestsFromName
#     module = __import__(module_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^
# ModuleNotFoundError: No module named 'src/tests/test_enhanced_features'
#
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# FAILED (errors=1)

# %%
# test_pattern.py
from src.parser.match_recognize_extractor import parse_full_query
import json

query = """
SELECT *
FROM orders
MATCH_RECOGNIZE (
    PARTITION BY orderkey
    ORDER BY orderdate
    MEASURES
        RUNNING COUNT(*) as cnt
    PATTERN (^A {-B-} (C | D)$)
    DEFINE
        A AS A.totalprice > 100,
        B AS B.totalprice > 200,
        C AS C.totalprice > 300,
        D AS D.totalprice > 400
)
"""

ast = parse_full_query(query)
print("Pattern:", ast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # test_pattern.py
# ----> 2 from src.parser.match_recognize_extractor import parse_full_query
#       3 import json
#       5 query = """
#       6 SELECT *
#       7 FROM orders
#    (...)
#      19 )
#      20 """
#
# File ~/Desktop/llm/Row_match_recognize/src/parser/match_recognize_extractor.py:39
#      36     parts = re.split(r'\s*AS\s*', raw_text, maxsplit=1, flags=re.IGNORECASE)
#      37     return parts
# ---> 39 def post_process_text(text: Optional[str]) -> Optional[str]:
#      40     if text is None:
#      41         return text
#
# NameError: name 'Optional' is not defined

# %%
test coverage

# %%
from src.parser.match_recognize_extractor import parse_full_query
from src.ast.ast_nodes import FullQueryAST

# Define a list of test queries to cover edge cases and full coverage
test_queries = [
    # 1. Basic ONE ROW PER MATCH
    {
        "name": "Basic One Row Per Match",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    A.totalprice AS starting_price,
                    LAST(B.totalprice) AS bottom_price
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 2. ALL ROWS PER MATCH with SHOW EMPTY MATCHES, SUBSET clause and union variable
    {
        "name": "All Rows Per Match - Show Empty Matches",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    A.totalprice AS starting_price,
                    LAST(B.totalprice) AS bottom_price,
                    LAST(U.totalprice) AS top_price
                ALL ROWS PER MATCH SHOW EMPTY MATCHES
                PATTERN (A | B | C | D)
                SUBSET U = (C, D)
                DEFINE
                    B AS totalprice < PREV(totalprice),
                    C AS totalprice > PREV(totalprice) AND totalprice <= A.totalprice,
                    D AS totalprice > PREV(totalprice)
            );
        """
    },
    # 3. ALL ROWS PER MATCH with OMIT EMPTY MATCHES
    {
        "name": "All Rows Per Match - Omit Empty Matches",
        "query": """
            SELECT * FROM transactions MATCH_RECOGNIZE(
                PARTITION BY account_id
                ORDER BY transaction_date
                MEASURES
                    A.amount AS start_amount,
                    C.amount AS final_amount
                ALL ROWS PER MATCH OMIT EMPTY MATCHES
                PATTERN (A | B | C)
                DEFINE
                    B AS amount < PREV(amount),
                    C AS amount > PREV(amount)
            );
        """
    },
    # 4. ALL ROWS PER MATCH WITH UNMATCHED ROWS
    {
        "name": "All Rows Per Match - With Unmatched Rows",
        "query": """
            SELECT * FROM sales MATCH_RECOGNIZE(
                PARTITION BY region
                ORDER BY sale_date
                MEASURES
                    A.price AS initial_price,
                    D.price AS final_price
                ALL ROWS PER MATCH WITH UNMATCHED ROWS
                PATTERN (A B C D)
                DEFINE
                    B AS price < PREV(price),
                    C AS price > PREV(price),
                    D AS price > A.price
            );
        """
    },
    # 5. Nested Pattern: union variables and repeated groups with WITH UNMATCHED ROWS
    {
        "name": "Nested Pattern with Unmatched Rows",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    A.totalprice AS starting_price,
                    F.totalprice AS ending_price
                ALL ROWS PER MATCH WITH UNMATCHED ROWS
                PATTERN (A (B C | D E)+ F)
                DEFINE
                    B AS totalprice < PREV(totalprice),
                    C AS totalprice > PREV(totalprice),
                    D AS totalprice = PREV(totalprice),
                    E AS totalprice >= PREV(totalprice)
            );
        """
    },
    # 6. Using Classifier() and MATCH_NUMBER() functions
    {
        "name": "Classifier and Match Number Functions",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    CLASSIFIER() AS pattern_type,
                    MATCH_NUMBER() AS match_id,
                    A.totalprice AS starting_price,
                    LAST(B.totalprice) AS bottom_price
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 7. Running vs Final Semantics in MEASURES
    {
        "name": "Running vs Final Semantics in Measures",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    RUNNING LAST(A.totalprice) AS running_last_price,
                    FINAL LAST(A.totalprice) AS final_last_price
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 8. Aggregates with Running vs Final semantics (avg and count)
    {
        "name": "Running Avg vs Final Count Functions",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    RUNNING avg(A.totalprice) AS running_avg,
                    FINAL count(A.*) AS final_count
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 9. Empty Match: pattern that produces an empty match for every row
    {
        "name": "Empty Match and Unmatched Rows",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    A.totalprice AS starting_price,
                    count(A.*) AS match_count
                ONE ROW PER MATCH
                PATTERN (())
            );
        """
    },
    # 10. Physical Navigation Functions: PREV() and NEXT()
    {
        "name": "Physical Navigation Functions",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    PREV(A.totalprice, 2) AS prev_price,
                    NEXT(A.totalprice, 1) AS next_price
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 11. Nested Navigation Function
    {
        "name": "Nested Navigation Function",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    PREV(FIRST(A.totalprice, 3), 2) AS nested_nav_price
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    }
]

# Run all test cases and print the resulting AST
for test in test_queries:
    print(f"🔹 Running Test: {test['name']}")
    try:
        query_ast = parse_full_query(test["query"])
        print(query_ast)
    except Exception as e:
        print(f"Error: {e}")
    print("=" * 80)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, LAST(B.totalprice) AS bottom_price ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(B.totalprice)': ['B']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(B.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, LAST(B.totalprice) AS bottom_price, LAST(U.totalprice) AS top_price ALL ROWS PER MATCH SHOW EMPTY MATCHES PATTERN (A | B | C | D) SUBSET U = (C, D) DEFINE B AS totalprice < PREV(totalprice), C AS totalprice > PREV(totalprice) AND totalprice <= A.totalprice, D AS totalprice > PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALLROWSPERMATCHSHOWEMPTYMATCHES
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH SHOW EMPTY MATCHES
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A|B|C|D
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A|B|C|D', metadata={'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']})
# DEBUG:src.parser.match_recognize_extractor:Extracted SUBSET: [SubsetClause(subset_text='U=(C,D)')]
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice>PREV(totalprice)ANDtotalprice<=A.totalprice'), Define(variable='D', condition='totalprice>PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A|B|C|D
# DEBUG:src.parser.match_recognize_extractor:Extracted subset mapping: U -> ['C', 'D']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(B.totalprice)': ['B']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(U.totalprice)': ['U']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from subset 'U=(C,D)': ['C', 'D']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>PREV(totalprice)ANDtotalprice<=A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B', 'D'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'U', 'C', 'D', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'C', 'D', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {'U': ['C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(B.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(U.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM transactions MATCH_RECOGNIZE( PARTITION BY account_id ORDER BY transaction_date MEASURES A.amount AS start_amount, C.amount AS final_amount ALL ROWS PER MATCH OMIT EMPTY MATCHES PATTERN (A | B | C) DEFINE B AS amount < PREV(amount), C AS amount > PREV(amount) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='transactions')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['account_id'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='transaction_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.amount', alias='start_amount', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='C.amount', alias='final_amount', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALLROWSPERMATCHOMITEMPTYMATCHES
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH OMIT EMPTY MATCHES
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A|B|C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A|B|C', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='amount<PREV(amount)'), Define(variable='C', condition='amount>PREV(amount)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A|B|C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.amount': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'C.amount': ['C']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'amount<PREV(amount)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'amount>PREV(amount)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'C', 'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'C', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.amount
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: C.amount
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM sales MATCH_RECOGNIZE( PARTITION BY region ORDER BY sale_date MEASURES A.price AS initial_price, D.price AS final_price ALL ROWS PER MATCH WITH UNMATCHED ROWS PATTERN (A B C D) DEFINE B AS price < PREV(price), C AS price > PREV(price), D AS price > A.price );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='sales')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['region'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='sale_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.price', alias='initial_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='D.price', alias='final_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALLROWSPERMATCHWITHUNMATCHEDROWS
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH WITH UNMATCHED ROWS
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: ABCD
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='ABCD', metadata={'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='price<PREV(price)'), Define(variable='C', condition='price>PREV(price)'), Define(variable='D', condition='price>A.price')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: ABCD
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.price': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'D.price': ['D']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'price<PREV(price)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'price>PREV(price)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'price>A.price': ['A']
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B', 'D'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'D', 'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'C', 'D', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.price
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: D.price
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, F.totalprice AS ending_price ALL ROWS PER MATCH WITH UNMATCHED ROWS PATTERN (A (B C | D E)+ F) DEFINE B AS totalprice < PREV(totalprice), C AS totalprice > PREV(totalprice), D AS totalprice = PREV(totalprice), E AS totalprice >= PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='F.totalprice', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALLROWSPERMATCHWITHUNMATCHEDROWS
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH WITH UNMATCHED ROWS
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D', 'E', 'F'], 'base_variables': ['A', 'B', 'C', 'D', 'E', 'F']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A(BC|DE)+F
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A(BC|DE)+F', metadata={'variables': ['A', 'B', 'C', 'D', 'E', 'F'], 'base_variables': ['A', 'B', 'C', 'D', 'E', 'F']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice>PREV(totalprice)'), Define(variable='D', condition='totalprice=PREV(totalprice)'), Define(variable='E', condition='totalprice>=PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D', 'E', 'F'], 'base_variables': ['A', 'B', 'C', 'D', 'E', 'F']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A(BC|DE)+F
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'F.totalprice': ['F']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice=PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>=PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'F', 'C', 'D', 'A', 'E', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'F', 'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'C', 'E', 'D', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: F.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES CLASSIFIER() AS pattern_type, MATCH_NUMBER() AS match_id, A.totalprice AS starting_price, LAST(B.totalprice) AS bottom_price ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_type', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_id', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'CLASSIFIER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'MATCH_NUMBER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(B.totalprice)': ['B']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(B.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES RUNNING LAST(A.totalprice) AS running_last_price, FINAL LAST(A.totalprice) AS final_last_price ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='RUNNINGLAST(A.totalprice)', alias='running_last_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='FINALLAST(A.totalprice)', alias='final_last_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'RUNNINGLAST(A.totalprice)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'FINALLAST(A.totalprice)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: RUNNINGLAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: FINALLAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES RUNNING avg(A.totalprice) AS running_avg, FINAL count(A.*) AS final_count ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='RUNNINGavg(A.totalprice)', alias='running_avg', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='FINALcount(A.*)', alias='final_count', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'RUNNINGavg(A.totalprice)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'FINALcount(A.*)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: RUNNINGavg(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: FINALcount(A.*)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES PREV(A.totalprice, 2) AS prev_price, NEXT(A.totalprice, 1) AS next_price ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='PREV(A.totalprice,2)', alias='prev_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='NEXT(A.totalprice,1)', alias='next_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'PREV(A.totalprice,2)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'NEXT(A.totalprice,1)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: PREV(A.totalprice,2)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: NEXT(A.totalprice,1)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES PREV(FIRST(A.totalprice, 3), 2) AS nested_nav_price ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='PREV(FIRST(A.totalprice,3),2)', alias='nested_nav_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'PREV(FIRST(A.totalprice,3),2)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: PREV(FIRST(A.totalprice,3),2)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# 🔹 Running Test: Basic One Row Per Match
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: All Rows Per Match - Show Empty Matches
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ALL ROWS PER MATCH SHOW EMPTY MATCHES,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A|B|C|D', metadata={'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}),
#   subset=[SubsetClause(subset_text='U=(C,D)')],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice>PREV(totalprice)ANDtotalprice<=A.totalprice'), Define(variable='D', condition='totalprice>PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: All Rows Per Match - Omit Empty Matches
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='transactions'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['account_id']),
#   order_by=OrderByClause(sort_items=[SortItem(column='transaction_date', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.amount', alias='start_amount', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='C.amount', alias='final_amount', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ALL ROWS PER MATCH OMIT EMPTY MATCHES,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A|B|C', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='amount<PREV(amount)'), Define(variable='C', condition='amount>PREV(amount)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: All Rows Per Match - With Unmatched Rows
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='sales'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['region']),
#   order_by=OrderByClause(sort_items=[SortItem(column='sale_date', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.price', alias='initial_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='D.price', alias='final_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ALL ROWS PER MATCH WITH UNMATCHED ROWS,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='ABCD', metadata={'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='price<PREV(price)'), Define(variable='C', condition='price>PREV(price)'), Define(variable='D', condition='price>A.price')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Nested Pattern with Unmatched Rows
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='F.totalprice', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ALL ROWS PER MATCH WITH UNMATCHED ROWS,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A(BC|DE)+F', metadata={'variables': ['A', 'B', 'C', 'D', 'E', 'F'], 'base_variables': ['A', 'B', 'C', 'D', 'E', 'F']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice>PREV(totalprice)'), Define(variable='D', condition='totalprice=PREV(totalprice)'), Define(variable='E', condition='totalprice>=PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Classifier and Match Number Functions
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_type', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_id', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Running vs Final Semantics in Measures
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='RUNNINGLAST(A.totalprice)', alias='running_last_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='FINALLAST(A.totalprice)', alias='final_last_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Running Avg vs Final Count Functions
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='RUNNINGavg(A.totalprice)', alias='running_avg', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='FINALcount(A.*)', alias='final_count', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Empty Match and Unmatched Rows
# Error: Syntax error at line 9, column 12: mismatched input ')' expecting {'DEFINE', 'SUBSET'}. Please verify your MATCH_RECOGNIZE clause syntax according to the specification. (Line: 9, Column: 12)
# Snippet: SELECT * FROM orders MATCH_RECOGNIZE(
#                 PARTITION BY custkey
#                 ORDER BY orderdate
#                 MEASURES
#                     A.totalprice AS starting_price,
#                     count(A.*) AS match_count
#                 ONE ROW PER MATCH
#                 PATTERN (())
#             );
# ================================================================================
# 🔹 Running Test: Physical Navigation Functions
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='PREV(A.totalprice,2)', alias='prev_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='NEXT(A.totalprice,1)', alias='next_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Nested Navigation Function
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='PREV(FIRST(A.totalprice,3),2)', alias='nested_nav_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================

# %%
from src.parser.match_recognize_extractor import parse_full_query
from src.ast.ast_nodes import FullQueryAST

# Define a list of test queries to cover edge cases and full coverage
test_queries = [
    # 1. Basic ONE ROW PER MATCH
    {
        "name": "Basic One Row Per Match",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    A.totalprice AS starting_price,
                    LAST(B.totalprice) AS bottom_price
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 2. ALL ROWS PER MATCH with SHOW EMPTY MATCHES, SUBSET clause and union variable
    {
        "name": "All Rows Per Match - Show Empty Matches",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    A.totalprice AS starting_price,
                    LAST(B.totalprice) AS bottom_price,
                    LAST(U.totalprice) AS top_price
                ALL ROWS PER MATCH SHOW EMPTY MATCHES
                PATTERN (A | B | C | D)
                SUBSET U = (C, D)
                DEFINE
                    B AS totalprice < PREV(totalprice),
                    C AS totalprice > PREV(totalprice) AND totalprice <= A.totalprice,
                    D AS totalprice > PREV(totalprice)
            );
        """
    },
    # 3. ALL ROWS PER MATCH with OMIT EMPTY MATCHES
    {
        "name": "All Rows Per Match - Omit Empty Matches",
        "query": """
            SELECT * FROM transactions MATCH_RECOGNIZE(
                PARTITION BY account_id
                ORDER BY transaction_date
                MEASURES
                    A.amount AS start_amount,
                    C.amount AS final_amount
                ALL ROWS PER MATCH OMIT EMPTY MATCHES
                PATTERN (A | B | C)
                DEFINE
                    B AS amount < PREV(amount),
                    C AS amount > PREV(amount)
            );
        """
    },
    # 4. ALL ROWS PER MATCH WITH UNMATCHED ROWS
    {
        "name": "All Rows Per Match - With Unmatched Rows",
        "query": """
            SELECT * FROM sales MATCH_RECOGNIZE(
                PARTITION BY region
                ORDER BY sale_date
                MEASURES
                    A.price AS initial_price,
                    D.price AS final_price
                ALL ROWS PER MATCH WITH UNMATCHED ROWS
                PATTERN (A B C D)
                DEFINE
                    B AS price < PREV(price),
                    C AS price > PREV(price),
                    D AS price > A.price
            );
        """
    },
    # 5. Nested Pattern: union variables and repeated groups with WITH UNMATCHED ROWS
    {
        "name": "Nested Pattern with Unmatched Rows",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    A.totalprice AS starting_price,
                    F.totalprice AS ending_price
                ALL ROWS PER MATCH WITH UNMATCHED ROWS
                PATTERN (A (B C | D E)+ F)
                DEFINE
                    B AS totalprice < PREV(totalprice),
                    C AS totalprice > PREV(totalprice),
                    D AS totalprice = PREV(totalprice),
                    E AS totalprice >= PREV(totalprice)
            );
        """
    },
    # 6. Using Classifier() and MATCH_NUMBER() functions
    {
        "name": "Classifier and Match Number Functions",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    CLASSIFIER() AS pattern_type,
                    MATCH_NUMBER() AS match_id,
                    A.totalprice AS starting_price,
                    LAST(B.totalprice) AS bottom_price
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 7. Running vs Final Semantics in MEASURES
    {
        "name": "Running vs Final Semantics in Measures",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    RUNNING LAST(A.totalprice) AS running_last_price,
                    FINAL LAST(A.totalprice) AS final_last_price
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 8. Aggregates with Running vs Final semantics (avg and count)
    {
        "name": "Running Avg vs Final Count Functions",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    RUNNING avg(A.totalprice) AS running_avg,
                    FINAL count(A.*) AS final_count
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 9. Empty Match: pattern that produces an empty match for every row
    {
        "name": "Empty Match and Unmatched Rows",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    A.totalprice AS starting_price,
                    count(A.*) AS match_count
                ONE ROW PER MATCH
                PATTERN (())
            );
        """
    },
    # 10. Physical Navigation Functions: PREV() and NEXT()
    {
        "name": "Physical Navigation Functions",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    PREV(A.totalprice, 2) AS prev_price,
                    NEXT(A.totalprice, 1) AS next_price
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    },
    # 11. Nested Navigation Function
    {
        "name": "Nested Navigation Function",
        "query": """
            SELECT * FROM orders MATCH_RECOGNIZE(
                PARTITION BY custkey
                ORDER BY orderdate
                MEASURES
                    PREV(FIRST(A.totalprice, 3), 2) AS nested_nav_price
                ONE ROW PER MATCH
                PATTERN (A B+ C)
                DEFINE
                    B AS totalprice < PREV(totalprice)
            );
        """
    }
]

# Run all test cases and print the resulting AST
for test in test_queries:
    print(f"🔹 Running Test: {test['name']}")
    try:
        query_ast = parse_full_query(test["query"])
        print(query_ast)
    except Exception as e:
        print(f"Error: {e}")
    print("=" * 80)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, LAST(B.totalprice) AS bottom_price ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(B.totalprice)': ['B']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(B.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, LAST(B.totalprice) AS bottom_price, LAST(U.totalprice) AS top_price ALL ROWS PER MATCH SHOW EMPTY MATCHES PATTERN (A | B | C | D) SUBSET U = (C, D) DEFINE B AS totalprice < PREV(totalprice), C AS totalprice > PREV(totalprice) AND totalprice <= A.totalprice, D AS totalprice > PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALLROWSPERMATCHSHOWEMPTYMATCHES
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH SHOW EMPTY MATCHES
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A|B|C|D
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A|B|C|D', metadata={'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']})
# DEBUG:src.parser.match_recognize_extractor:Extracted SUBSET: [SubsetClause(subset_text='U=(C,D)')]
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice>PREV(totalprice)ANDtotalprice<=A.totalprice'), Define(variable='D', condition='totalprice>PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A|B|C|D
# DEBUG:src.parser.match_recognize_extractor:Extracted subset mapping: U -> ['C', 'D']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(B.totalprice)': ['B']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(U.totalprice)': ['U']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from subset 'U=(C,D)': ['C', 'D']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>PREV(totalprice)ANDtotalprice<=A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B', 'D'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'U', 'C', 'D', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'C', 'D', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {'U': ['C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(B.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(U.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM transactions MATCH_RECOGNIZE( PARTITION BY account_id ORDER BY transaction_date MEASURES A.amount AS start_amount, C.amount AS final_amount ALL ROWS PER MATCH OMIT EMPTY MATCHES PATTERN (A | B | C) DEFINE B AS amount < PREV(amount), C AS amount > PREV(amount) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='transactions')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['account_id'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='transaction_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.amount', alias='start_amount', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='C.amount', alias='final_amount', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALLROWSPERMATCHOMITEMPTYMATCHES
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH OMIT EMPTY MATCHES
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A|B|C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A|B|C', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='amount<PREV(amount)'), Define(variable='C', condition='amount>PREV(amount)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A|B|C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.amount': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'C.amount': ['C']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'amount<PREV(amount)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'amount>PREV(amount)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'C', 'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'C', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.amount
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: C.amount
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM sales MATCH_RECOGNIZE( PARTITION BY region ORDER BY sale_date MEASURES A.price AS initial_price, D.price AS final_price ALL ROWS PER MATCH WITH UNMATCHED ROWS PATTERN (A B C D) DEFINE B AS price < PREV(price), C AS price > PREV(price), D AS price > A.price );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='sales')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['region'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='sale_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.price', alias='initial_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='D.price', alias='final_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALLROWSPERMATCHWITHUNMATCHEDROWS
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH WITH UNMATCHED ROWS
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: ABCD
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='ABCD', metadata={'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='price<PREV(price)'), Define(variable='C', condition='price>PREV(price)'), Define(variable='D', condition='price>A.price')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: ABCD
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.price': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'D.price': ['D']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'price<PREV(price)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'price>PREV(price)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'price>A.price': ['A']
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B', 'D'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'D', 'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'C', 'D', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.price
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: D.price
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES A.totalprice AS starting_price, F.totalprice AS ending_price ALL ROWS PER MATCH WITH UNMATCHED ROWS PATTERN (A (B C | D E)+ F) DEFINE B AS totalprice < PREV(totalprice), C AS totalprice > PREV(totalprice), D AS totalprice = PREV(totalprice), E AS totalprice >= PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='F.totalprice', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALLROWSPERMATCHWITHUNMATCHEDROWS
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH WITH UNMATCHED ROWS
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D', 'E', 'F'], 'base_variables': ['A', 'B', 'C', 'D', 'E', 'F']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A(BC|DE)+F
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A(BC|DE)+F', metadata={'variables': ['A', 'B', 'C', 'D', 'E', 'F'], 'base_variables': ['A', 'B', 'C', 'D', 'E', 'F']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice>PREV(totalprice)'), Define(variable='D', condition='totalprice=PREV(totalprice)'), Define(variable='E', condition='totalprice>=PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B', 'C', 'D', 'E', 'F'], 'base_variables': ['A', 'B', 'C', 'D', 'E', 'F']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A(BC|DE)+F
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'F.totalprice': ['F']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice=PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice>=PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'F', 'C', 'D', 'A', 'E', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'F', 'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'C', 'E', 'D', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: F.totalprice
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES CLASSIFIER() AS pattern_type, MATCH_NUMBER() AS match_id, A.totalprice AS starting_price, LAST(B.totalprice) AS bottom_price ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_type', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_id', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'CLASSIFIER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'MATCH_NUMBER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(B.totalprice)': ['B']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(B.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES RUNNING LAST(A.totalprice) AS running_last_price, FINAL LAST(A.totalprice) AS final_last_price ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='RUNNINGLAST(A.totalprice)', alias='running_last_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='FINALLAST(A.totalprice)', alias='final_last_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'RUNNINGLAST(A.totalprice)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'FINALLAST(A.totalprice)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: RUNNINGLAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: FINALLAST(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES RUNNING avg(A.totalprice) AS running_avg, FINAL count(A.*) AS final_count ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='RUNNINGavg(A.totalprice)', alias='running_avg', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='FINALcount(A.*)', alias='final_count', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'RUNNINGavg(A.totalprice)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'FINALcount(A.*)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: RUNNINGavg(A.totalprice)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: FINALcount(A.*)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES PREV(A.totalprice, 2) AS prev_price, NEXT(A.totalprice, 1) AS next_price ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='PREV(A.totalprice,2)', alias='prev_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='NEXT(A.totalprice,1)', alias='next_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'PREV(A.totalprice,2)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'NEXT(A.totalprice,1)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: PREV(A.totalprice,2)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: NEXT(A.totalprice,1)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE( PARTITION BY custkey ORDER BY orderdate MEASURES PREV(FIRST(A.totalprice, 3), 2) AS nested_nav_price ONE ROW PER MATCH PATTERN (A B+ C) DEFINE B AS totalprice < PREV(totalprice) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='PREV(FIRST(A.totalprice,3),2)', alias='nested_nav_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'PREV(FIRST(A.totalprice,3),2)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: PREV(FIRST(A.totalprice,3),2)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# 🔹 Running Test: Basic One Row Per Match
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: All Rows Per Match - Show Empty Matches
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(U.totalprice)', alias='top_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ALL ROWS PER MATCH SHOW EMPTY MATCHES,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A|B|C|D', metadata={'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}),
#   subset=[SubsetClause(subset_text='U=(C,D)')],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice>PREV(totalprice)ANDtotalprice<=A.totalprice'), Define(variable='D', condition='totalprice>PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: All Rows Per Match - Omit Empty Matches
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='transactions'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['account_id']),
#   order_by=OrderByClause(sort_items=[SortItem(column='transaction_date', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.amount', alias='start_amount', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='C.amount', alias='final_amount', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ALL ROWS PER MATCH OMIT EMPTY MATCHES,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A|B|C', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='amount<PREV(amount)'), Define(variable='C', condition='amount>PREV(amount)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: All Rows Per Match - With Unmatched Rows
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='sales'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['region']),
#   order_by=OrderByClause(sort_items=[SortItem(column='sale_date', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.price', alias='initial_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='D.price', alias='final_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ALL ROWS PER MATCH WITH UNMATCHED ROWS,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='ABCD', metadata={'variables': ['A', 'B', 'C', 'D'], 'base_variables': ['A', 'B', 'C', 'D']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='price<PREV(price)'), Define(variable='C', condition='price>PREV(price)'), Define(variable='D', condition='price>A.price')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Nested Pattern with Unmatched Rows
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='F.totalprice', alias='ending_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ALL ROWS PER MATCH WITH UNMATCHED ROWS,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='A(BC|DE)+F', metadata={'variables': ['A', 'B', 'C', 'D', 'E', 'F'], 'base_variables': ['A', 'B', 'C', 'D', 'E', 'F']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)'), Define(variable='C', condition='totalprice>PREV(totalprice)'), Define(variable='D', condition='totalprice=PREV(totalprice)'), Define(variable='E', condition='totalprice>=PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Classifier and Match Number Functions
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_type', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_id', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Running vs Final Semantics in Measures
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='RUNNINGLAST(A.totalprice)', alias='running_last_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='FINALLAST(A.totalprice)', alias='final_last_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Running Avg vs Final Count Functions
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='RUNNINGavg(A.totalprice)', alias='running_avg', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='FINALcount(A.*)', alias='final_count', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Empty Match and Unmatched Rows
# Error: Syntax error at line 9, column 12: mismatched input ')' expecting {'DEFINE', 'SUBSET'}. Please verify your MATCH_RECOGNIZE clause syntax according to the specification. (Line: 9, Column: 12)
# Snippet: SELECT * FROM orders MATCH_RECOGNIZE(
#                 PARTITION BY custkey
#                 ORDER BY orderdate
#                 MEASURES
#                     A.totalprice AS starting_price,
#                     count(A.*) AS match_count
#                 ONE ROW PER MATCH
#                 PATTERN (())
#             );
# ================================================================================
# 🔹 Running Test: Physical Navigation Functions
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='PREV(A.totalprice,2)', alias='prev_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='NEXT(A.totalprice,1)', alias='next_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================
# 🔹 Running Test: Nested Navigation Function
# FullQueryAST(
#   select_clause=SelectClause(items=[SelectItem(expression=*, metadata={})]),
#   from_clause=FromClause(table='orders'),
#   match_recognize=MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='PREV(FIRST(A.totalprice,3),2)', alias='nested_nav_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# ),
#   metadata={}
# )
# ================================================================================

# %%
from src.parser.match_recognize_extractor import parse_match_recognize_query
if __name__ == "__main__":
    sample_query = """
SELECT *
FROM orders
MATCH_RECOGNIZE(
  PARTITION BY custkey
  ORDER BY orderdate
  MEASURES
    CLASSIFIER() AS pattern_type,
    MATCH_NUMBER() AS match_id,
    A.totalprice AS starting_price,
    LAST(B.totalprice) AS bottom_price
  ONE ROW PER MATCH
  PATTERN (A B+ C)
  DEFINE
    B AS totalprice < PREV(totalprice)
);
    """
    components = parse_match_recognize_query(sample_query)

    print(components)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['custkey'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_type', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_id', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: AB+C
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'CLASSIFIER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'MATCH_NUMBER()': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'A.totalprice': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(B.totalprice)': ['B']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'totalprice<PREV(totalprice)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'C', 'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A', 'B'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'B'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.totalprice
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(B.totalprice)
# MatchRecognizeClause(
#   partition_by=PartitionByClause(columns=['custkey']),
#   order_by=OrderByClause(sort_items=[SortItem(column='orderdate', ordering='ASC', nulls_ordering=None)]),
#   measures=MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_type', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_id', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='A.totalprice', alias='starting_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(B.totalprice)', alias='bottom_price', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)]),
#   rows_per_match=ONE ROW PER MATCH,
#   after_match_skip=None,
#   pattern=PatternClause(pattern='AB+C', metadata={'variables': ['A', 'B+', 'C'], 'base_variables': ['A', 'B', 'C']}),
#   subset=[],
#   define=DefineClause(definitions=[Define(variable='B', condition='totalprice<PREV(totalprice)')])
# )

# %%
# !find . -type f -name "*.py" | sort
# Out:
# ./1.py
# ./2.py
# ./3.py
# ./__init__.py
# ./m3.py
# ./maiaas22222n.py
# ./main.py
# ./src/ast/ast_nodes.py
# ./src/ast/__init__.py
# ./src/executor/__init__.py
# ./src/grammar/__init__.py
# ./src/grammar/TrinoLexer.py
# ./src/grammar/TrinoParserListener.py
# ./src/grammar/TrinoParser.py
# ./src/grammar/TrinoParserVisitor.py
# ./src/__init__.py
# ./src/optimizer/__init__.py
# ./src/parser/error_listeners.py
# ./src/parser/__init__.py
# ./src/parser/match_recognize_extractor.py
# ./src/parser/query_parser.py
# ./src/validator/__init__.py
# ./tests/__init__.py
# ./tests/test_ast.py
# ./tests/test_parser_edge_cases.py
# ./tests/test_parser.py
# ./tests/test_validator.py

# %% [markdown]
# final work as we expected

# %%
import sys
import pandas as pd
# Use an absolute import for match_recognize.
from transformations.match_recognize import match_recognize

query = """
    SELECT id, name FROM employees MATCH_RECOGNIZE (
        PARTITION BY department, region
        ORDER BY hire_date
        MEASURES salary AS avg_salary
        PATTERN (A)
        DEFINE A AS salary > 1000
    );
    """
    
data = [
        {"id": 1, "name": "Alice",   "department": "Sales", "region": "West", "hire_date": "2021-01-01", "salary": 1200},
        {"id": 2, "name": "Bob",     "department": "Sales", "region": "West", "hire_date": "2021-01-02", "salary": 1300},
        {"id": 3, "name": "Charlie", "department": "Sales", "region": "West", "hire_date": "2021-01-03", "salary": 900},
        {"id": 4, "name": "Diana",   "department": "Sales", "region": "West", "hire_date": "2021-01-04", "salary": 1100},
    ]
    
try:
        output_df = match_recognize(query, pd.DataFrame(data))
        print("Match Recognize Output:")
        print(output_df)
except Exception as e:
        print(f"Error: {str(e)}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 4
#       2 import pandas as pd
#       3 # Use an absolute import for match_recognize.
# ----> 4 from transformations.match_recognize import match_recognize
#       6 query = """
#       7     SELECT id, name FROM employees MATCH_RECOGNIZE (
#       8         PARTITION BY department, region
#    (...)
#      13     );
#      14     """
#      16 data = [
#      17         {"id": 1, "name": "Alice",   "department": "Sales", "region": "West", "hire_date": "2021-01-01", "salary": 1200},
#      18         {"id": 2, "name": "Bob",     "department": "Sales", "region": "West", "hire_date": "2021-01-02", "salary": 1300},
#      19         {"id": 3, "name": "Charlie", "department": "Sales", "region": "West", "hire_date": "2021-01-03", "salary": 900},
#      20         {"id": 4, "name": "Diana",   "department": "Sales", "region": "West", "hire_date": "2021-01-04", "salary": 1100},
#      21     ]
#
# File ~/Desktop/llm/Match_recognize/project/transformations/__init__.py:5
#       1 """
#       2 SQL pattern matching transformations with type checking.
#       3 """
# ----> 5 from .automaton import (
#       6     AutomatonBuilder,
#       7     AutomatonExecutionEngine,
#       8     Match,
#       9     ExpressionEvaluator,
#      10     TypedValue
#      11 )
#      13 from .expressions import (
#      14     ExpressionAST,
#      15     infer_expression_return_type,
#    (...)
#      18     TypeCheckError
#      19 )
#      21 __all__ = [
#      22     # Main classes for pattern matching
#      23     'AutomatonBuilder',
#    (...)
#      34     'TypeCheckError'
#      35 ]
#
# File ~/Desktop/llm/Match_recognize/project/transformations/automaton/__init__.py:9
#       7 from .dfa import DFA
#       8 from .pattern_to_nfa import PatternToNFA
# ----> 9 from .automaton_builder import AutomatonBuilder
#      10 from .execution_engine import AutomatonExecutionEngine
#      11 from .match import Match
#
# File ~/Desktop/llm/Match_recognize/project/transformations/automaton/automaton_builder.py:8
#       6 from .dfa import DFA
#       7 from .state import State
# ----> 8 from .execution_engine import AutomatonExecutionEngine, Match, ExpressionEvaluator
#       9 from ..expressions.expressions_parser import ExpressionAST
#      10 from ..expressions.type_inference import (
#      11     infer_expression_return_type, validate_pattern_variable_conditions,
#      12     validate_measure_expressions, build_variable_schema, TypeCheckError
#      13 )
#
# File ~/Desktop/llm/Match_recognize/project/transformations/automaton/execution_engine.py:10
#       8 from .expression_evaluator import ExpressionEvaluator, TypedValue
#       9 from .match import Match
# ---> 10 from .automaton_builder import AutomatonBuilder
#      11 from ..pattern.pattern_ast import PatternAST
#      12 from ..expressions.expressions_parser import parse_expression
#
# ImportError: cannot import name 'AutomatonBuilder' from partially initialized module 'transformations.automaton.automaton_builder' (most likely due to a circular import) (/home/monierashraf/Desktop/llm/Match_recognize/project/transformations/automaton/automaton_builder.py)
