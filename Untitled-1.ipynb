    (89, 205, "2025-06-02 13:33:00", "buy", 3904.98),
    (90, 203, "2025-06-02 12:32:00", "buy", 5979.25),
    (91, 202, "2025-06-02 09:07:00", "profit", 1830.45),
    (92, 202, "2025-06-02 10:27:00", "profit", 395.29),
    (93, 204, "2025-06-02 12:12:00", "buy", 2600.49),
    (94, 202, "2025-06-02 11:35:00", "buy", 7299.24),
    (95, 204, "2025-06-02 09:02:00", "sell", 5323.18),
    (96, 201, "2025-06-02 13:59:00", "profit", 548.76),
    (97, 203, "2025-06-02 09:05:00", "buy", 5353.26),
    (98, 203, "2025-06-02 11:34:00", "sell", 4335.24),
    (99, 204, "2025-06-02 13:34:00", "sell", 9847.59),
    (100, 203, "2025-06-02 11:11:00", "sell", 8867.13),
]

df = pd.DataFrame(data, columns=["id", "user_id", "ts", "action", "amount"])
df["ts"] = pd.to_datetime(df["ts"])

df.head()
# Out:
#    id  user_id                  ts  action    amount
# 0   1      202 2025-06-02 13:45:00    sell   8183.65
# 1   2      204 2025-06-02 13:47:00    sell   7511.70
# 2   3      203 2025-06-02 10:03:00    sell  10647.87
# 3   4      204 2025-06-02 09:15:00     buy   9625.18
# 4   5      205 2025-06-02 10:27:00  profit   2152.95

# %%
query_permute_complex = """
SELECT *
FROM memory.default.trading_logs
MATCH_RECOGNIZE (
  PARTITION BY user_id
  ORDER BY ts
  PATTERN (BIGSELL SMALLPROFIT)
  DEFINE
    BIGSELL AS action = 'sell' AND amount > 12000,
    SMALLPROFIT AS action = 'profit' AND amount < 500
);



"""

print("- Testing complex pattern definitions")
output_df = match_recognize(query_permute_complex, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.trading_logs MATCH_RECOGNIZE ( PARTITION BY user_id ORDER BY ts PATTERN (BIGSELL SMALLPROFIT) DEFINE BIGSELL AS action = 'sell' AND amount > 12000, SMALLPROFIT AS action = 'profit' AND amount < 500 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['user_id'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='ts', ordering='ASC', nulls_ordering=None)])
# ...

# %%
print("Testing PERMUTE Patterns\n")
# Test 6: PERMUTE with Complex Conditions
query_permute_complex = """
SELECT *
FROM memory.default.trading_logs
MATCH_RECOGNIZE (
  PARTITION BY user_id
  ORDER BY ts
  PATTERN (BUY SELL PROFIT)
  DEFINE
    BUY AS action = 'buy',
    SELL AS action = 'sell',
    PROFIT AS action = 'profit'
);

"""

print("Test 6: PERMUTE with Complex Conditions - Testing complex pattern definitions")
output_df = match_recognize(query_permute_complex, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.trading_logs MATCH_RECOGNIZE ( PARTITION BY user_id ORDER BY ts PATTERN (BUY SELL PROFIT) DEFINE BUY AS action = 'buy', SELL AS action = 'sell', PROFIT AS action = 'profit' );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['user_id'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='ts', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['BUY', 'SELL', 'PROFIT'], 'base_variables': ['BUY', 'SELL', 'PROFIT']}
# ...

# %%
query_permute_complex = """
SELECT *
FROM memory.default.trading_logs
MATCH_RECOGNIZE (
  PARTITION BY user_id
  ORDER BY ts
  PATTERN (BIGSELL SMALLPROFIT)
  DEFINE
    BIGSELL AS action = 'sell' AND amount > 12000,
    SMALLPROFIT AS action = 'profit' AND amount < 500
);



"""

print("- Testing complex pattern definitions")
output_df = match_recognize(query_permute_complex, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.trading_logs MATCH_RECOGNIZE ( PARTITION BY user_id ORDER BY ts PATTERN (BIGSELL SMALLPROFIT) DEFINE BIGSELL AS action = 'sell' AND amount > 12000, SMALLPROFIT AS action = 'profit' AND amount < 500 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['user_id'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='ts', ordering='ASC', nulls_ordering=None)])
# ...

# %%
# Let's try a less restrictive pattern that should match some sequences
query_modified = """
SELECT *
FROM memory.default.trading_logs
MATCH_RECOGNIZE (
  PARTITION BY user_id
  ORDER BY ts
  PATTERN (BIGSELL ANYPROFIT)
  DEFINE
    BIGSELL AS action = 'sell' AND amount > 10000,
    ANYPROFIT AS action = 'profit'
);
"""

print("Testing modified pattern with less restrictive conditions")
output_df = match_recognize(query_modified, df)
print(output_df)
print("\n")
