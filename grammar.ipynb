# %%
# !python test_matcher.py
# Out:
# Running Pattern Matching Tests
# ==================================================
#
# Executing: Basic Pattern
# DEBUG:sql_parser:Raw measures content: FIRST(price) AS start_price,
#             LAST(price) AS end_price,
#             COUNT(*) AS pattern_length
# DEBUG:sql_parser:Added function measure: start_price = (FIRST, price)
# DEBUG:sql_parser:Added function measure: end_price = (LAST, price)
# DEBUG:sql_parser:Added COUNT(*) measure: pattern_length
# DEBUG:sql_parser:All parsed measures: {'start_price': ('FIRST', 'price'), 'end_price': ('LAST', 'price'), 'pattern_length': ('COUNT', '*')}
# DEBUG:sql_parser:Raw pattern: A+ B
# DEBUG:sql_parser:Parsed pattern: A+ B
# DEBUG:sql_parser:Raw define content: A AS price > PREV(price),
#             B AS price < PREV(price)
# DEBUG:sql_parser:Added condition for variable A: price > PREV(price)
# DEBUG:sql_parser:Added condition for variable B: price < PREV(price)
# DEBUG:sql_parser:Parsed conditions: {'A': 'price > PREV(price)', 'B': 'price < PREV(price)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=['ticker'], order_cols=['ts'], measures={'start_price': ('FIRST', 'price'), 'end_price': ('LAST', 'price'), 'pattern_length': ('COUNT', '*')}, pattern='A+ B', conditions={'A': 'price > PREV(price)', 'B': 'price < PREV(price)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={}, running_mode='RUNNING')
# DEBUG:execution_engine:Processing query:
#     SELECT *
#     FROM data
#     MATCH_RECOGNIZE (
#         PARTITION BY ticker
#         ORDER BY ts
#         MEASURES
#             FIRST(price) AS start_price,
#             LAST(price) AS end_price,
#             COUNT(*) AS pattern_length
#         PATTERN (A+ B)
#         DEFINE
#             A AS price > PREV(price),
#             B AS price < PREV(price)
#     );
#
# DEBUG:sql_parser:Raw measures content: FIRST(price) AS start_price,
#             LAST(price) AS end_price,
#             COUNT(*) AS pattern_length
# DEBUG:sql_parser:Added function measure: start_price = (FIRST, price)
# DEBUG:sql_parser:Added function measure: end_price = (LAST, price)
# DEBUG:sql_parser:Added COUNT(*) measure: pattern_length
# DEBUG:sql_parser:All parsed measures: {'start_price': ('FIRST', 'price'), 'end_price': ('LAST', 'price'), 'pattern_length': ('COUNT', '*')}
# DEBUG:sql_parser:Raw pattern: A+ B
# DEBUG:sql_parser:Parsed pattern: A+ B
# DEBUG:sql_parser:Raw define content: A AS price > PREV(price),
#             B AS price < PREV(price)
# DEBUG:sql_parser:Added condition for variable A: price > PREV(price)
# DEBUG:sql_parser:Added condition for variable B: price < PREV(price)
# DEBUG:sql_parser:Parsed conditions: {'A': 'price > PREV(price)', 'B': 'price < PREV(price)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=['ticker'], order_cols=['ts'], measures={'start_price': ('FIRST', 'price'), 'end_price': ('LAST', 'price'), 'pattern_length': ('COUNT', '*')}, pattern='A+ B', conditions={'A': 'price > PREV(price)', 'B': 'price < PREV(price)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={}, running_mode='RUNNING')
# DEBUG:nfa_matcher:Building NFA for pattern: A+ B
# DEBUG:nfa_matcher:Building NFA for pattern: A+ B
# DEBUG:nfa_matcher:First row {'ticker': 'AAPL', 'ts': '2024-01-01', 'price': 100} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'AAPL', 'ts': '2024-01-01', 'price': 100}: matched
# DEBUG:nfa_matcher:Comparing 110.0 > 100.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'AAPL', 'ts': '2024-01-02', 'price': 110}: matched
# DEBUG:nfa_matcher:Comparing 110.0 < 100.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'ticker': 'AAPL', 'ts': '2024-01-02', 'price': 110}: not matched
# DEBUG:nfa_matcher:Comparing 120.0 > 110.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'AAPL', 'ts': '2024-01-03', 'price': 120}: matched
# DEBUG:nfa_matcher:Comparing 120.0 < 110.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'ticker': 'AAPL', 'ts': '2024-01-03', 'price': 120}: not matched
# DEBUG:nfa_matcher:Comparing 115.0 > 120.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'AAPL', 'ts': '2024-01-04', 'price': 115}: not matched
# DEBUG:nfa_matcher:Comparing 115.0 < 120.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'ticker': 'AAPL', 'ts': '2024-01-04', 'price': 115}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=B, match_number=1
# DEBUG:nfa_matcher:Building NFA for pattern: A+ B
# DEBUG:nfa_matcher:Building NFA for pattern: A+ B
# DEBUG:nfa_matcher:First row {'ticker': 'GOOGL', 'ts': '2024-01-01', 'price': 500} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'GOOGL', 'ts': '2024-01-01', 'price': 500}: matched
# DEBUG:nfa_matcher:Comparing 520.0 > 500.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'GOOGL', 'ts': '2024-01-02', 'price': 520}: matched
# DEBUG:nfa_matcher:Comparing 520.0 < 500.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'ticker': 'GOOGL', 'ts': '2024-01-02', 'price': 520}: not matched
# DEBUG:nfa_matcher:Comparing 510.0 > 520.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'GOOGL', 'ts': '2024-01-03', 'price': 510}: not matched
# DEBUG:nfa_matcher:Comparing 510.0 < 520.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'ticker': 'GOOGL', 'ts': '2024-01-03', 'price': 510}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=B, match_number=3
# DEBUG:execution_engine:Output DataFrame columns: ['ticker', 'start_price', 'end_price', 'pattern_length']
# DEBUG:execution_engine:Performance stats: {'parse_time_ms': 1.4982223510742188, 'match_time_ms': 0.9763240814208984, 'total_rows': 7, 'matched_rows': 8, 'match_count': 2, 'rows_per_second': 3541.9292138399073}
#
# Basic pattern results:
#   ticker  start_price  end_price  pattern_length
# 0   AAPL          100        115               4
# 1  GOOGL          500        510               3
#
# Executing: Pattern Measures
# DEBUG:sql_parser:Raw measures content: FIRST(value) AS start_val,
#             LAST(value) AS end_val,
#             AVG(value) AS avg_val,
#             COUNT(*) AS pattern_length,
#             MATCH_NUMBER() AS match_num,
#             CLASSIFIER() AS pattern_type
# DEBUG:sql_parser:Added function measure: start_val = (FIRST, value)
# DEBUG:sql_parser:Added function measure: end_val = (LAST, value)
# DEBUG:sql_parser:Added function measure: avg_val = (AVG, value)
# DEBUG:sql_parser:Added COUNT(*) measure: pattern_length
# DEBUG:sql_parser:Added MATCH_NUMBER measure: match_num
# DEBUG:sql_parser:Added CLASSIFIER measure: pattern_type
# DEBUG:sql_parser:All parsed measures: {'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value'), 'avg_val': ('AVG', 'value'), 'pattern_length': ('COUNT', '*'), 'match_num': ('MATCH_NUMBER', '*'), 'pattern_type': ('CLASSIFIER', '*')}
# DEBUG:sql_parser:Raw pattern: A+ B?
# DEBUG:sql_parser:Parsed pattern: A+ B?
# DEBUG:sql_parser:Raw define content: A AS value >= PREV(value),
#             B AS value < PREV(value)
# DEBUG:sql_parser:Added condition for variable A: value >= PREV(value)
# DEBUG:sql_parser:Added condition for variable B: value < PREV(value)
# DEBUG:sql_parser:Parsed conditions: {'A': 'value >= PREV(value)', 'B': 'value < PREV(value)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=['group'], order_cols=['id'], measures={'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value'), 'avg_val': ('AVG', 'value'), 'pattern_length': ('COUNT', '*'), 'match_num': ('MATCH_NUMBER', '*'), 'pattern_type': ('CLASSIFIER', '*')}, pattern='A+ B?', conditions={'A': 'value >= PREV(value)', 'B': 'value < PREV(value)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={}, running_mode='RUNNING')
# DEBUG:execution_engine:Processing query:
#     SELECT *
#     FROM data
#     MATCH_RECOGNIZE (
#         PARTITION BY group
#         ORDER BY id
#         MEASURES
#             FIRST(value) AS start_val,
#             LAST(value) AS end_val,
#             AVG(value) AS avg_val,
#             COUNT(*) AS pattern_length,
#             MATCH_NUMBER() AS match_num,
#             CLASSIFIER() AS pattern_type
#         PATTERN (A+ B?)
#         DEFINE
#             A AS value >= PREV(value),
#             B AS value < PREV(value)
#     );
#
# DEBUG:sql_parser:Raw measures content: FIRST(value) AS start_val,
#             LAST(value) AS end_val,
#             AVG(value) AS avg_val,
#             COUNT(*) AS pattern_length,
#             MATCH_NUMBER() AS match_num,
#             CLASSIFIER() AS pattern_type
# DEBUG:sql_parser:Added function measure: start_val = (FIRST, value)
# DEBUG:sql_parser:Added function measure: end_val = (LAST, value)
# DEBUG:sql_parser:Added function measure: avg_val = (AVG, value)
# DEBUG:sql_parser:Added COUNT(*) measure: pattern_length
# DEBUG:sql_parser:Added MATCH_NUMBER measure: match_num
# DEBUG:sql_parser:Added CLASSIFIER measure: pattern_type
# DEBUG:sql_parser:All parsed measures: {'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value'), 'avg_val': ('AVG', 'value'), 'pattern_length': ('COUNT', '*'), 'match_num': ('MATCH_NUMBER', '*'), 'pattern_type': ('CLASSIFIER', '*')}
# DEBUG:sql_parser:Raw pattern: A+ B?
# DEBUG:sql_parser:Parsed pattern: A+ B?
# DEBUG:sql_parser:Raw define content: A AS value >= PREV(value),
#             B AS value < PREV(value)
# DEBUG:sql_parser:Added condition for variable A: value >= PREV(value)
# DEBUG:sql_parser:Added condition for variable B: value < PREV(value)
# DEBUG:sql_parser:Parsed conditions: {'A': 'value >= PREV(value)', 'B': 'value < PREV(value)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=['group'], order_cols=['id'], measures={'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value'), 'avg_val': ('AVG', 'value'), 'pattern_length': ('COUNT', '*'), 'match_num': ('MATCH_NUMBER', '*'), 'pattern_type': ('CLASSIFIER', '*')}, pattern='A+ B?', conditions={'A': 'value >= PREV(value)', 'B': 'value < PREV(value)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={}, running_mode='RUNNING')
# DEBUG:nfa_matcher:Building NFA for pattern: A+ B?
# DEBUG:nfa_matcher:Building NFA for pattern: A+ B?
# DEBUG:nfa_matcher:First row {'id': 1, 'value': 10, 'group': 'A'} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 1, 'value': 10, 'group': 'A'}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=A, match_number=1
# DEBUG:nfa_matcher:First row {'id': 2, 'value': 20, 'group': 'A'} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 2, 'value': 20, 'group': 'A'}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=A, match_number=2
# DEBUG:nfa_matcher:First row {'id': 3, 'value': 15, 'group': 'A'} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 3, 'value': 15, 'group': 'A'}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=A, match_number=3
# DEBUG:nfa_matcher:Building NFA for pattern: A+ B?
# DEBUG:nfa_matcher:Building NFA for pattern: A+ B?
# DEBUG:nfa_matcher:First row {'id': 4, 'value': 25, 'group': 'B'} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 4, 'value': 25, 'group': 'B'}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=A, match_number=7
# DEBUG:nfa_matcher:First row {'id': 5, 'value': 30, 'group': 'B'} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 5, 'value': 30, 'group': 'B'}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=A, match_number=8
# DEBUG:nfa_matcher:First row {'id': 6, 'value': 28, 'group': 'B'} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 6, 'value': 28, 'group': 'B'}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=A, match_number=9
# DEBUG:execution_engine:Output DataFrame columns: ['group', 'start_val', 'end_val', 'avg_val', 'pattern_length', 'match_num', 'pattern_type']
# DEBUG:execution_engine:Performance stats: {'parse_time_ms': 0.3371238708496094, 'match_time_ms': 0.6520748138427734, 'total_rows': 6, 'matched_rows': 42, 'match_count': 6, 'rows_per_second': 3631.796786517087}
#
# Pattern measures results:
#   group  start_val  end_val  avg_val  pattern_length  match_num pattern_type
# 0     A         10       10     10.0               1          4            A
# 1     A         20       20     20.0               1          5            A
# 2     A         15       15     15.0               1          6            A
# 3     B         25       25     25.0               1         10            A
# 4     B         30       30     30.0               1         11            A
# 5     B         28       28     28.0               1         12            A
#
# Executing: All Rows Output
# DEBUG:sql_parser:Raw measures content: RUNNING COUNT(*) AS row_num,
#             RUNNING AVG(val) AS running_avg,
#             FINAL MAX(val) AS max_val
# DEBUG:sql_parser:Added COUNT(*) measure: row_num
# DEBUG:sql_parser:Added function measure: running_avg = (RUNNING_AVG, val)
# DEBUG:sql_parser:Added function measure: max_val = (FINAL_MAX, val)
# DEBUG:sql_parser:All parsed measures: {'row_num': ('RUNNING_COUNT', '*'), 'running_avg': ('RUNNING_AVG', 'val'), 'max_val': ('FINAL_MAX', 'val')}
# DEBUG:sql_parser:Raw pattern: A+ B?
# DEBUG:sql_parser:Parsed pattern: A+ B?
# DEBUG:sql_parser:Raw define content: A AS val >= PREV(val),
#             B AS val < PREV(val)
# DEBUG:sql_parser:Added condition for variable A: val >= PREV(val)
# DEBUG:sql_parser:Added condition for variable B: val < PREV(val)
# DEBUG:sql_parser:Parsed conditions: {'A': 'val >= PREV(val)', 'B': 'val < PREV(val)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=[], order_cols=['seq\n        ALL ROWS PER MATCH'], measures={'row_num': ('RUNNING_COUNT', '*'), 'running_avg': ('RUNNING_AVG', 'val'), 'max_val': ('FINAL_MAX', 'val')}, pattern='A+ B?', conditions={'A': 'val >= PREV(val)', 'B': 'val < PREV(val)'}, row_per_match='ALL', after_match='SKIP PAST LAST ROW', subsets={}, running_mode='FINAL')
# DEBUG:execution_engine:Processing query:
#     SELECT *
#     FROM data
#     MATCH_RECOGNIZE (
#         ORDER BY seq
#         ALL ROWS PER MATCH
#         MEASURES
#             RUNNING COUNT(*) AS row_num,
#             RUNNING AVG(val) AS running_avg,
#             FINAL MAX(val) AS max_val
#         PATTERN (A+ B?)
#         DEFINE
#             A AS val >= PREV(val),
#             B AS val < PREV(val)
#     );
#
# DEBUG:sql_parser:Raw measures content: RUNNING COUNT(*) AS row_num,
#             RUNNING AVG(val) AS running_avg,
#             FINAL MAX(val) AS max_val
# DEBUG:sql_parser:Added COUNT(*) measure: row_num
# DEBUG:sql_parser:Added function measure: running_avg = (RUNNING_AVG, val)
# DEBUG:sql_parser:Added function measure: max_val = (FINAL_MAX, val)
# DEBUG:sql_parser:All parsed measures: {'row_num': ('RUNNING_COUNT', '*'), 'running_avg': ('RUNNING_AVG', 'val'), 'max_val': ('FINAL_MAX', 'val')}
# DEBUG:sql_parser:Raw pattern: A+ B?
# DEBUG:sql_parser:Parsed pattern: A+ B?
# DEBUG:sql_parser:Raw define content: A AS val >= PREV(val),
#             B AS val < PREV(val)
# DEBUG:sql_parser:Added condition for variable A: val >= PREV(val)
# DEBUG:sql_parser:Added condition for variable B: val < PREV(val)
# DEBUG:sql_parser:Parsed conditions: {'A': 'val >= PREV(val)', 'B': 'val < PREV(val)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=[], order_cols=['seq\n        ALL ROWS PER MATCH'], measures={'row_num': ('RUNNING_COUNT', '*'), 'running_avg': ('RUNNING_AVG', 'val'), 'max_val': ('FINAL_MAX', 'val')}, pattern='A+ B?', conditions={'A': 'val >= PREV(val)', 'B': 'val < PREV(val)'}, row_per_match='ALL', after_match='SKIP PAST LAST ROW', subsets={}, running_mode='FINAL')
# DEBUG:nfa_matcher:Building NFA for pattern: A+ B?
# DEBUG:nfa_matcher:Building NFA for pattern: A+ B?
# DEBUG:nfa_matcher:First row {'seq': 1, 'val': 100} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'seq': 1, 'val': 100}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=A, match_number=1
# DEBUG:nfa_matcher:First row {'seq': 2, 'val': 110} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'seq': 2, 'val': 110}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=A, match_number=2
# DEBUG:nfa_matcher:First row {'seq': 3, 'val': 120} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'seq': 3, 'val': 120}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=A, match_number=3
# DEBUG:nfa_matcher:First row {'seq': 4, 'val': 115} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'seq': 4, 'val': 115}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=A, match_number=4
# DEBUG:nfa_matcher:First row {'seq': 5, 'val': 125} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'seq': 5, 'val': 125}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=A, match_number=5
# DEBUG:execution_engine:Output DataFrame columns: ['seq', 'val', 'row_num', 'running_avg', 'max_val']
# DEBUG:execution_engine:Performance stats: {'parse_time_ms': 0.24557113647460938, 'match_time_ms': 0.6046295166015625, 'total_rows': 5, 'matched_rows': 25, 'match_count': 5, 'rows_per_second': 3115.984062532688}
#
# All rows output results:
#    seq  val  row_num  running_avg  max_val
# 0    1  100        1        100.0    100.0
# 1    2  110        1        110.0    110.0
# 2    3  120        1        120.0    120.0
# 3    4  115        1        115.0    115.0
# 4    5  125        1        125.0    125.0
#
# Executing: Subset Pattern
# DEBUG:sql_parser:Raw measures content: FIRST(price) AS start_price,
#             LAST(price) AS end_price,
#             MAX(volume) AS max_volume
# DEBUG:sql_parser:Added function measure: start_price = (FIRST, price)
# DEBUG:sql_parser:Added function measure: end_price = (LAST, price)
# DEBUG:sql_parser:Added function measure: max_volume = (MAX, volume)
# DEBUG:sql_parser:All parsed measures: {'start_price': ('FIRST', 'price'), 'end_price': ('LAST', 'price'), 'max_volume': ('MAX', 'volume')}
# DEBUG:sql_parser:Raw pattern: PRICE_MOVE+
# DEBUG:sql_parser:Parsed pattern: PRICE_MOVE+
# DEBUG:sql_parser:Raw define content: UP AS price > PREV(price),
#             DOWN AS price < PREV(price)
# DEBUG:sql_parser:Added condition for variable UP: price > PREV(price)
# DEBUG:sql_parser:Added condition for variable DOWN: price < PREV(price)
# DEBUG:sql_parser:Parsed conditions: {'UP': 'price > PREV(price)', 'DOWN': 'price < PREV(price)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=[], order_cols=['ts'], measures={'start_price': ('FIRST', 'price'), 'end_price': ('LAST', 'price'), 'max_volume': ('MAX', 'volume')}, pattern='PRICE_MOVE+', conditions={'UP': 'price > PREV(price)', 'DOWN': 'price < PREV(price)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={'PRICE_MOVE': {'DOWN', '(UP'}}, running_mode='RUNNING')
# DEBUG:execution_engine:Processing query:
#     SELECT *
#     FROM data
#     MATCH_RECOGNIZE (
#         ORDER BY ts
#         MEASURES
#             FIRST(price) AS start_price,
#             LAST(price) AS end_price,
#             MAX(volume) AS max_volume
#         SUBSET PRICE_MOVE = (UP DOWN)
#         PATTERN (PRICE_MOVE+)
#         DEFINE
#             UP AS price > PREV(price),
#             DOWN AS price < PREV(price)
#     );
#
# DEBUG:sql_parser:Raw measures content: FIRST(price) AS start_price,
#             LAST(price) AS end_price,
#             MAX(volume) AS max_volume
# DEBUG:sql_parser:Added function measure: start_price = (FIRST, price)
# DEBUG:sql_parser:Added function measure: end_price = (LAST, price)
# DEBUG:sql_parser:Added function measure: max_volume = (MAX, volume)
# DEBUG:sql_parser:All parsed measures: {'start_price': ('FIRST', 'price'), 'end_price': ('LAST', 'price'), 'max_volume': ('MAX', 'volume')}
# DEBUG:sql_parser:Raw pattern: PRICE_MOVE+
# DEBUG:sql_parser:Parsed pattern: PRICE_MOVE+
# DEBUG:sql_parser:Raw define content: UP AS price > PREV(price),
#             DOWN AS price < PREV(price)
# DEBUG:sql_parser:Added condition for variable UP: price > PREV(price)
# DEBUG:sql_parser:Added condition for variable DOWN: price < PREV(price)
# DEBUG:sql_parser:Parsed conditions: {'UP': 'price > PREV(price)', 'DOWN': 'price < PREV(price)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=[], order_cols=['ts'], measures={'start_price': ('FIRST', 'price'), 'end_price': ('LAST', 'price'), 'max_volume': ('MAX', 'volume')}, pattern='PRICE_MOVE+', conditions={'UP': 'price > PREV(price)', 'DOWN': 'price < PREV(price)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={'PRICE_MOVE': {'DOWN', '(UP'}}, running_mode='RUNNING')
# DEBUG:nfa_matcher:Building NFA for pattern: PRICE_MOVE+
# DEBUG:nfa_matcher:Building NFA for pattern: PRICE_MOVE+
# DEBUG:nfa_matcher:Testing variable PRICE_MOVE for row {'ts': '2024-01-01', 'price': 100, 'volume': 1000}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=PRICE_MOVE, match_number=1
# DEBUG:nfa_matcher:Testing variable PRICE_MOVE for row {'ts': '2024-01-02', 'price': 110, 'volume': 1200}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=PRICE_MOVE, match_number=2
# DEBUG:nfa_matcher:Testing variable PRICE_MOVE for row {'ts': '2024-01-03', 'price': 105, 'volume': 800}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=PRICE_MOVE, match_number=3
# DEBUG:nfa_matcher:Testing variable PRICE_MOVE for row {'ts': '2024-01-04', 'price': 115, 'volume': 1500}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=PRICE_MOVE, match_number=4
# DEBUG:execution_engine:Output DataFrame columns: ['start_price', 'end_price', 'max_volume']
# DEBUG:execution_engine:Performance stats: {'parse_time_ms': 0.2682209014892578, 'match_time_ms': 0.4227161407470703, 'total_rows': 4, 'matched_rows': 12, 'match_count': 4, 'rows_per_second': 2811.5235959153415}
#
# Subset pattern results:
#    start_price  end_price  max_volume
# 0          100        100      1000.0
# 1          110        110      1200.0
# 2          105        105       800.0
# 3          115        115      1500.0
#
# Executing: Comprehensive Features
# DEBUG:sql_parser:Raw measures content: FIRST(price) AS start_price,
#             LAST(A.price) AS bottom_price,
#             LAST(price) AS end_price,
#             COUNT(*) AS pattern_length,
#             CLASSIFIER() AS pattern_var,
#             MATCH_NUMBER() AS match_num,
#             RUNNING AVG(volume) AS avg_volume,
#             FINAL MAX(volume) AS max_volume
# DEBUG:sql_parser:Added function measure: start_price = (FIRST, price)
# DEBUG:sql_parser:Added pattern variable measure: bottom_price = (LAST, A.price)
# DEBUG:sql_parser:Added function measure: end_price = (LAST, price)
# DEBUG:sql_parser:Added COUNT(*) measure: pattern_length
# DEBUG:sql_parser:Added CLASSIFIER measure: pattern_var
# DEBUG:sql_parser:Added MATCH_NUMBER measure: match_num
# DEBUG:sql_parser:Added function measure: avg_volume = (RUNNING_AVG, volume)
# DEBUG:sql_parser:Added function measure: max_volume = (FINAL_MAX, volume)
# DEBUG:sql_parser:All parsed measures: {'start_price': ('FIRST', 'price'), 'bottom_price': ('LAST', 'A.price'), 'end_price': ('LAST', 'price'), 'pattern_length': ('COUNT', '*'), 'pattern_var': ('CLASSIFIER', '*'), 'match_num': ('MATCH_NUMBER', '*'), 'avg_volume': ('RUNNING_AVG', 'volume'), 'max_volume': ('FINAL_MAX', 'volume')}
# DEBUG:sql_parser:Raw pattern: A+ (B | C) D?
# DEBUG:sql_parser:Parsed pattern: A+ (B | C) D?
# DEBUG:sql_parser:Raw define content: A AS price < PREV(price),
#             B AS price > PREV(price),
#             C AS price = PREV(price),
#             D AS price > PREV(price)
# DEBUG:sql_parser:Added condition for variable A: price < PREV(price)
# DEBUG:sql_parser:Added condition for variable B: price > PREV(price)
# DEBUG:sql_parser:Added condition for variable C: price = PREV(price)
# DEBUG:sql_parser:Added condition for variable D: price > PREV(price)
# DEBUG:sql_parser:Parsed conditions: {'A': 'price < PREV(price)', 'B': 'price > PREV(price)', 'C': 'price = PREV(price)', 'D': 'price > PREV(price)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=['ticker'], order_cols=['ts'], measures={'start_price': ('FIRST', 'price'), 'bottom_price': ('LAST', 'A.price'), 'end_price': ('LAST', 'price'), 'pattern_length': ('COUNT', '*'), 'pattern_var': ('CLASSIFIER', '*'), 'match_num': ('MATCH_NUMBER', '*'), 'avg_volume': ('RUNNING_AVG', 'volume'), 'max_volume': ('FINAL_MAX', 'volume')}, pattern='A+ (B | C) D?', conditions={'A': 'price < PREV(price)', 'B': 'price > PREV(price)', 'C': 'price = PREV(price)', 'D': 'price > PREV(price)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={'PRICE_TREND': {'(B'}}, running_mode='FINAL')
# DEBUG:execution_engine:Processing query:
#     SELECT *
#     FROM data
#     MATCH_RECOGNIZE (
#         PARTITION BY ticker
#         ORDER BY ts
#         MEASURES
#             FIRST(price) AS start_price,
#             LAST(A.price) AS bottom_price,
#             LAST(price) AS end_price,
#             COUNT(*) AS pattern_length,
#             CLASSIFIER() AS pattern_var,
#             MATCH_NUMBER() AS match_num,
#             RUNNING AVG(volume) AS avg_volume,
#             FINAL MAX(volume) AS max_volume
#         ONE ROW PER MATCH
#         PATTERN (A+ (B | C) D?)
#         SUBSET PRICE_TREND = (B, C)
#         DEFINE
#             A AS price < PREV(price),
#             B AS price > PREV(price),
#             C AS price = PREV(price),
#             D AS price > PREV(price)
#     );
#
# DEBUG:sql_parser:Raw measures content: FIRST(price) AS start_price,
#             LAST(A.price) AS bottom_price,
#             LAST(price) AS end_price,
#             COUNT(*) AS pattern_length,
#             CLASSIFIER() AS pattern_var,
#             MATCH_NUMBER() AS match_num,
#             RUNNING AVG(volume) AS avg_volume,
#             FINAL MAX(volume) AS max_volume
# DEBUG:sql_parser:Added function measure: start_price = (FIRST, price)
# DEBUG:sql_parser:Added pattern variable measure: bottom_price = (LAST, A.price)
# DEBUG:sql_parser:Added function measure: end_price = (LAST, price)
# DEBUG:sql_parser:Added COUNT(*) measure: pattern_length
# DEBUG:sql_parser:Added CLASSIFIER measure: pattern_var
# DEBUG:sql_parser:Added MATCH_NUMBER measure: match_num
# DEBUG:sql_parser:Added function measure: avg_volume = (RUNNING_AVG, volume)
# DEBUG:sql_parser:Added function measure: max_volume = (FINAL_MAX, volume)
# DEBUG:sql_parser:All parsed measures: {'start_price': ('FIRST', 'price'), 'bottom_price': ('LAST', 'A.price'), 'end_price': ('LAST', 'price'), 'pattern_length': ('COUNT', '*'), 'pattern_var': ('CLASSIFIER', '*'), 'match_num': ('MATCH_NUMBER', '*'), 'avg_volume': ('RUNNING_AVG', 'volume'), 'max_volume': ('FINAL_MAX', 'volume')}
# DEBUG:sql_parser:Raw pattern: A+ (B | C) D?
# DEBUG:sql_parser:Parsed pattern: A+ (B | C) D?
# DEBUG:sql_parser:Raw define content: A AS price < PREV(price),
#             B AS price > PREV(price),
#             C AS price = PREV(price),
#             D AS price > PREV(price)
# DEBUG:sql_parser:Added condition for variable A: price < PREV(price)
# DEBUG:sql_parser:Added condition for variable B: price > PREV(price)
# DEBUG:sql_parser:Added condition for variable C: price = PREV(price)
# DEBUG:sql_parser:Added condition for variable D: price > PREV(price)
# DEBUG:sql_parser:Parsed conditions: {'A': 'price < PREV(price)', 'B': 'price > PREV(price)', 'C': 'price = PREV(price)', 'D': 'price > PREV(price)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=['ticker'], order_cols=['ts'], measures={'start_price': ('FIRST', 'price'), 'bottom_price': ('LAST', 'A.price'), 'end_price': ('LAST', 'price'), 'pattern_length': ('COUNT', '*'), 'pattern_var': ('CLASSIFIER', '*'), 'match_num': ('MATCH_NUMBER', '*'), 'avg_volume': ('RUNNING_AVG', 'volume'), 'max_volume': ('FINAL_MAX', 'volume')}, pattern='A+ (B | C) D?', conditions={'A': 'price < PREV(price)', 'B': 'price > PREV(price)', 'C': 'price = PREV(price)', 'D': 'price > PREV(price)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={'PRICE_TREND': {'(B'}}, running_mode='FINAL')
# DEBUG:nfa_matcher:Building NFA for pattern: A+ (B | C) D?
# DEBUG:nfa_matcher:Building NFA for pattern: A+ (B | C) D?
# DEBUG:nfa_matcher:First row {'ticker': 'AAPL', 'ts': '2024-01-01', 'price': 100, 'volume': 1000} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'AAPL', 'ts': '2024-01-01', 'price': 100, 'volume': 1000}: matched
# DEBUG:nfa_matcher:Comparing 95.0 < 100.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'AAPL', 'ts': '2024-01-02', 'price': 95, 'volume': 1100}: matched
# DEBUG:nfa_matcher:Testing variable (B for row {'ticker': 'AAPL', 'ts': '2024-01-02', 'price': 95, 'volume': 1100}: matched
# DEBUG:nfa_matcher:Comparing 90.0 < 95.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'AAPL', 'ts': '2024-01-03', 'price': 90, 'volume': 1200}: matched
# DEBUG:nfa_matcher:Testing variable (B for row {'ticker': 'AAPL', 'ts': '2024-01-03', 'price': 90, 'volume': 1200}: matched
# DEBUG:nfa_matcher:Testing variable | for row {'ticker': 'AAPL', 'ts': '2024-01-03', 'price': 90, 'volume': 1200}: matched
# DEBUG:nfa_matcher:Comparing 92.0 < 90.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'AAPL', 'ts': '2024-01-04', 'price': 92, 'volume': 1300}: not matched
# DEBUG:nfa_matcher:Testing variable (B for row {'ticker': 'AAPL', 'ts': '2024-01-04', 'price': 92, 'volume': 1300}: matched
# DEBUG:nfa_matcher:Testing variable | for row {'ticker': 'AAPL', 'ts': '2024-01-04', 'price': 92, 'volume': 1300}: matched
# DEBUG:nfa_matcher:Testing variable C) for row {'ticker': 'AAPL', 'ts': '2024-01-04', 'price': 92, 'volume': 1300}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=C), match_number=1
# DEBUG:nfa_matcher:First row {'ticker': 'AAPL', 'ts': '2024-01-05', 'price': 98, 'volume': 1400} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'AAPL', 'ts': '2024-01-05', 'price': 98, 'volume': 1400}: matched
# DEBUG:nfa_matcher:Building NFA for pattern: A+ (B | C) D?
# DEBUG:nfa_matcher:Building NFA for pattern: A+ (B | C) D?
# DEBUG:nfa_matcher:First row {'ticker': 'GOOGL', 'ts': '2024-01-01', 'price': 500, 'volume': 2000} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'GOOGL', 'ts': '2024-01-01', 'price': 500, 'volume': 2000}: matched
# DEBUG:nfa_matcher:Comparing 480.0 < 500.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'GOOGL', 'ts': '2024-01-02', 'price': 480, 'volume': 2100}: matched
# DEBUG:nfa_matcher:Testing variable (B for row {'ticker': 'GOOGL', 'ts': '2024-01-02', 'price': 480, 'volume': 2100}: matched
# DEBUG:nfa_matcher:Comparing 470.0 < 480.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'GOOGL', 'ts': '2024-01-03', 'price': 470, 'volume': 2200}: matched
# DEBUG:nfa_matcher:Testing variable (B for row {'ticker': 'GOOGL', 'ts': '2024-01-03', 'price': 470, 'volume': 2200}: matched
# DEBUG:nfa_matcher:Testing variable | for row {'ticker': 'GOOGL', 'ts': '2024-01-03', 'price': 470, 'volume': 2200}: matched
# DEBUG:nfa_matcher:Comparing 485.0 < 470.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'GOOGL', 'ts': '2024-01-04', 'price': 485, 'volume': 2300}: not matched
# DEBUG:nfa_matcher:Testing variable (B for row {'ticker': 'GOOGL', 'ts': '2024-01-04', 'price': 485, 'volume': 2300}: matched
# DEBUG:nfa_matcher:Testing variable C) for row {'ticker': 'GOOGL', 'ts': '2024-01-04', 'price': 485, 'volume': 2300}: matched
# DEBUG:nfa_matcher:Testing variable | for row {'ticker': 'GOOGL', 'ts': '2024-01-04', 'price': 485, 'volume': 2300}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=|, match_number=3
# DEBUG:nfa_matcher:First row {'ticker': 'GOOGL', 'ts': '2024-01-05', 'price': 510, 'volume': 2400} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'GOOGL', 'ts': '2024-01-05', 'price': 510, 'volume': 2400}: matched
# DEBUG:execution_engine:Output DataFrame columns: ['ticker', 'start_price', 'bottom_price', 'end_price', 'pattern_length', 'pattern_var', 'match_num', 'avg_volume', 'max_volume']
# DEBUG:execution_engine:Performance stats: {'parse_time_ms': 0.4305839538574219, 'match_time_ms': 1.0745525360107422, 'total_rows': 10, 'matched_rows': 18, 'match_count': 2, 'rows_per_second': 4820.316587031093}
#
# Comprehensive Feature Test Results:
#   ticker  start_price  bottom_price  ...  match_num  avg_volume max_volume
# 0   AAPL          100            90  ...          2      1150.0     1300.0
# 1  GOOGL          500           470  ...          4      2150.0     2300.0
#
# [2 rows x 9 columns]
#
# Feature Verification:
# Partition: ✓
# Measures: ✓
# Running/Final: ✓
# Pattern: ✓
# All Rows: ✓
#
# Executing: Empty Partition
# DEBUG:sql_parser:Raw measures content: FIRST(value) AS start_val,
#             LAST(value) AS end_val
# DEBUG:sql_parser:Added function measure: start_val = (FIRST, value)
# DEBUG:sql_parser:Added function measure: end_val = (LAST, value)
# DEBUG:sql_parser:All parsed measures: {'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value')}
# DEBUG:sql_parser:Raw pattern: A+ B?
# DEBUG:sql_parser:Parsed pattern: A+ B?
# DEBUG:sql_parser:Raw define content: A AS value >= PREV(value),
#             B AS value < PREV(value)
# DEBUG:sql_parser:Added condition for variable A: value >= PREV(value)
# DEBUG:sql_parser:Added condition for variable B: value < PREV(value)
# DEBUG:sql_parser:Parsed conditions: {'A': 'value >= PREV(value)', 'B': 'value < PREV(value)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=['group'], order_cols=['id'], measures={'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value')}, pattern='A+ B?', conditions={'A': 'value >= PREV(value)', 'B': 'value < PREV(value)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={}, running_mode='RUNNING')
# DEBUG:execution_engine:Processing query:
#     SELECT *
#     FROM data
#     MATCH_RECOGNIZE (
#         PARTITION BY group
#         ORDER BY id
#         MEASURES
#             FIRST(value) AS start_val,
#             LAST(value) AS end_val
#         PATTERN (A+ B?)
#         DEFINE
#             A AS value >= PREV(value),
#             B AS value < PREV(value)
#     );
#
# DEBUG:sql_parser:Raw measures content: FIRST(value) AS start_val,
#             LAST(value) AS end_val
# DEBUG:sql_parser:Added function measure: start_val = (FIRST, value)
# DEBUG:sql_parser:Added function measure: end_val = (LAST, value)
# DEBUG:sql_parser:All parsed measures: {'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value')}
# DEBUG:sql_parser:Raw pattern: A+ B?
# DEBUG:sql_parser:Parsed pattern: A+ B?
# DEBUG:sql_parser:Raw define content: A AS value >= PREV(value),
#             B AS value < PREV(value)
# DEBUG:sql_parser:Added condition for variable A: value >= PREV(value)
# DEBUG:sql_parser:Added condition for variable B: value < PREV(value)
# DEBUG:sql_parser:Parsed conditions: {'A': 'value >= PREV(value)', 'B': 'value < PREV(value)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=['group'], order_cols=['id'], measures={'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value')}, pattern='A+ B?', conditions={'A': 'value >= PREV(value)', 'B': 'value < PREV(value)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={}, running_mode='RUNNING')
# WARNING:execution_engine:No matches found for pattern
#
# Empty partition results:
# Empty DataFrame
# Columns: []
# Index: []
#
# Executing: Single Row Partition
# DEBUG:sql_parser:Raw measures content: FIRST(value) AS start_val,
#             LAST(value) AS end_val
# DEBUG:sql_parser:Added function measure: start_val = (FIRST, value)
# DEBUG:sql_parser:Added function measure: end_val = (LAST, value)
# DEBUG:sql_parser:All parsed measures: {'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value')}
# DEBUG:sql_parser:Raw pattern: A
# DEBUG:sql_parser:Parsed pattern: A
# DEBUG:sql_parser:Raw define content: A AS value >= PREV(value)
# DEBUG:sql_parser:Added condition for variable A: value >= PREV(value)
# DEBUG:sql_parser:Parsed conditions: {'A': 'value >= PREV(value)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=['group'], order_cols=['id'], measures={'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value')}, pattern='A', conditions={'A': 'value >= PREV(value)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={}, running_mode='RUNNING')
# DEBUG:execution_engine:Processing query:
#     SELECT *
#     FROM data
#     MATCH_RECOGNIZE (
#         PARTITION BY group
#         ORDER BY id
#         MEASURES
#             FIRST(value) AS start_val,
#             LAST(value) AS end_val
#         PATTERN (A)
#         DEFINE
#             A AS value >= PREV(value)
#     );
#
# DEBUG:sql_parser:Raw measures content: FIRST(value) AS start_val,
#             LAST(value) AS end_val
# DEBUG:sql_parser:Added function measure: start_val = (FIRST, value)
# DEBUG:sql_parser:Added function measure: end_val = (LAST, value)
# DEBUG:sql_parser:All parsed measures: {'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value')}
# DEBUG:sql_parser:Raw pattern: A
# DEBUG:sql_parser:Parsed pattern: A
# DEBUG:sql_parser:Raw define content: A AS value >= PREV(value)
# DEBUG:sql_parser:Added condition for variable A: value >= PREV(value)
# DEBUG:sql_parser:Parsed conditions: {'A': 'value >= PREV(value)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=['group'], order_cols=['id'], measures={'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value')}, pattern='A', conditions={'A': 'value >= PREV(value)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={}, running_mode='RUNNING')
# DEBUG:nfa_matcher:Building NFA for pattern: A
# DEBUG:nfa_matcher:Building NFA for pattern: A
# DEBUG:nfa_matcher:First row {'group': 'A', 'id': 1, 'value': 10} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'group': 'A', 'id': 1, 'value': 10}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=A, match_number=1
# DEBUG:execution_engine:Output DataFrame columns: ['group', 'start_val', 'end_val']
# DEBUG:execution_engine:Performance stats: {'parse_time_ms': 0.1862049102783203, 'match_time_ms': 0.2970695495605469, 'total_rows': 1, 'matched_rows': 3, 'match_count': 1, 'rows_per_second': 770.968681161935}
#
# Single row partition results:
#   group  start_val  end_val
# 0     A         10       10
#
# Executing: No Matches
# DEBUG:sql_parser:Raw measures content: FIRST(value) AS start_val,
#             LAST(value) AS end_val
# DEBUG:sql_parser:Added function measure: start_val = (FIRST, value)
# DEBUG:sql_parser:Added function measure: end_val = (LAST, value)
# DEBUG:sql_parser:All parsed measures: {'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value')}
# DEBUG:sql_parser:Raw pattern: A+ B+
# DEBUG:sql_parser:Parsed pattern: A+ B+
# DEBUG:sql_parser:Raw define content: A AS value > PREV(value),
#             B AS value > PREV(value)
# DEBUG:sql_parser:Added condition for variable A: value > PREV(value)
# DEBUG:sql_parser:Added condition for variable B: value > PREV(value)
# DEBUG:sql_parser:Parsed conditions: {'A': 'value > PREV(value)', 'B': 'value > PREV(value)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=[], order_cols=['id'], measures={'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value')}, pattern='A+ B+', conditions={'A': 'value > PREV(value)', 'B': 'value > PREV(value)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={}, running_mode='RUNNING')
# DEBUG:execution_engine:Processing query:
#     SELECT *
#     FROM data
#     MATCH_RECOGNIZE (
#         ORDER BY id
#         MEASURES
#             FIRST(value) AS start_val,
#             LAST(value) AS end_val
#         PATTERN (A+ B+)
#         DEFINE
#             A AS value > PREV(value),
#             B AS value > PREV(value)
#     );
#
# DEBUG:sql_parser:Raw measures content: FIRST(value) AS start_val,
#             LAST(value) AS end_val
# DEBUG:sql_parser:Added function measure: start_val = (FIRST, value)
# DEBUG:sql_parser:Added function measure: end_val = (LAST, value)
# DEBUG:sql_parser:All parsed measures: {'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value')}
# DEBUG:sql_parser:Raw pattern: A+ B+
# DEBUG:sql_parser:Parsed pattern: A+ B+
# DEBUG:sql_parser:Raw define content: A AS value > PREV(value),
#             B AS value > PREV(value)
# DEBUG:sql_parser:Added condition for variable A: value > PREV(value)
# DEBUG:sql_parser:Added condition for variable B: value > PREV(value)
# DEBUG:sql_parser:Parsed conditions: {'A': 'value > PREV(value)', 'B': 'value > PREV(value)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=[], order_cols=['id'], measures={'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value')}, pattern='A+ B+', conditions={'A': 'value > PREV(value)', 'B': 'value > PREV(value)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={}, running_mode='RUNNING')
# DEBUG:nfa_matcher:Building NFA for pattern: A+ B+
# DEBUG:nfa_matcher:Building NFA for pattern: A+ B+
# DEBUG:nfa_matcher:First row {'id': 1, 'value': 10} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 1, 'value': 10}: matched
# DEBUG:nfa_matcher:Comparing 8.0 > 10.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 2, 'value': 8}: not matched
# DEBUG:nfa_matcher:Comparing 8.0 > 10.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 2, 'value': 8}: not matched
# WARNING:execution_engine:No matches found for pattern
#
# No matches results:
# Empty DataFrame
# Columns: []
# Index: []
#
# Executing: Complex Pattern
# DEBUG:sql_parser:Raw measures content: FIRST(value) AS start_val,
#             LAST(value) AS end_val,
#             CLASSIFIER() AS pattern_type
# DEBUG:sql_parser:Added function measure: start_val = (FIRST, value)
# DEBUG:sql_parser:Added function measure: end_val = (LAST, value)
# DEBUG:sql_parser:Added CLASSIFIER measure: pattern_type
# DEBUG:sql_parser:All parsed measures: {'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value'), 'pattern_type': ('CLASSIFIER', '*')}
# DEBUG:sql_parser:Raw pattern: A+ (B | C)+ D?
# DEBUG:sql_parser:Parsed pattern: A+ (B | C)+ D?
# DEBUG:sql_parser:Raw define content: A AS value > PREV(value),
#             B AS value = PREV(value),
#             C AS value < PREV(value),
#             D AS value > PREV(value)
# DEBUG:sql_parser:Added condition for variable A: value > PREV(value)
# DEBUG:sql_parser:Added condition for variable B: value = PREV(value)
# DEBUG:sql_parser:Added condition for variable C: value < PREV(value)
# DEBUG:sql_parser:Added condition for variable D: value > PREV(value)
# DEBUG:sql_parser:Parsed conditions: {'A': 'value > PREV(value)', 'B': 'value = PREV(value)', 'C': 'value < PREV(value)', 'D': 'value > PREV(value)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=[], order_cols=['id'], measures={'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value'), 'pattern_type': ('CLASSIFIER', '*')}, pattern='A+ (B | C)+ D?', conditions={'A': 'value > PREV(value)', 'B': 'value = PREV(value)', 'C': 'value < PREV(value)', 'D': 'value > PREV(value)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={}, running_mode='RUNNING')
# DEBUG:execution_engine:Processing query:
#     SELECT *
#     FROM data
#     MATCH_RECOGNIZE (
#         ORDER BY id
#         MEASURES
#             FIRST(value) AS start_val,
#             LAST(value) AS end_val,
#             CLASSIFIER() AS pattern_type
#         PATTERN (A+ (B | C)+ D?)
#         DEFINE
#             A AS value > PREV(value),
#             B AS value = PREV(value),
#             C AS value < PREV(value),
#             D AS value > PREV(value)
#     );
#
# DEBUG:sql_parser:Raw measures content: FIRST(value) AS start_val,
#             LAST(value) AS end_val,
#             CLASSIFIER() AS pattern_type
# DEBUG:sql_parser:Added function measure: start_val = (FIRST, value)
# DEBUG:sql_parser:Added function measure: end_val = (LAST, value)
# DEBUG:sql_parser:Added CLASSIFIER measure: pattern_type
# DEBUG:sql_parser:All parsed measures: {'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value'), 'pattern_type': ('CLASSIFIER', '*')}
# DEBUG:sql_parser:Raw pattern: A+ (B | C)+ D?
# DEBUG:sql_parser:Parsed pattern: A+ (B | C)+ D?
# DEBUG:sql_parser:Raw define content: A AS value > PREV(value),
#             B AS value = PREV(value),
#             C AS value < PREV(value),
#             D AS value > PREV(value)
# DEBUG:sql_parser:Added condition for variable A: value > PREV(value)
# DEBUG:sql_parser:Added condition for variable B: value = PREV(value)
# DEBUG:sql_parser:Added condition for variable C: value < PREV(value)
# DEBUG:sql_parser:Added condition for variable D: value > PREV(value)
# DEBUG:sql_parser:Parsed conditions: {'A': 'value > PREV(value)', 'B': 'value = PREV(value)', 'C': 'value < PREV(value)', 'D': 'value > PREV(value)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=[], order_cols=['id'], measures={'start_val': ('FIRST', 'value'), 'end_val': ('LAST', 'value'), 'pattern_type': ('CLASSIFIER', '*')}, pattern='A+ (B | C)+ D?', conditions={'A': 'value > PREV(value)', 'B': 'value = PREV(value)', 'C': 'value < PREV(value)', 'D': 'value > PREV(value)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={}, running_mode='RUNNING')
# DEBUG:nfa_matcher:Building NFA for pattern: A+ (B | C)+ D?
# DEBUG:nfa_matcher:Building NFA for pattern: A+ (B | C)+ D?
# DEBUG:nfa_matcher:First row {'id': 1, 'value': 10} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 1, 'value': 10}: matched
# DEBUG:nfa_matcher:Comparing 12.0 > 10.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 2, 'value': 12}: matched
# DEBUG:nfa_matcher:Testing variable (B for row {'id': 2, 'value': 12}: matched
# DEBUG:nfa_matcher:Comparing 12.0 > 12.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 3, 'value': 12}: not matched
# DEBUG:nfa_matcher:Testing variable (B for row {'id': 3, 'value': 12}: matched
# DEBUG:nfa_matcher:Testing variable | for row {'id': 3, 'value': 12}: matched
# DEBUG:nfa_matcher:Testing variable | for row {'id': 4, 'value': 11}: matched
# DEBUG:nfa_matcher:Testing variable C) for row {'id': 4, 'value': 11}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=C), match_number=1
# DEBUG:nfa_matcher:First row {'id': 5, 'value': 13} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 5, 'value': 13}: matched
# DEBUG:execution_engine:Output DataFrame columns: ['start_val', 'end_val', 'pattern_type']
# DEBUG:execution_engine:Performance stats: {'parse_time_ms': 0.37217140197753906, 'match_time_ms': 0.5130767822265625, 'total_rows': 5, 'matched_rows': 3, 'match_count': 1, 'rows_per_second': 3304.5249644517503}
#
# Complex pattern results:
#    start_val  end_val pattern_type
# 0         10       11            A
#
# Executing: After Match Skip
# DEBUG:sql_parser:Raw measures content: FIRST(id) AS start_id,
#             LAST(id) AS end_id,
#             COUNT(*) AS pattern_length
# DEBUG:sql_parser:Added function measure: start_id = (FIRST, id)
# DEBUG:sql_parser:Added function measure: end_id = (LAST, id)
# DEBUG:sql_parser:Added COUNT(*) measure: pattern_length
# DEBUG:sql_parser:All parsed measures: {'start_id': ('FIRST', 'id'), 'end_id': ('LAST', 'id'), 'pattern_length': ('COUNT', '*')}
# DEBUG:sql_parser:Raw pattern: A B
# DEBUG:sql_parser:Parsed pattern: A B
# DEBUG:sql_parser:Raw define content: A AS val < NEXT(val),
#             B AS val > PREV(val)
# DEBUG:sql_parser:Added condition for variable A: val < NEXT(val)
# DEBUG:sql_parser:Added condition for variable B: val > PREV(val)
# DEBUG:sql_parser:Parsed conditions: {'A': 'val < NEXT(val)', 'B': 'val > PREV(val)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=[], order_cols=['id'], measures={'start_id': ('FIRST', 'id'), 'end_id': ('LAST', 'id'), 'pattern_length': ('COUNT', '*')}, pattern='A B', conditions={'A': 'val < NEXT(val)', 'B': 'val > PREV(val)'}, row_per_match='ONE', after_match='SKIP TO NEXT ROW', subsets={}, running_mode='RUNNING')
# DEBUG:execution_engine:Processing query:
# ...
# DEBUG:nfa_matcher:Comparing 59.0 > 49.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 459, 'group': 'group_9', 'value': 59}: matched
# DEBUG:nfa_matcher:Comparing 59.0 < 49.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 459, 'group': 'group_9', 'value': 59}: not matched
# DEBUG:nfa_matcher:Comparing 69.0 > 59.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 469, 'group': 'group_9', 'value': 69}: matched
# DEBUG:nfa_matcher:Comparing 69.0 < 59.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 469, 'group': 'group_9', 'value': 69}: not matched
# DEBUG:nfa_matcher:Comparing 79.0 > 69.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 479, 'group': 'group_9', 'value': 79}: matched
# DEBUG:nfa_matcher:Comparing 79.0 < 69.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 479, 'group': 'group_9', 'value': 79}: not matched
# DEBUG:nfa_matcher:Comparing 89.0 > 79.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 489, 'group': 'group_9', 'value': 89}: matched
# DEBUG:nfa_matcher:Comparing 89.0 < 79.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 489, 'group': 'group_9', 'value': 89}: not matched
# DEBUG:nfa_matcher:Comparing 49.0 > 89.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 49, 'group': 'group_9', 'value': 49}: not matched
# DEBUG:nfa_matcher:Comparing 49.0 < 89.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 49, 'group': 'group_9', 'value': 49}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=B, match_number=107
# DEBUG:nfa_matcher:First row {'id': 499, 'group': 'group_9', 'value': 99} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 499, 'group': 'group_9', 'value': 99}: matched
# DEBUG:nfa_matcher:Comparing 9.0 > 99.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 509, 'group': 'group_9', 'value': 9}: not matched
# DEBUG:nfa_matcher:Comparing 9.0 < 99.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 509, 'group': 'group_9', 'value': 9}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=B, match_number=108
# DEBUG:nfa_matcher:First row {'id': 519, 'group': 'group_9', 'value': 19} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 519, 'group': 'group_9', 'value': 19}: matched
# DEBUG:nfa_matcher:Comparing 29.0 > 19.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 529, 'group': 'group_9', 'value': 29}: matched
# DEBUG:nfa_matcher:Comparing 29.0 < 19.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 529, 'group': 'group_9', 'value': 29}: not matched
# DEBUG:nfa_matcher:Comparing 39.0 > 29.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 539, 'group': 'group_9', 'value': 39}: matched
# DEBUG:nfa_matcher:Comparing 39.0 < 29.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 539, 'group': 'group_9', 'value': 39}: not matched
# DEBUG:nfa_matcher:Comparing 49.0 > 39.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 549, 'group': 'group_9', 'value': 49}: matched
# DEBUG:nfa_matcher:Comparing 49.0 < 39.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 549, 'group': 'group_9', 'value': 49}: not matched
# DEBUG:nfa_matcher:Comparing 59.0 > 49.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 559, 'group': 'group_9', 'value': 59}: matched
# DEBUG:nfa_matcher:Comparing 59.0 < 49.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 559, 'group': 'group_9', 'value': 59}: not matched
# DEBUG:nfa_matcher:Comparing 69.0 > 59.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 569, 'group': 'group_9', 'value': 69}: matched
# DEBUG:nfa_matcher:Comparing 69.0 < 59.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 569, 'group': 'group_9', 'value': 69}: not matched
# DEBUG:nfa_matcher:Comparing 79.0 > 69.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 579, 'group': 'group_9', 'value': 79}: matched
# DEBUG:nfa_matcher:Comparing 79.0 < 69.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 579, 'group': 'group_9', 'value': 79}: not matched
# DEBUG:nfa_matcher:Comparing 89.0 > 79.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 589, 'group': 'group_9', 'value': 89}: matched
# DEBUG:nfa_matcher:Comparing 89.0 < 79.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 589, 'group': 'group_9', 'value': 89}: not matched
# DEBUG:nfa_matcher:Comparing 59.0 > 89.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 59, 'group': 'group_9', 'value': 59}: not matched
# DEBUG:nfa_matcher:Comparing 59.0 < 89.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 59, 'group': 'group_9', 'value': 59}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=B, match_number=109
# DEBUG:nfa_matcher:First row {'id': 599, 'group': 'group_9', 'value': 99} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 599, 'group': 'group_9', 'value': 99}: matched
# DEBUG:nfa_matcher:Comparing 9.0 > 99.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 609, 'group': 'group_9', 'value': 9}: not matched
# DEBUG:nfa_matcher:Comparing 9.0 < 99.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 609, 'group': 'group_9', 'value': 9}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=B, match_number=110
# DEBUG:nfa_matcher:First row {'id': 619, 'group': 'group_9', 'value': 19} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 619, 'group': 'group_9', 'value': 19}: matched
# DEBUG:nfa_matcher:Comparing 29.0 > 19.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 629, 'group': 'group_9', 'value': 29}: matched
# DEBUG:nfa_matcher:Comparing 29.0 < 19.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 629, 'group': 'group_9', 'value': 29}: not matched
# DEBUG:nfa_matcher:Comparing 39.0 > 29.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 639, 'group': 'group_9', 'value': 39}: matched
# DEBUG:nfa_matcher:Comparing 39.0 < 29.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 639, 'group': 'group_9', 'value': 39}: not matched
# DEBUG:nfa_matcher:Comparing 49.0 > 39.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 649, 'group': 'group_9', 'value': 49}: matched
# DEBUG:nfa_matcher:Comparing 49.0 < 39.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 649, 'group': 'group_9', 'value': 49}: not matched
# DEBUG:nfa_matcher:Comparing 59.0 > 49.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 659, 'group': 'group_9', 'value': 59}: matched
# DEBUG:nfa_matcher:Comparing 59.0 < 49.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 659, 'group': 'group_9', 'value': 59}: not matched
# DEBUG:nfa_matcher:Comparing 69.0 > 59.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 669, 'group': 'group_9', 'value': 69}: matched
# DEBUG:nfa_matcher:Comparing 69.0 < 59.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 669, 'group': 'group_9', 'value': 69}: not matched
# DEBUG:nfa_matcher:Comparing 79.0 > 69.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 679, 'group': 'group_9', 'value': 79}: matched
# DEBUG:nfa_matcher:Comparing 79.0 < 69.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 679, 'group': 'group_9', 'value': 79}: not matched
# DEBUG:nfa_matcher:Comparing 89.0 > 79.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 689, 'group': 'group_9', 'value': 89}: matched
# DEBUG:nfa_matcher:Comparing 89.0 < 79.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 689, 'group': 'group_9', 'value': 89}: not matched
# DEBUG:nfa_matcher:Comparing 69.0 > 89.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 69, 'group': 'group_9', 'value': 69}: not matched
# DEBUG:nfa_matcher:Comparing 69.0 < 89.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 69, 'group': 'group_9', 'value': 69}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=B, match_number=111
# DEBUG:nfa_matcher:First row {'id': 699, 'group': 'group_9', 'value': 99} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 699, 'group': 'group_9', 'value': 99}: matched
# DEBUG:nfa_matcher:Comparing 9.0 > 99.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 709, 'group': 'group_9', 'value': 9}: not matched
# DEBUG:nfa_matcher:Comparing 9.0 < 99.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 709, 'group': 'group_9', 'value': 9}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=B, match_number=112
# DEBUG:nfa_matcher:First row {'id': 719, 'group': 'group_9', 'value': 19} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 719, 'group': 'group_9', 'value': 19}: matched
# DEBUG:nfa_matcher:Comparing 29.0 > 19.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 729, 'group': 'group_9', 'value': 29}: matched
# DEBUG:nfa_matcher:Comparing 29.0 < 19.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 729, 'group': 'group_9', 'value': 29}: not matched
# DEBUG:nfa_matcher:Comparing 39.0 > 29.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 739, 'group': 'group_9', 'value': 39}: matched
# DEBUG:nfa_matcher:Comparing 39.0 < 29.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 739, 'group': 'group_9', 'value': 39}: not matched
# DEBUG:nfa_matcher:Comparing 49.0 > 39.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 749, 'group': 'group_9', 'value': 49}: matched
# DEBUG:nfa_matcher:Comparing 49.0 < 39.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 749, 'group': 'group_9', 'value': 49}: not matched
# DEBUG:nfa_matcher:Comparing 59.0 > 49.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 759, 'group': 'group_9', 'value': 59}: matched
# DEBUG:nfa_matcher:Comparing 59.0 < 49.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 759, 'group': 'group_9', 'value': 59}: not matched
# DEBUG:nfa_matcher:Comparing 69.0 > 59.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 769, 'group': 'group_9', 'value': 69}: matched
# DEBUG:nfa_matcher:Comparing 69.0 < 59.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 769, 'group': 'group_9', 'value': 69}: not matched
# DEBUG:nfa_matcher:Comparing 79.0 > 69.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 779, 'group': 'group_9', 'value': 79}: matched
# DEBUG:nfa_matcher:Comparing 79.0 < 69.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 779, 'group': 'group_9', 'value': 79}: not matched
# DEBUG:nfa_matcher:Comparing 89.0 > 79.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 789, 'group': 'group_9', 'value': 89}: matched
# DEBUG:nfa_matcher:Comparing 89.0 < 79.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 789, 'group': 'group_9', 'value': 89}: not matched
# DEBUG:nfa_matcher:Comparing 79.0 > 89.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 79, 'group': 'group_9', 'value': 79}: not matched
# DEBUG:nfa_matcher:Comparing 79.0 < 89.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 79, 'group': 'group_9', 'value': 79}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=B, match_number=113
# DEBUG:nfa_matcher:First row {'id': 799, 'group': 'group_9', 'value': 99} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 799, 'group': 'group_9', 'value': 99}: matched
# DEBUG:nfa_matcher:Comparing 9.0 > 99.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 809, 'group': 'group_9', 'value': 9}: not matched
# DEBUG:nfa_matcher:Comparing 9.0 < 99.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 809, 'group': 'group_9', 'value': 9}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=B, match_number=114
# DEBUG:nfa_matcher:First row {'id': 819, 'group': 'group_9', 'value': 19} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 819, 'group': 'group_9', 'value': 19}: matched
# DEBUG:nfa_matcher:Comparing 29.0 > 19.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 829, 'group': 'group_9', 'value': 29}: matched
# DEBUG:nfa_matcher:Comparing 29.0 < 19.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 829, 'group': 'group_9', 'value': 29}: not matched
# DEBUG:nfa_matcher:Comparing 39.0 > 29.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 839, 'group': 'group_9', 'value': 39}: matched
# DEBUG:nfa_matcher:Comparing 39.0 < 29.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 839, 'group': 'group_9', 'value': 39}: not matched
# DEBUG:nfa_matcher:Comparing 49.0 > 39.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 849, 'group': 'group_9', 'value': 49}: matched
# DEBUG:nfa_matcher:Comparing 49.0 < 39.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 849, 'group': 'group_9', 'value': 49}: not matched
# DEBUG:nfa_matcher:Comparing 59.0 > 49.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 859, 'group': 'group_9', 'value': 59}: matched
# DEBUG:nfa_matcher:Comparing 59.0 < 49.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 859, 'group': 'group_9', 'value': 59}: not matched
# DEBUG:nfa_matcher:Comparing 69.0 > 59.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 869, 'group': 'group_9', 'value': 69}: matched
# DEBUG:nfa_matcher:Comparing 69.0 < 59.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 869, 'group': 'group_9', 'value': 69}: not matched
# DEBUG:nfa_matcher:Comparing 79.0 > 69.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 879, 'group': 'group_9', 'value': 79}: matched
# DEBUG:nfa_matcher:Comparing 79.0 < 69.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 879, 'group': 'group_9', 'value': 79}: not matched
# DEBUG:nfa_matcher:Comparing 89.0 > 79.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 889, 'group': 'group_9', 'value': 89}: matched
# DEBUG:nfa_matcher:Comparing 89.0 < 79.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 889, 'group': 'group_9', 'value': 89}: not matched
# DEBUG:nfa_matcher:Comparing 89.0 > 89.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'id': 89, 'group': 'group_9', 'value': 89}: not matched
# DEBUG:nfa_matcher:Comparing 89.0 < 89.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'id': 89, 'group': 'group_9', 'value': 89}: not matched
# DEBUG:execution_engine:Output DataFrame columns: ['group', 'start_val', 'end_val', 'pattern_length']
# DEBUG:execution_engine:Performance stats: {'parse_time_ms': 0.2460479736328125, 'match_time_ms': 21.98648452758789, 'total_rows': 1000, 'matched_rows': 256, 'match_count': 64, 'rows_per_second': 43503.82498897651}
#
# Performance test results:
# Execution time: 0.02 seconds
# Matches found: 64
#
# Test Results Summary:
# ==================================================
# ✅ Basic Pattern: PASS (0.01s)
# ✅ Pattern Measures: PASS (0.00s)
# ✅ All Rows Output: PASS (0.00s)
# ✅ Subset Pattern: PASS (0.00s)
# ✅ Comprehensive Features: PASS (0.01s)
# ✅ Empty Partition: PASS (0.00s)
# ✅ Single Row Partition: PASS (0.00s)
# ✅ No Matches: PASS (0.00s)
# ✅ Complex Pattern: PASS (0.00s)
# ✅ After Match Skip: PASS (0.00s)
# ✅ Pattern Exclusion: PASS (0.00s)
# ✅ Exact Repetition Quantifiers: PASS (0.00s)
# ✅ Performance: PASS (0.02s)
#
# Summary:
# Total: 13, Passed: 13, Failed: 0, Errors: 0

# %%
# Import necessary libraries
import pandas as pd
from execution_engine import run_match_recognize

# Create the DataFrame
data = pd.DataFrame([
    {"ticker": "AAPL", "ts": "2024-01-01", "price": 100, "volume": 1000},
    {"ticker": "AAPL", "ts": "2024-01-02", "price": 95, "volume": 1100},
    {"ticker": "AAPL", "ts": "2024-01-03", "price": 90, "volume": 1200},
    {"ticker": "AAPL", "ts": "2024-01-04", "price": 92, "volume": 1300},
    {"ticker": "AAPL", "ts": "2024-01-05", "price": 98, "volume": 1400},
    {"ticker": "GOOGL", "ts": "2024-01-01", "price": 500, "volume": 2000},
    {"ticker": "GOOGL", "ts": "2024-01-02", "price": 480, "volume": 2100},
    {"ticker": "GOOGL", "ts": "2024-01-03", "price": 470, "volume": 2200},
    {"ticker": "GOOGL", "ts": "2024-01-04", "price": 485, "volume": 2300},
    {"ticker": "GOOGL", "ts": "2024-01-05", "price": 510, "volume": 2400}
])

# Define the MATCH_RECOGNIZE query
query = """
SELECT *
FROM data
MATCH_RECOGNIZE (
    PARTITION BY ticker
    ORDER BY ts
    MEASURES
        FIRST(price) AS start_price,
        LAST(A.price) AS bottom_price,
        LAST(price) AS end_price,
        COUNT(*) AS pattern_length,
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        RUNNING AVG(volume) AS avg_volume,
        FINAL MAX(volume) AS max_volume
    ONE ROW PER MATCH
    PATTERN (A+ (B | C) D?)
    SUBSET PRICE_TREND = (B, C)
    DEFINE
        A AS price < PREV(price),
        B AS price > PREV(price),
        C AS price = PREV(price),
        D AS price > PREV(price)
);
"""

# Run the MATCH_RECOGNIZE query
try:
    result = run_match_recognize(query, data)
    print("MATCH_RECOGNIZE Results:")
    print(result)
except Exception as e:
    print(f"Error running MATCH_RECOGNIZE: {str(e)}")
# Out:
# DEBUG:sql_parser:Raw measures content: FIRST(price) AS start_price,
#         LAST(A.price) AS bottom_price,
#         LAST(price) AS end_price,
#         COUNT(*) AS pattern_length,
#         CLASSIFIER() AS pattern_var,
#         MATCH_NUMBER() AS match_num,
#         RUNNING AVG(volume) AS avg_volume,
#         FINAL MAX(volume) AS max_volume
# DEBUG:sql_parser:Added function measure: start_price = (FIRST, price)
# DEBUG:sql_parser:Added pattern variable measure: bottom_price = (LAST, A.price)
# DEBUG:sql_parser:Added function measure: end_price = (LAST, price)
# DEBUG:sql_parser:Added COUNT(*) measure: pattern_length
# DEBUG:sql_parser:Added CLASSIFIER measure: pattern_var
# DEBUG:sql_parser:Added MATCH_NUMBER measure: match_num
# DEBUG:sql_parser:Added function measure: avg_volume = (RUNNING_AVG, volume)
# DEBUG:sql_parser:Added function measure: max_volume = (FINAL_MAX, volume)
# DEBUG:sql_parser:All parsed measures: {'start_price': ('FIRST', 'price'), 'bottom_price': ('LAST', 'A.price'), 'end_price': ('LAST', 'price'), 'pattern_length': ('COUNT', '*'), 'pattern_var': ('CLASSIFIER', '*'), 'match_num': ('MATCH_NUMBER', '*'), 'avg_volume': ('RUNNING_AVG', 'volume'), 'max_volume': ('FINAL_MAX', 'volume')}
# DEBUG:sql_parser:Raw pattern: A+ (B | C) D?
# DEBUG:sql_parser:Parsed pattern: A+ (B | C) D?
# DEBUG:sql_parser:Raw define content: A AS price < PREV(price),
#         B AS price > PREV(price),
#         C AS price = PREV(price),
#         D AS price > PREV(price)
# DEBUG:sql_parser:Added condition for variable A: price < PREV(price)
# DEBUG:sql_parser:Added condition for variable B: price > PREV(price)
# DEBUG:sql_parser:Added condition for variable C: price = PREV(price)
# DEBUG:sql_parser:Added condition for variable D: price > PREV(price)
# DEBUG:sql_parser:Parsed conditions: {'A': 'price < PREV(price)', 'B': 'price > PREV(price)', 'C': 'price = PREV(price)', 'D': 'price > PREV(price)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=['ticker'], order_cols=['ts'], measures={'start_price': ('FIRST', 'price'), 'bottom_price': ('LAST', 'A.price'), 'end_price': ('LAST', 'price'), 'pattern_length': ('COUNT', '*'), 'pattern_var': ('CLASSIFIER', '*'), 'match_num': ('MATCH_NUMBER', '*'), 'avg_volume': ('RUNNING_AVG', 'volume'), 'max_volume': ('FINAL_MAX', 'volume')}, pattern='A+ (B | C) D?', conditions={'A': 'price < PREV(price)', 'B': 'price > PREV(price)', 'C': 'price = PREV(price)', 'D': 'price > PREV(price)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={'PRICE_TREND': {'(B'}}, running_mode='FINAL')
# DEBUG:execution_engine:Processing query:
# SELECT *
# FROM data
# MATCH_RECOGNIZE (
#     PARTITION BY ticker
#     ORDER BY ts
#     MEASURES
#         FIRST(price) AS start_price,
#         LAST(A.price) AS bottom_price,
#         LAST(price) AS end_price,
#         COUNT(*) AS pattern_length,
#         CLASSIFIER() AS pattern_var,
#         MATCH_NUMBER() AS match_num,
#         RUNNING AVG(volume) AS avg_volume,
#         FINAL MAX(volume) AS max_volume
#     ONE ROW PER MATCH
#     PATTERN (A+ (B | C) D?)
#     SUBSET PRICE_TREND = (B, C)
#     DEFINE
#         A AS price < PREV(price),
#         B AS price > PREV(price),
#         C AS price = PREV(price),
#         D AS price > PREV(price)
# );
#
# DEBUG:sql_parser:Raw measures content: FIRST(price) AS start_price,
#         LAST(A.price) AS bottom_price,
#         LAST(price) AS end_price,
#         COUNT(*) AS pattern_length,
#         CLASSIFIER() AS pattern_var,
#         MATCH_NUMBER() AS match_num,
#         RUNNING AVG(volume) AS avg_volume,
#         FINAL MAX(volume) AS max_volume
# DEBUG:sql_parser:Added function measure: start_price = (FIRST, price)
# DEBUG:sql_parser:Added pattern variable measure: bottom_price = (LAST, A.price)
# DEBUG:sql_parser:Added function measure: end_price = (LAST, price)
# DEBUG:sql_parser:Added COUNT(*) measure: pattern_length
# DEBUG:sql_parser:Added CLASSIFIER measure: pattern_var
# DEBUG:sql_parser:Added MATCH_NUMBER measure: match_num
# DEBUG:sql_parser:Added function measure: avg_volume = (RUNNING_AVG, volume)
# DEBUG:sql_parser:Added function measure: max_volume = (FINAL_MAX, volume)
# DEBUG:sql_parser:All parsed measures: {'start_price': ('FIRST', 'price'), 'bottom_price': ('LAST', 'A.price'), 'end_price': ('LAST', 'price'), 'pattern_length': ('COUNT', '*'), 'pattern_var': ('CLASSIFIER', '*'), 'match_num': ('MATCH_NUMBER', '*'), 'avg_volume': ('RUNNING_AVG', 'volume'), 'max_volume': ('FINAL_MAX', 'volume')}
# DEBUG:sql_parser:Raw pattern: A+ (B | C) D?
# DEBUG:sql_parser:Parsed pattern: A+ (B | C) D?
# DEBUG:sql_parser:Raw define content: A AS price < PREV(price),
#         B AS price > PREV(price),
#         C AS price = PREV(price),
#         D AS price > PREV(price)
# DEBUG:sql_parser:Added condition for variable A: price < PREV(price)
# DEBUG:sql_parser:Added condition for variable B: price > PREV(price)
# DEBUG:sql_parser:Added condition for variable C: price = PREV(price)
# DEBUG:sql_parser:Added condition for variable D: price > PREV(price)
# DEBUG:sql_parser:Parsed conditions: {'A': 'price < PREV(price)', 'B': 'price > PREV(price)', 'C': 'price = PREV(price)', 'D': 'price > PREV(price)'}
# DEBUG:sql_parser:Parsed parameters: MatchRecognizeParams(partition_cols=['ticker'], order_cols=['ts'], measures={'start_price': ('FIRST', 'price'), 'bottom_price': ('LAST', 'A.price'), 'end_price': ('LAST', 'price'), 'pattern_length': ('COUNT', '*'), 'pattern_var': ('CLASSIFIER', '*'), 'match_num': ('MATCH_NUMBER', '*'), 'avg_volume': ('RUNNING_AVG', 'volume'), 'max_volume': ('FINAL_MAX', 'volume')}, pattern='A+ (B | C) D?', conditions={'A': 'price < PREV(price)', 'B': 'price > PREV(price)', 'C': 'price = PREV(price)', 'D': 'price > PREV(price)'}, row_per_match='ONE', after_match='SKIP PAST LAST ROW', subsets={'PRICE_TREND': {'(B'}}, running_mode='FINAL')
# DEBUG:nfa_matcher:Building NFA for pattern: A+ (B | C) D?
# DEBUG:nfa_matcher:Building NFA for pattern: A+ (B | C) D?
# DEBUG:nfa_matcher:First row {'ticker': 'AAPL', 'ts': '2024-01-01', 'price': 100, 'volume': 1000} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'AAPL', 'ts': '2024-01-01', 'price': 100, 'volume': 1000}: matched
# DEBUG:nfa_matcher:Comparing 95.0 < 100.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'AAPL', 'ts': '2024-01-02', 'price': 95, 'volume': 1100}: matched
# DEBUG:nfa_matcher:Comparing 95.0 = 100.0 for variable C
# DEBUG:nfa_matcher:Testing variable C for row {'ticker': 'AAPL', 'ts': '2024-01-02', 'price': 95, 'volume': 1100}: not matched
# DEBUG:nfa_matcher:Comparing 95.0 > 100.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'ticker': 'AAPL', 'ts': '2024-01-02', 'price': 95, 'volume': 1100}: not matched
# DEBUG:nfa_matcher:Comparing 90.0 < 95.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'AAPL', 'ts': '2024-01-03', 'price': 90, 'volume': 1200}: matched
# DEBUG:nfa_matcher:Comparing 90.0 = 95.0 for variable C
# DEBUG:nfa_matcher:Testing variable C for row {'ticker': 'AAPL', 'ts': '2024-01-03', 'price': 90, 'volume': 1200}: not matched
# DEBUG:nfa_matcher:Comparing 90.0 > 95.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'ticker': 'AAPL', 'ts': '2024-01-03', 'price': 90, 'volume': 1200}: not matched
# DEBUG:nfa_matcher:Comparing 92.0 < 90.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'AAPL', 'ts': '2024-01-04', 'price': 92, 'volume': 1300}: not matched
# DEBUG:nfa_matcher:Comparing 92.0 = 90.0 for variable C
# DEBUG:nfa_matcher:Testing variable C for row {'ticker': 'AAPL', 'ts': '2024-01-04', 'price': 92, 'volume': 1300}: not matched
# DEBUG:nfa_matcher:Comparing 92.0 > 90.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'ticker': 'AAPL', 'ts': '2024-01-04', 'price': 92, 'volume': 1300}: matched
# DEBUG:nfa_matcher:Match found: pattern_var=B, match_number=1
# DEBUG:nfa_matcher:First row {'ticker': 'AAPL', 'ts': '2024-01-05', 'price': 98, 'volume': 1400} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'AAPL', 'ts': '2024-01-05', 'price': 98, 'volume': 1400}: matched
# DEBUG:nfa_matcher:Building NFA for pattern: A+ (B | C) D?
# DEBUG:nfa_matcher:Building NFA for pattern: A+ (B | C) D?
# DEBUG:nfa_matcher:First row {'ticker': 'GOOGL', 'ts': '2024-01-01', 'price': 500, 'volume': 2000} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'GOOGL', 'ts': '2024-01-01', 'price': 500, 'volume': 2000}: matched
# DEBUG:nfa_matcher:Comparing 480.0 < 500.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'GOOGL', 'ts': '2024-01-02', 'price': 480, 'volume': 2100}: matched
# DEBUG:nfa_matcher:Comparing 480.0 > 500.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'ticker': 'GOOGL', 'ts': '2024-01-02', 'price': 480, 'volume': 2100}: not matched
# DEBUG:nfa_matcher:Comparing 480.0 = 500.0 for variable C
# DEBUG:nfa_matcher:Testing variable C for row {'ticker': 'GOOGL', 'ts': '2024-01-02', 'price': 480, 'volume': 2100}: not matched
# DEBUG:nfa_matcher:Comparing 470.0 < 480.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'GOOGL', 'ts': '2024-01-03', 'price': 470, 'volume': 2200}: matched
# DEBUG:nfa_matcher:Comparing 470.0 > 480.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'ticker': 'GOOGL', 'ts': '2024-01-03', 'price': 470, 'volume': 2200}: not matched
# DEBUG:nfa_matcher:Comparing 470.0 = 480.0 for variable C
# DEBUG:nfa_matcher:Testing variable C for row {'ticker': 'GOOGL', 'ts': '2024-01-03', 'price': 470, 'volume': 2200}: not matched
# DEBUG:nfa_matcher:Comparing 485.0 < 470.0 for variable A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'GOOGL', 'ts': '2024-01-04', 'price': 485, 'volume': 2300}: not matched
# DEBUG:nfa_matcher:Comparing 485.0 > 470.0 for variable B
# DEBUG:nfa_matcher:Testing variable B for row {'ticker': 'GOOGL', 'ts': '2024-01-04', 'price': 485, 'volume': 2300}: matched
# DEBUG:nfa_matcher:Comparing 485.0 = 470.0 for variable C
# DEBUG:nfa_matcher:Testing variable C for row {'ticker': 'GOOGL', 'ts': '2024-01-04', 'price': 485, 'volume': 2300}: not matched
# DEBUG:nfa_matcher:Match found: pattern_var=B, match_number=3
# DEBUG:nfa_matcher:First row {'ticker': 'GOOGL', 'ts': '2024-01-05', 'price': 510, 'volume': 2400} automatically matches condition for A
# DEBUG:nfa_matcher:Testing variable A for row {'ticker': 'GOOGL', 'ts': '2024-01-05', 'price': 510, 'volume': 2400}: matched
# DEBUG:execution_engine:Output DataFrame columns: ['ticker', 'start_price', 'bottom_price', 'end_price', 'pattern_length', 'pattern_var', 'match_num', 'avg_volume', 'max_volume']
# DEBUG:execution_engine:Performance stats: {'parse_time_ms': 5.3577423095703125, 'match_time_ms': 14.681100845336914, 'total_rows': 10, 'matched_rows': 18, 'match_count': 2, 'rows_per_second': 637.7103303288619}
# MATCH_RECOGNIZE Results:
#   ticker  start_price  bottom_price  end_price  pattern_length pattern_var  \
# 0   AAPL          100            90         92               4           A
# 1  GOOGL          500           470        485               4           A
#
#    match_num  avg_volume  max_volume
# 0          2      1150.0      1300.0
# 1          4      2150.0      2300.0

# %%
# !python -m transformations.match_recognize_ast
# Out:
# DEBUG:__main__:Entering MATCH_RECOGNIZE clause (enhanced AST builder)
# DEBUG:__main__:Extracted PARTITION BY: ['custkey']
# DEBUG:__main__:Extracted ORDER BY: ['orderdate']
# DEBUG:__main__:Parsed expression 'FIRST(price)' into AST: ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='FIRST', offset=None)
# DEBUG:__main__:Parsed expression 'LAST(price)' into AST: ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='LAST', offset=None)
# DEBUG:__main__:Extracted MEASURES: [Measure(expression={'raw': 'FIRST(price)', 'ast': ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='FIRST', offset=None)}, alias='start_price'), Measure(expression={'raw': 'LAST(price)', 'ast': ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='LAST', offset=None)}, alias='end_price')]
# DEBUG:__main__:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:__main__:Extracted AFTER MATCH SKIP: SKIP PAST LAST ROW
# DEBUG:__main__:Normalized pattern from 'A+B C' to 'A + B C'
# DEBUG:__main__:Parsed pattern 'A + B C' into AST: PatternAST(type='concatenation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='quantifier', value=None, quantifier='+', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False), PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='literal', value='C', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)
# DEBUG:__main__:Optimizing pattern AST: {'raw': 'A + B C', 'ast': PatternAST(type='concatenation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='quantifier', value=None, quantifier='+', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False), PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='literal', value='C', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)}
# DEBUG:__main__:Extracted PATTERN: {'raw': 'A + B C', 'ast': PatternAST(type='concatenation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='quantifier', value=None, quantifier='+', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False), PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='literal', value='C', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)}
# DEBUG:__main__:Parsed expression 'price>10' into AST: ExpressionAST(type='binary', value=None, operator='>', children=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='10', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], function_name=None, arguments=[], navigation_type=None, offset=None)
# DEBUG:__main__:Parsed expression 'price<PREV(price,2)' into AST: ExpressionAST(type='binary', value=None, operator='<', children=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='2', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='PREV', offset=2)], function_name=None, arguments=[], navigation_type=None, offset=None)
# DEBUG:__main__:Parsed expression 'price=PREV(price)' into AST: ExpressionAST(type='binary', value=None, operator='=', children=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='PREV', offset=None)], function_name=None, arguments=[], navigation_type=None, offset=None)
# DEBUG:__main__:Extracted DEFINE: [DefineClause(variable='A', condition={'raw': 'price>10', 'ast': ExpressionAST(type='binary', value=None, operator='>', children=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='10', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], function_name=None, arguments=[], navigation_type=None, offset=None)}), DefineClause(variable='B', condition={'raw': 'price<PREV(price,2)', 'ast': ExpressionAST(type='binary', value=None, operator='<', children=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='2', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='PREV', offset=2)], function_name=None, arguments=[], navigation_type=None, offset=None)}), DefineClause(variable='C', condition={'raw': 'price=PREV(price)', 'ast': ExpressionAST(type='binary', value=None, operator='=', children=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='PREV', offset=None)], function_name=None, arguments=[], navigation_type=None, offset=None)})]
# INFO:__main__:MATCH_RECOGNIZE clause validated successfully!
# Generated AST:
# MatchRecognizeAST(partition_by=['custkey'], order_by=['orderdate'], measures=[Measure(expression={'raw': 'FIRST(price)', 'ast': ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='FIRST', offset=None)}, alias='start_price'), Measure(expression={'raw': 'LAST(price)', 'ast': ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='LAST', offset=None)}, alias='end_price')], rows_per_match='ONE ROW PER MATCH', after_match_skip='SKIP PAST LAST ROW', pattern={'raw': 'A + B C', 'ast': PatternAST(type='concatenation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='quantifier', value=None, quantifier='+', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False), PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='literal', value='C', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)}, subset={}, define=[DefineClause(variable='A', condition={'raw': 'price>10', 'ast': ExpressionAST(type='binary', value=None, operator='>', children=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='10', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], function_name=None, arguments=[], navigation_type=None, offset=None)}), DefineClause(variable='B', condition={'raw': 'price<PREV(price,2)', 'ast': ExpressionAST(type='binary', value=None, operator='<', children=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='2', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='PREV', offset=2)], function_name=None, arguments=[], navigation_type=None, offset=None)}), DefineClause(variable='C', condition={'raw': 'price=PREV(price)', 'ast': ExpressionAST(type='binary', value=None, operator='=', children=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='identifier', value='price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='PREV', offset=None)], function_name=None, arguments=[], navigation_type=None, offset=None)})])

# %%
# !python -m unittest tests.test_enhancements
# Out:
# INFO:root:✓ Successfully detected circular reference
# .DEBUG:transformations.match_recognize_pattern:Parsed pattern 'A | B | A' into AST: PatternAST(type='alternation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='alternation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)], excluded=False)
# INFO:root:✓ Successfully optimized 'A | B | A' to remove duplicates
# .Entering MATCH_RECOGNIZE clause
# DEBUG:transformations.match_recognize_parser:Entering MATCH_RECOGNIZE clause (enhanced AST builder)
# DEBUG:transformations.match_recognize_parser:Extracted PARTITION BY: ['symbol']
# DEBUG:transformations.match_recognize_parser:Extracted ORDER BY: ['timestamp']
# DEBUG:transformations.match_recognize_expression:Parsed expression 'FIRST(A.price)' into AST: ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='qualified_identifier', value='A.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='FIRST', offset=None)
# DEBUG:transformations.match_recognize_expression:Parsed expression 'LAST(B.price)' into AST: ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='qualified_identifier', value='B.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='LAST', offset=None)
# DEBUG:transformations.match_recognize_parser:Extracted MEASURES: [Measure(expression={'raw': 'FIRST(A.price)', 'ast': ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='qualified_identifier', value='A.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='FIRST', offset=None)}, alias='start_price'), Measure(expression={'raw': 'LAST(B.price)', 'ast': ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='qualified_identifier', value='B.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='LAST', offset=None)}, alias='end_price')]
# DEBUG:transformations.match_recognize_pattern:Normalized pattern from 'A B+' to 'A B +'
# DEBUG:transformations.match_recognize_pattern:Parsed pattern 'A B +' into AST: PatternAST(type='concatenation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='quantifier', value=None, quantifier='+', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)], excluded=False)
# DEBUG:transformations.match_recognize_pattern:Optimizing pattern AST: {'raw': 'A B +', 'ast': PatternAST(type='concatenation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='quantifier', value=None, quantifier='+', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)], excluded=False)}
# DEBUG:transformations.match_recognize_parser:Extracted PATTERN: {'raw': 'A B +', 'ast': PatternAST(type='concatenation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='quantifier', value=None, quantifier='+', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)], excluded=False)}
# DEBUG:transformations.match_recognize_expression:Parsed expression 'A.price>100' into AST: ExpressionAST(type='binary', value=None, operator='>', children=[ExpressionAST(type='qualified_identifier', value='A.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='100', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], function_name=None, arguments=[], navigation_type=None, offset=None)
# DEBUG:transformations.match_recognize_expression:Parsed expression 'B.price>A.price' into AST: ExpressionAST(type='binary', value=None, operator='>', children=[ExpressionAST(type='qualified_identifier', value='B.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='qualified_identifier', value='A.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], function_name=None, arguments=[], navigation_type=None, offset=None)
# DEBUG:transformations.match_recognize_parser:Extracted DEFINE: [DefineClause(variable='A', condition={'raw': 'A.price>100', 'ast': ExpressionAST(type='binary', value=None, operator='>', children=[ExpressionAST(type='qualified_identifier', value='A.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='100', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], function_name=None, arguments=[], navigation_type=None, offset=None)}), DefineClause(variable='B', condition={'raw': 'B.price>A.price', 'ast': ExpressionAST(type='binary', value=None, operator='>', children=[ExpressionAST(type='qualified_identifier', value='B.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='qualified_identifier', value='A.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], function_name=None, arguments=[], navigation_type=None, offset=None)})]
# INFO:transformations.match_recognize_parser:MATCH_RECOGNIZE clause validated successfully!
# INFO:root:✓ Full query enhancement completed successfully
# .INFO:root:✓ Cache operations passed with stats: {'hits': 1, 'misses': 2, 'evictions': 1}
# .DEBUG:transformations.match_recognize_pattern:Parsed pattern '(A)' into AST: PatternAST(type='group', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)
# DEBUG:transformations.match_recognize_pattern:Parsed pattern '(A | B)+ C* D?' into AST: PatternAST(type='concatenation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='quantifier', value=None, quantifier='+', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='group', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='alternation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)], excluded=False)], excluded=False), PatternAST(type='quantifier', value=None, quantifier='*', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='C', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False), PatternAST(type='quantifier', value=None, quantifier='?', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='D', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)], excluded=False)
# INFO:root:✓ Simple pattern complexity: 3.7
# INFO:root:✓ Complex pattern complexity: 18.8
# .INFO:root:✓ Pattern equivalence checking passed
# .DEBUG:transformations.match_recognize_pattern:Normalized pattern from 'A B+' to 'A B +'
# INFO:root:✓ Normalized 'A B+' to 'A B +'
# DEBUG:transformations.match_recognize_pattern:Normalized pattern from 'A B C+' to 'A B C +'
# INFO:root:✓ Normalized 'A B C+' to 'A B C +'
# DEBUG:transformations.match_recognize_pattern:Normalized pattern from 'A+ B' to 'A + B'
# INFO:root:✓ Normalized 'A+ B' to 'A + B'
# .DEBUG:transformations.match_recognize_pattern:Normalized pattern from 'A B+' to 'A B +'
# DEBUG:transformations.match_recognize_pattern:Parsed pattern 'A B +' into AST: PatternAST(type='concatenation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='quantifier', value=None, quantifier='+', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)], excluded=False)
# INFO:root:✓ Successfully parsed pattern: A B+
# DEBUG:transformations.match_recognize_pattern:Normalized pattern from 'A | B' to 'A | B'
# DEBUG:transformations.match_recognize_pattern:Parsed pattern 'A | B' into AST: PatternAST(type='alternation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)
# INFO:root:✓ Successfully parsed pattern: A | B
# DEBUG:transformations.match_recognize_pattern:Normalized pattern from '(A B)+' to '(A B)+'
# DEBUG:transformations.match_recognize_pattern:Parsed pattern '(A B)+' into AST: PatternAST(type='quantifier', value=None, quantifier='+', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='group', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='concatenation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)], excluded=False)], excluded=False)
# INFO:root:✓ Successfully parsed pattern: (A B)+
# DEBUG:transformations.match_recognize_pattern:Normalized pattern from 'A*' to 'A *'
# DEBUG:transformations.match_recognize_pattern:Parsed pattern 'A *' into AST: PatternAST(type='quantifier', value=None, quantifier='*', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)
# INFO:root:✓ Successfully parsed pattern: A*
# .DEBUG:transformations.match_recognize_pattern:Parsed pattern '(A B+)' into AST: PatternAST(type='group', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='concatenation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='quantifier', value=None, quantifier='+', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)], excluded=False)], excluded=False)
# INFO:root:✓ Pattern visualization works correctly
# .DEBUG:transformations.match_recognize_pattern:Parsed pattern '(A | B)*' into AST: PatternAST(type='quantifier', value=None, quantifier='*', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='group', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='alternation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)], excluded=False)], excluded=False)
# DEBUG:transformations.match_recognize_pattern:Parsed pattern '((A+)+)' into AST: PatternAST(type='group', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='quantifier', value=None, quantifier='+', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='group', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='quantifier', value=None, quantifier='+', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)], excluded=False)], excluded=False)], excluded=False)
# INFO:root:✓ Detected risks in unbounded pattern: ['Pattern uses unbounded repetition (*) which may cause excessive backtracking']
# INFO:root:⚠️ Note: Advanced nested quantifier detection not implemented
# .Entering MATCH_RECOGNIZE clause
# DEBUG:transformations.match_recognize_parser:Entering MATCH_RECOGNIZE clause (enhanced AST builder)
# DEBUG:transformations.match_recognize_parser:Extracted PARTITION BY: ['symbol']
# DEBUG:transformations.match_recognize_parser:Extracted ORDER BY: ['timestamp']
# DEBUG:transformations.match_recognize_expression:Parsed expression 'FIRST(A.price)' into AST: ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='qualified_identifier', value='A.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='FIRST', offset=None)
# DEBUG:transformations.match_recognize_expression:Parsed expression 'LAST(B.price)' into AST: ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='qualified_identifier', value='B.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='LAST', offset=None)
# DEBUG:transformations.match_recognize_parser:Extracted MEASURES: [Measure(expression={'raw': 'FIRST(A.price)', 'ast': ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='qualified_identifier', value='A.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='FIRST', offset=None)}, alias='start_price'), Measure(expression={'raw': 'LAST(B.price)', 'ast': ExpressionAST(type='navigation', value=None, operator=None, children=[], function_name=None, arguments=[ExpressionAST(type='qualified_identifier', value='B.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='literal', value='0', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], navigation_type='LAST', offset=None)}, alias='end_price')]
# DEBUG:transformations.match_recognize_pattern:Normalized pattern from 'A B+' to 'A B +'
# DEBUG:transformations.match_recognize_pattern:Parsed pattern 'A B +' into AST: PatternAST(type='concatenation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='quantifier', value=None, quantifier='+', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)], excluded=False)
# DEBUG:transformations.match_recognize_pattern:Optimizing pattern AST: {'raw': 'A B +', 'ast': PatternAST(type='concatenation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='quantifier', value=None, quantifier='+', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)], excluded=False)}
# DEBUG:transformations.match_recognize_parser:Extracted PATTERN: {'raw': 'A B +', 'ast': PatternAST(type='concatenation', value=None, quantifier=None, quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='A', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False), PatternAST(type='quantifier', value=None, quantifier='+', quantifier_min=None, quantifier_max=None, children=[PatternAST(type='literal', value='B', quantifier=None, quantifier_min=None, quantifier_max=None, children=[], excluded=False)], excluded=False)], excluded=False)}
# DEBUG:transformations.match_recognize_expression:Parsed expression 'A.price>B.price' into AST: ExpressionAST(type='binary', value=None, operator='>', children=[ExpressionAST(type='qualified_identifier', value='A.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='qualified_identifier', value='B.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], function_name=None, arguments=[], navigation_type=None, offset=None)
# DEBUG:transformations.match_recognize_expression:Parsed expression 'B.price>A.price' into AST: ExpressionAST(type='binary', value=None, operator='>', children=[ExpressionAST(type='qualified_identifier', value='B.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='qualified_identifier', value='A.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], function_name=None, arguments=[], navigation_type=None, offset=None)
# DEBUG:transformations.match_recognize_parser:Extracted DEFINE: [DefineClause(variable='A', condition={'raw': 'A.price>B.price', 'ast': ExpressionAST(type='binary', value=None, operator='>', children=[ExpressionAST(type='qualified_identifier', value='A.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='qualified_identifier', value='B.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], function_name=None, arguments=[], navigation_type=None, offset=None)}), DefineClause(variable='B', condition={'raw': 'B.price>A.price', 'ast': ExpressionAST(type='binary', value=None, operator='>', children=[ExpressionAST(type='qualified_identifier', value='B.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None), ExpressionAST(type='qualified_identifier', value='A.price', operator=None, children=[], function_name=None, arguments=[], navigation_type=None, offset=None)], function_name=None, arguments=[], navigation_type=None, offset=None)})]
# INFO:transformations.match_recognize_parser:MATCH_RECOGNIZE clause validated successfully!
# INFO:root:✓ Query with issues was processed
# .
# ----------------------------------------------------------------------
# Ran 11 tests in 0.081s
#
# OK

# %%
from antlr4 import *
from grammar.TrinoLexer import TrinoLexer
from grammar.TrinoParser import TrinoParser

def parse_input(input_text):
    input_stream = InputStream(input_text)
    lexer = TrinoLexer(input_stream)
    stream = CommonTokenStream(lexer)
    parser = TrinoParser(stream)

    # Check the actual entry rule from your grammar!
    tree = parser.statements()  # Change 'statements' if your grammar has a different entry rule.

    return tree, parser

if __name__ == "__main__":
    sample = "SELECT * FROM table_name;"  # Example SQL query
    tree, parser = parse_input(sample)
    print(tree.toStringTree(recog=parser))  # Print the parse tree
# Out:
# (statements (singleStatement (statement (rootQuery (query (queryNoWith (queryTerm (queryPrimary (querySpecification SELECT (selectItem *) FROM (relation (sampledRelation (patternRecognition (aliasedRelation (relationPrimary (qualifiedName (identifier table_name)))))))))))))) ;))

# %%
from antlr4 import *
from grammar.TrinoLexer import TrinoLexer
from grammar.TrinoParser import TrinoParser

def parse_input(input_text):
    input_stream = InputStream(input_text)
    lexer = TrinoLexer(input_stream)
    stream = CommonTokenStream(lexer)
    parser = TrinoParser(stream)

    # Check the actual entry rule from your grammar!
    tree = parser.statements()  # Change 'statements' if your grammar has a different entry rule.

    return tree, parser

if __name__ == "__main__":
    sample = "SELECT * FROM table_name;"  # Example SQL query
    tree, parser = parse_input(sample)
    print(tree.toStringTree(recog=parser))  # Print the parse tree
# Out:
# (statements (singleStatement (statement (rootQuery (query (queryNoWith (queryTerm (queryPrimary (querySpecification SELECT (selectItem *) FROM (relation (sampledRelation (patternRecognition (aliasedRelation (relationPrimary (qualifiedName (identifier table_name)))))))))))))) ;))

# %%
from antlr4 import *
from grammar.TrinoLexer import *
from grammar.TrinoParser import *

# %%
from antlr4 import *
from grammar.TrinoLexer import TrinoLexer
from grammar.TrinoParser import TrinoParser

def parse_input(input_text):
    input_stream = InputStream(input_text)
    lexer = TrinoLexer(input_stream)
    stream = CommonTokenStream(lexer)
    parser = TrinoParser(stream)

    # Replace 'parse' with the correct start rule from your TrinoParser.g4 file
    tree = parser.statements()  # Change this to match your grammar's entry rule

    return tree, parser  # Return both the parse tree and parser

if __name__ == "__main__":
    sample = """SELECT *
    FROM data
    MATCH_RECOGNIZE (
        PARTITION BY ticker
        ORDER BY ts
        MEASURES
            FIRST(price) AS start_price,
            LAST(A.price) AS bottom_price,
            LAST(price) AS end_price,
            COUNT(*) AS pattern_length,
            CLASSIFIER() AS pattern_var,
            MATCH_NUMBER() AS match_num,
            RUNNING AVG(volume) AS avg_volume,
            FINAL MAX(volume) AS max_volume
        ONE ROW PER MATCH
        PATTERN (A+ (B | C) D?)
        SUBSET PRICE_TREND = (B, C)
        DEFINE
            A AS price < PREV(price),
            B AS price > PREV(price),
            C AS price = PREV(price),
            D AS price > PREV(price)
    );"""
    
    tree, parser = parse_input(sample)  # Capture both values returned by parse_input()
    print(tree.toStringTree(recog=parser))  # Now parser is correctly defined
# Out:
# (statements (singleStatement (statement (rootQuery (query (queryNoWith (queryTerm (queryPrimary (querySpecification SELECT (selectItem *) FROM (relation (sampledRelation (patternRecognition (aliasedRelation (relationPrimary (qualifiedName (identifier (nonReserved data))))) MATCH_RECOGNIZE ( PARTITION BY (expression (booleanExpression (valueExpression (primaryExpression (identifier ticker))))) ORDER BY (sortItem (expression (booleanExpression (valueExpression (primaryExpression (identifier ts)))))) MEASURES (measureDefinition (expression (booleanExpression (valueExpression (primaryExpression (qualifiedName (identifier (nonReserved FIRST))) ( (expression (booleanExpression (valueExpression (primaryExpression (identifier price))))) ))))) AS (identifier start_price)) , (measureDefinition (expression (booleanExpression (valueExpression (primaryExpression (qualifiedName (identifier (nonReserved LAST))) ( (expression (booleanExpression (valueExpression (primaryExpression (primaryExpression (identifier A)) . (identifier price))))) ))))) AS (identifier bottom_price)) , (measureDefinition (expression (booleanExpression (valueExpression (primaryExpression (qualifiedName (identifier (nonReserved LAST))) ( (expression (booleanExpression (valueExpression (primaryExpression (identifier price))))) ))))) AS (identifier end_price)) , (measureDefinition (expression (booleanExpression (valueExpression (primaryExpression (qualifiedName (identifier (nonReserved COUNT))) ( * ))))) AS (identifier pattern_length)) , (measureDefinition (expression (booleanExpression (valueExpression (primaryExpression (qualifiedName (identifier CLASSIFIER)) ( ))))) AS (identifier pattern_var)) , (measureDefinition (expression (booleanExpression (valueExpression (primaryExpression (qualifiedName (identifier MATCH_NUMBER)) ( ))))) AS (identifier match_num)) , (measureDefinition (expression (booleanExpression (valueExpression (primaryExpression (processingMode RUNNING) (qualifiedName (identifier AVG)) ( (expression (booleanExpression (valueExpression (primaryExpression (identifier volume))))) ))))) AS (identifier avg_volume)) , (measureDefinition (expression (booleanExpression (valueExpression (primaryExpression (processingMode FINAL) (qualifiedName (identifier MAX)) ( (expression (booleanExpression (valueExpression (primaryExpression (identifier volume))))) ))))) AS (identifier max_volume)) (rowsPerMatch ONE ROW PER MATCH) PATTERN ( (rowPattern (rowPattern (rowPattern (patternPrimary (identifier A)) (patternQuantifier +)) (rowPattern (patternPrimary ( (rowPattern (rowPattern (patternPrimary (identifier B))) | (rowPattern (patternPrimary (identifier C)))) )))) (rowPattern (patternPrimary (identifier D)) (patternQuantifier ?))) ) SUBSET (subsetDefinition (identifier PRICE_TREND) = ( (identifier B) , (identifier C) )) DEFINE (variableDefinition (identifier A) AS (expression (booleanExpression (valueExpression (primaryExpression (identifier price))) (predicate_ (comparisonOperator <) (valueExpression (primaryExpression (qualifiedName (identifier PREV)) ( (expression (booleanExpression (valueExpression (primaryExpression (identifier price))))) ))))))) , (variableDefinition (identifier B) AS (expression (booleanExpression (valueExpression (primaryExpression (identifier price))) (predicate_ (comparisonOperator >) (valueExpression (primaryExpression (qualifiedName (identifier PREV)) ( (expression (booleanExpression (valueExpression (primaryExpression (identifier price))))) ))))))) , (variableDefinition (identifier C) AS (expression (booleanExpression (valueExpression (primaryExpression (identifier price))) (predicate_ (comparisonOperator =) (valueExpression (primaryExpression (qualifiedName (identifier PREV)) ( (expression (booleanExpression (valueExpression (primaryExpression (identifier price))))) ))))))) , (variableDefinition (identifier D) AS (expression (booleanExpression (valueExpression (primaryExpression (identifier price))) (predicate_ (comparisonOperator >) (valueExpre ...

# %%
from antlr4.tree.Trees import Trees

tree, parser = parse_input(sample)
print(Trees.toStringTree(tree, None, parser))
# Out:
# (statements (singleStatement (statement (rootQuery (query (queryNoWith (queryTerm (queryPrimary (querySpecification SELECT (selectItem *) FROM (relation (sampledRelation (patternRecognition (aliasedRelation (relationPrimary (qualifiedName (identifier (nonReserved data))))) MATCH_RECOGNIZE ( PARTITION BY (expression (booleanExpression (valueExpression (primaryExpression (identifier ticker))))) ORDER BY (sortItem (expression (booleanExpression (valueExpression (primaryExpression (identifier ts)))))) MEASURES (measureDefinition (expression (booleanExpression (valueExpression (primaryExpression (qualifiedName (identifier (nonReserved FIRST))) ( (expression (booleanExpression (valueExpression (primaryExpression (identifier price))))) ))))) AS (identifier start_price)) , (measureDefinition (expression (booleanExpression (valueExpression (primaryExpression (qualifiedName (identifier (nonReserved LAST))) ( (expression (booleanExpression (valueExpression (primaryExpression (primaryExpression (identifier A)) . (identifier price))))) ))))) AS (identifier bottom_price)) , (measureDefinition (expression (booleanExpression (valueExpression (primaryExpression (qualifiedName (identifier (nonReserved LAST))) ( (expression (booleanExpression (valueExpression (primaryExpression (identifier price))))) ))))) AS (identifier end_price)) , (measureDefinition (expression (booleanExpression (valueExpression (primaryExpression (qualifiedName (identifier (nonReserved COUNT))) ( * ))))) AS (identifier pattern_length)) , (measureDefinition (expression (booleanExpression (valueExpression (primaryExpression (qualifiedName (identifier CLASSIFIER)) ( ))))) AS (identifier pattern_var)) , (measureDefinition (expression (booleanExpression (valueExpression (primaryExpression (qualifiedName (identifier MATCH_NUMBER)) ( ))))) AS (identifier match_num)) , (measureDefinition (expression (booleanExpression (valueExpression (primaryExpression (processingMode RUNNING) (qualifiedName (identifier AVG)) ( (expression (booleanExpression (valueExpression (primaryExpression (identifier volume))))) ))))) AS (identifier avg_volume)) , (measureDefinition (expression (booleanExpression (valueExpression (primaryExpression (processingMode FINAL) (qualifiedName (identifier MAX)) ( (expression (booleanExpression (valueExpression (primaryExpression (identifier volume))))) ))))) AS (identifier max_volume)) (rowsPerMatch ONE ROW PER MATCH) PATTERN ( (rowPattern (rowPattern (rowPattern (patternPrimary (identifier A)) (patternQuantifier +)) (rowPattern (patternPrimary ( (rowPattern (rowPattern (patternPrimary (identifier B))) | (rowPattern (patternPrimary (identifier C)))) )))) (rowPattern (patternPrimary (identifier D)) (patternQuantifier ?))) ) SUBSET (subsetDefinition (identifier PRICE_TREND) = ( (identifier B) , (identifier C) )) DEFINE (variableDefinition (identifier A) AS (expression (booleanExpression (valueExpression (primaryExpression (identifier price))) (predicate_ (comparisonOperator <) (valueExpression (primaryExpression (qualifiedName (identifier PREV)) ( (expression (booleanExpression (valueExpression (primaryExpression (identifier price))))) ))))))) , (variableDefinition (identifier B) AS (expression (booleanExpression (valueExpression (primaryExpression (identifier price))) (predicate_ (comparisonOperator >) (valueExpression (primaryExpression (qualifiedName (identifier PREV)) ( (expression (booleanExpression (valueExpression (primaryExpression (identifier price))))) ))))))) , (variableDefinition (identifier C) AS (expression (booleanExpression (valueExpression (primaryExpression (identifier price))) (predicate_ (comparisonOperator =) (valueExpression (primaryExpression (qualifiedName (identifier PREV)) ( (expression (booleanExpression (valueExpression (primaryExpression (identifier price))))) ))))))) , (variableDefinition (identifier D) AS (expression (booleanExpression (valueExpression (primaryExpression (identifier price))) (predicate_ (comparisonOperator >) (valueExpre ...

# %%
from grammar.TrinoParserListener import TrinoParserListener
from antlr4 import ParseTreeWalker

class SQLListener(TrinoParserListener):
    def enterQualifiedName(self, ctx):
        print("Table or Column Detected:", ctx.getText())

tree, parser = parse_input(sample)

walker = ParseTreeWalker()
listener = SQLListener()
walker.walk(listener, tree)
# Out:
# Table or Column Detected: data
# Table or Column Detected: FIRST
# Table or Column Detected: LAST
# Table or Column Detected: LAST
# Table or Column Detected: COUNT
# Table or Column Detected: CLASSIFIER
# Table or Column Detected: MATCH_NUMBER
# Table or Column Detected: AVG
# Table or Column Detected: MAX
# Table or Column Detected: PREV
# Table or Column Detected: PREV
# Table or Column Detected: PREV
# Table or Column Detected: PREV

# %%
class MatchRecognizeListener(TrinoParserListener):
    def enterPatternRecognition(self, ctx):
        print("MATCH_RECOGNIZE Clause Detected:", ctx.getText())

tree, parser = parse_input(sample)

walker = ParseTreeWalker()
listener = MatchRecognizeListener()
walker.walk(listener, tree)
# Out:
# MATCH_RECOGNIZE Clause Detected: dataMATCH_RECOGNIZE(PARTITIONBYtickerORDERBYtsMEASURESFIRST(price)ASstart_price,LAST(A.price)ASbottom_price,LAST(price)ASend_price,COUNT(*)ASpattern_length,CLASSIFIER()ASpattern_var,MATCH_NUMBER()ASmatch_num,RUNNINGAVG(volume)ASavg_volume,FINALMAX(volume)ASmax_volumeONEROWPERMATCHPATTERN(A+(B|C)D?)SUBSETPRICE_TREND=(B,C)DEFINEAASprice<PREV(price),BASprice>PREV(price),CASprice=PREV(price),DASprice>PREV(price))

# %%
# !pip install anytree
# Out:
# Requirement already satisfied: anytree in /home/monierashraf/anaconda3/lib/python3.12/site-packages (2.12.1)
# Requirement already satisfied: six in /home/monierashraf/anaconda3/lib/python3.12/site-packages (from anytree) (1.16.0)

# %%
from anytree import Node, RenderTree

def build_tree(node, parser, parent=None):
    node_name = parser.ruleNames[node.getRuleIndex()] if node.getChildCount() > 0 else node.getText()
    tree_node = Node(node_name, parent=parent)
    for i in range(node.getChildCount()):
        build_tree(node.getChild(i), parser, tree_node)
    return tree_node

tree, parser = parse_input(sample)
root = build_tree(tree, parser)

for pre, fill, node in RenderTree(root):
    print("%s%s" % (pre, node.name))
# Out:
# statements
# └── singleStatement
#     ├── statement
#     │   └── rootQuery
#     │       └── query
#     │           └── queryNoWith
#     │               └── queryTerm
#     │                   └── queryPrimary
#     │                       └── querySpecification
#     │                           ├── SELECT
#     │                           ├── selectItem
#     │                           │   └── *
#     │                           ├── FROM
#     │                           └── relation
#     │                               └── sampledRelation
#     │                                   └── patternRecognition
#     │                                       ├── aliasedRelation
#     │                                       │   └── relationPrimary
#     │                                       │       └── qualifiedName
#     │                                       │           └── identifier
#     │                                       │               └── nonReserved
#     │                                       │                   └── data
#     │                                       ├── MATCH_RECOGNIZE
#     │                                       ├── (
#     │                                       ├── PARTITION
#     │                                       ├── BY
#     │                                       ├── expression
#     │                                       │   └── booleanExpression
#     │                                       │       └── valueExpression
#     │                                       │           └── primaryExpression
#     │                                       │               └── identifier
#     │                                       │                   └── ticker
#     │                                       ├── ORDER
#     │                                       ├── BY
#     │                                       ├── sortItem
#     │                                       │   └── expression
#     │                                       │       └── booleanExpression
#     │                                       │           └── valueExpression
#     │                                       │               └── primaryExpression
#     │                                       │                   └── identifier
#     │                                       │                       └── ts
#     │                                       ├── MEASURES
#     │                                       ├── measureDefinition
#     │                                       │   ├── expression
#     │                                       │   │   └── booleanExpression
#     │                                       │   │       └── valueExpression
#     │                                       │   │           └── primaryExpression
#     │                                       │   │               ├── qualifiedName
#     │                                       │   │               │   └── identifier
#     │                                       │   │               │       └── nonReserved
#     │                                       │   │               │           └── FIRST
#     │                                       │   │               ├── (
#     │                                       │   │               ├── expression
#     │                                       │   │               │   └── booleanExpression
#     │                                       │   │               │       └── valueExpression
#     │                                       │   │               │           └── primaryExpression
#     │                                       │   │               │               └── identifier
#     │                                       │   │               │                   └── price
#     │                                       │   │               └── )
#     │                                       │   ├── AS
#     │                                       │   └── identifier
#     │                                       │       └── start_price
#     │                                       ├── ,
#     │                                       ├── measureDefinition
#     │                                       │   ├── expression
#     │                                       │   │   └── booleanExpression
#     │                                       │   │       └── valueExpression
#     │                                       │   │           └── primaryExpression
#     │                                       │   │               ├── qualifiedName
#     │                                       │   │               │   └── identifier
#     │                                       │   │               │       └── nonReserved
#     │                                       │   │               │           └── LAST
#     │                                       │   │               ├── (
#     │                                       │   │               ├── expression
#     │                                       │   │               │   └── booleanExpression
#     │                                       │   │               │       └── valueExpression
#     │                                       │   │               │           └── primaryExpression
#     │                                       │   │               │               ├── primaryExpression
#     │                                       │   │               │               │   └── identifier
#     │                                       │   │               │               │       └── A
#     │                                       │   │               │               ├── .
#     │                                       │   │               │               └── identifier
#     │                                       │   │               │                   └── price
#     │                                       │   │               └── )
#     │                                       │   ├── AS
#     │                                       │   └── identifier
#     │                                       │       └── bottom_price
#     │                                       ├── ,
#     │                                       ├── measureDefinition
#     │                                       │   ├── expression
#     │                                       │   │   └── booleanExpression
#     │                                       │   │       └── valueExpression
#     │                                       │   │           └── primaryExpression
#     │                                       │   │               ├── qualifiedName
#     │                                       │   │               │   └── identifier
#     │                                       │   │               │       └── nonReserved
#     │                                       │   │               │           └── LAST
#     │                                       │   │               ├── (
#     │                                       │   │               ├── expression
#     │                                       │   │               │   └── booleanExpression
#     │                                       │   │               │       └── valueExpression
#     │                                       │   │               │           └── primaryExpression
#     │                                       │   │               │               └── identifier
#     │                                       │   │               │                   └── price
#     │                                       │   │               └── )
#     │                                       │   ├── AS
#     │                                       │   └── identifier
#     │                                       │       └── end_price
#     │                                       ├── ,
#     │                                       ├── measureDefinition
#     │                                       │   ├── expression
#     │                                       │   │   └── booleanExpression
#     │                                       │   │       └── valueExpression
#     │                                       │   │           └── primaryExpression
#     │                                       │   │               ├── qualifiedName
#     │                                       │   │               │   └── identifier
#     │                                       │   │               │       └── nonReserved
#     │                                       │   │               │           └── COUNT
#     │                                       │   │               ├── (
#     │                                       │   │               ├── *
#     │                                       │   │               └── )
#     │                                       │   ├── AS
#     │                                       │   └── identifier
#     │                                       │       └── pattern_length
#     │                                       ├── ,
#     │                                       ├── measureDefinition
#     │                                       │   ├── expression
#     │                                       │   │   └── booleanExpression
#     │                                       │   │       └── valueExpression
#     │                                       │   │           └── primaryExpression
#     │                                       │   │               ├── qualifiedName
#     │                                       │   │               │   └── identifier
#     │                                       │   │               │       └── CLASSIFIER
#     │                                       │   │               ├── (
#     │                                       │   │               └── )
#     │                                       │   ├── AS
#     │                                       │   └── identifier
#     │                                       │       └── pattern_var
#     │                                       ├── ,
#     │                                       ├── measureDefinition
#     │                                       │   ├── expression
#     │                                       │   │   └── booleanExpression
#     │                                       │   │       └── valueExpression
#     │                                       │   │           └── primaryExpression
#     │                                       │   │               ├── qualifiedName
#     │                                       │   │               │   └── identifier
#     │                                       │   │               │       └── MATCH_NUMBER
#     │                                       │   │               ├── (
#     │                                       │   │               └── )
#     │                                       │   ├── AS
#     │                                       │   └── identifier
#     │                                       │       └── match_num
#     │                                       ├── ,
#     │                                       ├── measureDefinition
#     │                                       │   ├── expression
#     │                                       │   │   └── booleanExpression
#     │                                       │   │       └── valueExpression
#     │                                       │   │           └── primaryExpression
#     │                                       │   │               ├── processingMode
#     │                                       │   │               │   └── RUNNING
#     │                                       │   │               ├── qualifiedName
#     │                                       │   │               │   └── identifier
#     │                                       │   │               │       └── AVG
#     │                                       │   │               ├── (
#     │                                       │   │               ├── expression
#     │                                       │   │               │   └── booleanExpression
#     │                                       │   │               │       └── valueExpression
#     │                                       │   │               │           └── primaryExpression
#     │                                       │   │               │               └── identifier
#     │                                       │   │               │                   └── volume
#     │                                       │   │               └── )
#     │                                       │   ├── AS
#     │                                       │   └── identifier
#     │                                       │       └── avg_volume
#     │                                       ├── ,
#     │                                       ├── measureDefinition
#     │                                       │   ├── expression
#     │                                       │   │   └── booleanExpression
#     │                                       │   │       └── valueExpression
#     │                                       │   │           └── primaryExpression
#     │                                       │   │               ├── processingMode
#     │                                       │   │               │   └── FINAL
#     │                                       │   │               ├── qualifiedName
#     │                                       │   │               │   └── identifier
#     │                                       │   │               │       └── MAX
#     │                                       │   │               ├── (
#     │                                       │   │               ├── expression
#     │                                       │   │               │   └── booleanExpression
#     │                                       │   │               │       └── valueExpression
#     │                                       │   │               │           └── primaryExpression
#     │                                       │   │               │               └── identifier
#     │                                       │   │               │                   └── volume
#     │                                       │   │               └── )
#     │                                       │   ├── AS
#     │                                       │   └── identifier
#     │                                       │       └── max_volume
#     │                                       ├── rowsPerMatch
#     │                                       │   ├── ONE
#     │                                       │   ├── ROW
#     │                                       │   ├── PER
#     │                                       │   └── MATCH
#     │                                       ├── PATTERN
#     │                                       ├── (
#     │                                       ├── rowPattern
#     │                                       │   ├── rowPattern
#     │                                       │   │   ├── rowPattern
#     │                                       │   │   │   ├── patternPrimary
#     │                                       │   │   │   │   └── identifier
#     │                                       │   │   │   │       └── A
#     │                                       │   │   │   └── patternQuantifier
#     │                                       │   │   │       └── +
#     │                                       │   │   └── rowPattern
#     │                                       │   │       └── patternPrimary
#     │                                       │   │           ├── (
#     │                                       │   │           ├── rowPattern
#     │                                       │   │           │   ├── rowPattern
#     │                                       │   │           │   │   └── patternPrimary
#     │                                       │   │           │   │       └── identifier
#     │                                       │   │           │   │           └── B
#     │                                       │   │           │   ├── |
#     │                                       │   │           │   └── rowPattern
#     │                                       │   │           │       └── patternPrimary
#     │                                       │   │           │           └── identifier
#     │                                       │   │           │               └── C
#     │                                       │   │           └── )
#     │                                       │   └── rowPattern
#     │                                       │       ├── patternPrimary
#     │                                       │       │   └── identifier
#     │                                       │       │       └── D
#     │                                       │       └── patternQuantifier
#     │                                       │           └── ?
#     │                                       ├── )
#     │                                       ├── SUBSET
#     │                                       ├── subsetDefinition
#     │                                       │   ├── identifier
#     │                                       │   │   └── PRICE_TREND
#     │                                       │   ├── =
#     │                                       │   ├── (
#     │                                       │   ├── identifier
#     │                                       │   │   └── B
#     │                                       │   ├── ,
#     │                                       │   ├── identifier
#     │                                       │   │   └── C
#     │                                       │   └── )
#     │                                       ├── DEFINE
#     │                                       ├── variableDefinition
#     │                                       │   ├── identifier
#     │                                       │   │   └── A
#     │                                       │   ├── AS
#     │                                       │   └── expression
#     │                                       │       └── booleanExpression
#     │                                       │           ├── valueExpression
#     │                                       │           │   └── primaryExpression
#     │                                       │           │       └── identifier
#     │                                       │           │           └── price
#     │                                       │           └── predicate_
#     │                                       │               ├── comparisonOperator
#     │                                       │               │   └── <
#     │                                       │               └── valueExpression
#     │                                       │                   └── primaryExpression
#     │                                       │                       ├── qualifiedName
#     │                                       │                       │   └── identifier
#     │                                       │                       │       └── PREV
#     │                                       │                       ├── (
#     │                                       │                       ├── expression
#     │                                       │                       │   └── booleanExpression
#     │                                       │                       │       └── valueExpression
#     │                                       │                       │           └── primaryExpression
#     │                                       │                       │               └── identifier
#     │                                       │                       │                   └── price
#     │                                       │                       └── )
#     │                                       ├── ,
#     │                                       ├── variableDefinition
#     │                                       │   ├── identifier
#     │                                       │   │   └── B
#     │                                       │   ├── AS
#     │                                       │   └── expression
#     │                                       │       └── booleanExpression
#     │                                       │           ├── valueExpression
#     │                                       │           │   └── primaryExpression
#     │                                       │           │       └── identifier
#     │                                       │           │           └── price
#     │                                       │           └── predicate_
#     │                                       │               ├── comparisonOperator
#     │                                       │               │   └── >
#     │                                       │               └── valueExpression
#     │                                       │                   └── primaryExpression
#     │                                       │                       ├── qualifiedName
#     │                                       │                       │   └── identifier
#     │                                       │                       │       └── PREV
#     │                                       │                       ├── (
#     │                                       │                       ├── expression
#     │                                       │                       │   └── booleanExpression
#     │                                       │                       │       └── valueExpression
#     │                                       │                       │           └── primaryExpression
#     │                                       │                       │               └── identifier
#     │                                       │                       │                   └── price
#     │                                       │                       └── )
#     │                                       ├── ,
#     │                                       ├── variableDefinition
#     │                                       │   ├── identifier
#     │                                       │   │   └── C
#     │                                       │   ├── AS
#     │                                       │   └── expression
#     │                                       │       └── booleanExpression
#     │                                       │           ├── valueExpression
#     │                                       │           │   └── primaryExpression
#     │                                       │           │       └── identifier
#     │                                       │           │           └── price
#     │                                       │           └── predicate_
#     │                                       │               ├── comparisonOperator
#     │                                       │               │   └── =
#     │                                       │               └── valueExpression
#     │                                       │                   └── primaryExpression
#     │                                       │                       ├── qualifiedName
#     │                                       │                       │   └── identifier
#     │                                       │                       │       └── PREV
#     │                                       │                       ├── (
#     │                                       │                       ├── expression
#     │                                       │                       │   └── booleanExpression
#     │                                       │                       │       └── valueExpression
#     │                                       │                       │           └── primaryExpression
#     │                                       │                       │               └── identifier
#     │                                       │                       │                   └── price
#     │                                       │                       └── )
#     │                                       ├── ,
#     │                                       ├── variableDefinition
#     │                                       │   ├── identifier
#     │                                       │   │   └── D
#     │                                       │   ├── AS
#     │                                       │   └── expression
#     │                                       │       └── booleanExpression
#     │                                       │           ├── valueExpression
#     │                                       │           │   └── primaryExpression
#     │                                       │           │       └── identifier
#     │                                       │           │           └── price
#     │                                       │           └── predicate_
#     │                                       │               ├── comparisonOperator
#     │                                       │               │   └── >
#     │                                       │               └── valueExpression
#     │                                       │                   └── primaryExpression
#     │                                       │                       ├── qualifiedName
#     │                                       │                       │   └── identifier
#     │                                       │                       │       └── PREV
#     │                                       │                       ├── (
#     │                                       │                       ├── expression
#     │                                       │                       │   └── booleanExpression
#     │                                       │                       │       └── valueExpression
#     │                                       │                       │           └── primaryExpression
#     │                                       │                       │               └── identifier
#     │                                       │                       │                   └── price
#     │                                       │                       └── )
#     │                                       └── )
#     └── ;

# %% [markdown]
# Print Indented Tree Format (More Readable)

# %%
def print_tree(node, parser, indent=0):
    if node.getChildCount() == 0:
        print("  " * indent + node.getText())
    else:
        print("  " * indent + parser.ruleNames[node.getRuleIndex()])
        for i in range(node.getChildCount()):
            print_tree(node.getChild(i), parser, indent + 1)

tree, parser = parse_input(sample)
print_tree(tree, parser)
# Out:
# statements
#   singleStatement
#     statement
#       rootQuery
#         query
#           queryNoWith
#             queryTerm
#               queryPrimary
#                 querySpecification
#                   SELECT
#                   selectItem
#                     *
#                   FROM
#                   relation
#                     sampledRelation
#                       patternRecognition
#                         aliasedRelation
#                           relationPrimary
#                             qualifiedName
#                               identifier
#                                 nonReserved
#                                   data
#                         MATCH_RECOGNIZE
#                         (
#                         PARTITION
#                         BY
#                         expression
#                           booleanExpression
#                             valueExpression
#                               primaryExpression
#                                 identifier
#                                   ticker
#                         ORDER
#                         BY
#                         sortItem
#                           expression
#                             booleanExpression
#                               valueExpression
#                                 primaryExpression
#                                   identifier
#                                     ts
#                         MEASURES
#                         measureDefinition
#                           expression
#                             booleanExpression
#                               valueExpression
#                                 primaryExpression
#                                   qualifiedName
#                                     identifier
#                                       nonReserved
#                                         FIRST
#                                   (
#                                   expression
#                                     booleanExpression
#                                       valueExpression
#                                         primaryExpression
#                                           identifier
#                                             price
#                                   )
#                           AS
#                           identifier
#                             start_price
#                         ,
#                         measureDefinition
#                           expression
#                             booleanExpression
#                               valueExpression
#                                 primaryExpression
#                                   qualifiedName
#                                     identifier
#                                       nonReserved
#                                         LAST
#                                   (
#                                   expression
#                                     booleanExpression
#                                       valueExpression
#                                         primaryExpression
#                                           primaryExpression
#                                             identifier
#                                               A
#                                           .
#                                           identifier
#                                             price
#                                   )
#                           AS
#                           identifier
#                             bottom_price
#                         ,
#                         measureDefinition
#                           expression
#                             booleanExpression
#                               valueExpression
#                                 primaryExpression
#                                   qualifiedName
#                                     identifier
#                                       nonReserved
#                                         LAST
#                                   (
#                                   expression
#                                     booleanExpression
#                                       valueExpression
#                                         primaryExpression
#                                           identifier
#                                             price
#                                   )
#                           AS
#                           identifier
#                             end_price
#                         ,
#                         measureDefinition
#                           expression
#                             booleanExpression
#                               valueExpression
#                                 primaryExpression
#                                   qualifiedName
#                                     identifier
#                                       nonReserved
#                                         COUNT
#                                   (
#                                   *
#                                   )
#                           AS
#                           identifier
#                             pattern_length
#                         ,
#                         measureDefinition
#                           expression
#                             booleanExpression
#                               valueExpression
#                                 primaryExpression
#                                   qualifiedName
#                                     identifier
#                                       CLASSIFIER
#                                   (
#                                   )
#                           AS
#                           identifier
#                             pattern_var
#                         ,
#                         measureDefinition
#                           expression
#                             booleanExpression
#                               valueExpression
#                                 primaryExpression
#                                   qualifiedName
#                                     identifier
#                                       MATCH_NUMBER
#                                   (
#                                   )
#                           AS
#                           identifier
#                             match_num
#                         ,
#                         measureDefinition
#                           expression
#                             booleanExpression
#                               valueExpression
#                                 primaryExpression
#                                   processingMode
#                                     RUNNING
#                                   qualifiedName
#                                     identifier
#                                       AVG
#                                   (
#                                   expression
#                                     booleanExpression
#                                       valueExpression
#                                         primaryExpression
#                                           identifier
#                                             volume
#                                   )
#                           AS
#                           identifier
#                             avg_volume
#                         ,
#                         measureDefinition
#                           expression
#                             booleanExpression
#                               valueExpression
#                                 primaryExpression
#                                   processingMode
#                                     FINAL
#                                   qualifiedName
#                                     identifier
#                                       MAX
#                                   (
#                                   expression
#                                     booleanExpression
#                                       valueExpression
#                                         primaryExpression
#                                           identifier
#                                             volume
#                                   )
#                           AS
#                           identifier
#                             max_volume
#                         rowsPerMatch
#                           ONE
#                           ROW
#                           PER
#                           MATCH
#                         PATTERN
#                         (
#                         rowPattern
#                           rowPattern
#                             rowPattern
#                               patternPrimary
#                                 identifier
#                                   A
#                               patternQuantifier
#                                 +
#                             rowPattern
#                               patternPrimary
#                                 (
#                                 rowPattern
#                                   rowPattern
#                                     patternPrimary
#                                       identifier
#                                         B
#                                   |
#                                   rowPattern
#                                     patternPrimary
#                                       identifier
#                                         C
#                                 )
#                           rowPattern
#                             patternPrimary
#                               identifier
#                                 D
#                             patternQuantifier
#                               ?
#                         )
#                         SUBSET
#                         subsetDefinition
#                           identifier
#                             PRICE_TREND
#                           =
#                           (
#                           identifier
#                             B
#                           ,
#                           identifier
#                             C
#                           )
#                         DEFINE
#                         variableDefinition
#                           identifier
#                             A
#                           AS
#                           expression
#                             booleanExpression
#                               valueExpression
#                                 primaryExpression
#                                   identifier
#                                     price
#                               predicate_
#                                 comparisonOperator
#                                   <
#                                 valueExpression
#                                   primaryExpression
#                                     qualifiedName
#                                       identifier
#                                         PREV
#                                     (
#                                     expression
#                                       booleanExpression
#                                         valueExpression
#                                           primaryExpression
#                                             identifier
#                                               price
#                                     )
#                         ,
#                         variableDefinition
#                           identifier
#                             B
#                           AS
#                           expression
#                             booleanExpression
#                               valueExpression
#                                 primaryExpression
#                                   identifier
#                                     price
#                               predicate_
#                                 comparisonOperator
#                                   >
#                                 valueExpression
#                                   primaryExpression
#                                     qualifiedName
#                                       identifier
#                                         PREV
#                                     (
#                                     expression
#                                       booleanExpression
#                                         valueExpression
#                                           primaryExpression
#                                             identifier
#                                               price
#                                     )
#                         ,
#                         variableDefinition
#                           identifier
#                             C
#                           AS
#                           expression
#                             booleanExpression
#                               valueExpression
#                                 primaryExpression
#                                   identifier
#                                     price
#                               predicate_
#                                 comparisonOperator
#                                   =
#                                 valueExpression
#                                   primaryExpression
#                                     qualifiedName
#                                       identifier
#                                         PREV
#                                     (
#                                     expression
#                                       booleanExpression
#                                         valueExpression
#                                           primaryExpression
#                                             identifier
#                                               price
#                                     )
#                         ,
#                         variableDefinition
#                           identifier
#                             D
#                           AS
#                           expression
#                             booleanExpression
#                               valueExpression
#                                 primaryExpression
#                                   identifier
#                                     price
#                               predicate_
#                                 comparisonOperator
#                                   >
#                                 valueExpression
#                                   primaryExpression
#                                     qualifiedName
#                                       identifier
#                                         PREV
#                                     (
#                                     expression
#                                       booleanExpression
#                                         valueExpression
#                                           primaryExpression
#                                             identifier
#                                               price
#                                     )
#                         )
#     ;

# %%
from antlr4.error.ErrorListener import ErrorListener

class CustomErrorListener(ErrorListener):
    def __init__(self):
        super(CustomErrorListener, self).__init__()
        self.errors = []

    def syntaxError(self, recognizer, offendingSymbol, line, column, msg, e):
        self.errors.append(f"Syntax error at {line}:{column} - {msg}")

    def has_errors(self):
        return len(self.errors) > 0

def parse_input(input_text):
    input_stream = InputStream(input_text)
    lexer = TrinoLexer(input_stream)
    stream = CommonTokenStream(lexer)
    parser = TrinoParser(stream)

    error_listener = CustomErrorListener()
    parser.removeErrorListeners()
    parser.addErrorListener(error_listener)

    tree = parser.statements()  # Use correct entry rule

    if error_listener.has_errors():
        print("Errors detected in SQL:")
        for err in error_listener.errors:
            print(err)
        return None, None  # Return None if errors exist

    return tree, parser

# %%
sample = "SELECT FROM data WHERE price > 10"  # Missing column names
tree, parser = parse_input(sample)
# Out:
# Errors detected in SQL:
# Syntax error at 1:7 - extraneous input 'FROM' expecting {'ABSENT', 'ADD', 'ADMIN', 'AFTER', 'ALL', 'ANALYZE', 'ANY', 'ARRAY', 'ASC', 'AT', 'AUTHORIZATION', 'BEGIN', 'BERNOULLI', 'BOTH', 'CALL', 'CALLED', 'CASCADE', 'CASE', 'CAST', 'CATALOG', 'CATALOGS', 'COLUMN', 'COLUMNS', 'COMMENT', 'COMMIT', 'COMMITTED', 'CONDITIONAL', 'COUNT', 'COPARTITION', 'CURRENT', 'CURRENT_CATALOG', 'CURRENT_DATE', 'CURRENT_PATH', 'CURRENT_SCHEMA', 'CURRENT_TIME', 'CURRENT_TIMESTAMP', 'CURRENT_USER', 'DATA', 'DATE', 'DAY', 'DECLARE', 'DEFAULT', 'DEFINE', 'DEFINER', 'DENY', 'DESC', 'DESCRIPTOR', 'DETERMINISTIC', 'DISTINCT', 'DISTRIBUTED', 'DO', 'DOUBLE', 'EMPTY', 'ELSEIF', 'ENCODING', 'ERROR', 'EXCLUDING', 'EXISTS', 'EXPLAIN', 'EXTRACT', 'FALSE', 'FETCH', 'FILTER', 'FINAL', 'FIRST', 'FOLLOWING', 'FORMAT', 'FUNCTION', 'FUNCTIONS', 'GRACE', 'GRANT', 'GRANTED', 'GRANTS', 'GRAPHVIZ', 'GROUPING', 'GROUPS', 'HOUR', 'IF', 'IGNORE', 'IMMEDIATE', 'INCLUDING', 'INITIAL', 'INPUT', 'INTERVAL', 'INVOKER', 'IO', 'ISOLATION', 'ITERATE', 'JSON', 'JSON_ARRAY', 'JSON_EXISTS', 'JSON_OBJECT', 'JSON_QUERY', 'JSON_VALUE', 'KEEP', 'KEY', 'KEYS', 'LANGUAGE', 'LAST', 'LATERAL', 'LEADING', 'LEAVE', 'LEVEL', 'LIMIT', 'LISTAGG', 'LOCAL', 'LOCALTIME', 'LOCALTIMESTAMP', 'LOGICAL', 'LOOP', 'MAP', 'MATCH', 'MATCHED', 'MATCHES', 'MATCH_RECOGNIZE', 'MATERIALIZED', 'MEASURES', 'MERGE', 'MINUTE', 'MONTH', 'NESTED', 'NEXT', 'NFC', 'NFD', 'NFKC', 'NFKD', 'NO', 'NONE', 'NORMALIZE', 'NOT', 'NULL', 'NULLIF', 'NULLS', 'OBJECT', 'OF', 'OFFSET', 'OMIT', 'ONE', 'ONLY', 'OPTION', 'ORDINALITY', 'OUTPUT', 'OVER', 'OVERFLOW', 'PARTITION', 'PARTITIONS', 'PASSING', 'PAST', 'PATH', 'PATTERN', 'PER', 'PERIOD', 'PERMUTE', 'PLAN', 'POSITION', 'PRECEDING', 'PRECISION', 'PRIVILEGES', 'PROPERTIES', 'PRUNE', 'QUOTES', 'RANGE', 'READ', 'REFRESH', 'RENAME', 'REPEAT', 'REPEATABLE', 'REPLACE', 'RESET', 'RESPECT', 'RESTRICT', 'RETURN', 'RETURNING', 'RETURNS', 'REVOKE', 'ROLE', 'ROLES', 'ROLLBACK', 'ROW', 'ROWS', 'RUNNING', 'SCALAR', 'SCHEMA', 'SCHEMAS', 'SECOND', 'SECURITY', 'SEEK', 'SERIALIZABLE', 'SESSION', 'SET', 'SETS', 'SHOW', 'SOME', 'START', 'STATS', 'SUBSET', 'SUBSTRING', 'SYSTEM', 'TABLES', 'TABLESAMPLE', 'TEXT', 'STRING', 'TIES', 'TIME', 'TIMESTAMP', 'TO', 'TRAILING', 'TRANSACTION', 'TRIM', 'TRUE', 'TRUNCATE', 'TRY_CAST', 'TYPE', 'UNBOUNDED', 'UNCOMMITTED', 'UNCONDITIONAL', 'UNIQUE', 'UNKNOWN', 'UNMATCHED', 'UNTIL', 'UPDATE', 'USE', 'USER', 'UTF16', 'UTF32', 'UTF8', 'VALIDATE', 'VALUE', 'VERBOSE', 'VERSION', 'VIEW', 'WHILE', 'WINDOW', 'WITHIN', 'WITHOUT', 'WORK', 'WRAPPER', 'WRITE', 'YEAR', 'ZONE', '+', '-', '*', '?', '(', STRING_, UNICODE_STRING_, BINARY_LITERAL_, INTEGER_VALUE_, DECIMAL_VALUE_, DOUBLE_VALUE_, IDENTIFIER_, DIGIT_IDENTIFIER_, QUOTED_IDENTIFIER_, BACKQUOTED_IDENTIFIER_}
# Syntax error at 1:33 - missing ';' at '<EOF>'
