# %%
import pandas as pd
from src.executor.match_recognize import match_recognize

# Create test data with different permutation patterns
data = [
    # Sequence 1: Has A-B-C pattern
    {"id": 1, "seq": 1, "step": 1, "event_type": "start", "value": 100},  # A
    {"id": 2, "seq": 1, "step": 2, "event_type": "middle", "value": 200}, # B
    {"id": 3, "seq": 1, "step": 3, "event_type": "end", "value": 300},    # C
    
    # Sequence 2: Has B-A-C pattern
    {"id": 4, "seq": 2, "step": 1, "event_type": "middle", "value": 250}, # B
    {"id": 5, "seq": 2, "step": 2, "event_type": "start", "value": 150},  # A
    {"id": 6, "seq": 2, "step": 3, "event_type": "end", "value": 350},    # C
    
    # Sequence 3: Has A-C-B pattern
    {"id": 7, "seq": 3, "step": 1, "event_type": "start", "value": 175},  # A
    {"id": 8, "seq": 3, "step": 2, "event_type": "end", "value": 275},    # C
    {"id": 9, "seq": 3, "step": 3, "event_type": "middle", "value": 375}, # B
    
    # Sequence 4: Has C-B-A pattern
    {"id": 10, "seq": 4, "step": 1, "event_type": "end", "value": 225},   # C
    {"id": 11, "seq": 4, "step": 2, "event_type": "middle", "value": 325}, # B
    {"id": 12, "seq": 4, "step": 3, "event_type": "start", "value": 425},  # A
]

df = pd.DataFrame(data)

print("Testing PERMUTE Patterns\n")

# Test 1: Basic PERMUTE - Match any order of A, B, C
query_basic_permute = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        A.value AS a_value,
        B.value AS b_value,
        C.value AS c_value
    ONE ROW PER MATCH
    PATTERN (PERMUTE(A, B, C))
    DEFINE 
        A AS event_type = 'start',
        B AS event_type = 'middle',
        C AS event_type = 'end'
);
"""

print("Test 1: Basic PERMUTE - Should match all sequences with A, B, C in any order")
output_df = match_recognize(query_basic_permute, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, A.value AS a_value, B.value AS b_value, C.value AS c_value ONE ROW PER MATCH PATTERN (PERMUTE(A, B, C)) DEFINE A AS event_type = 'start', B AS event_type = 'middle', C AS event_type = 'end' );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='A.value', alias='a_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='B.value', alias='b_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='C.value', alias='c_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['C', 'B', 'A'], 'base_variables': ['C', 'B', 'A'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B, C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C'], 'permute': True, 'nested_permute': False})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start'"), Define(variable='B', condition="event_type = 'middle'"), Define(variable='C', condition="event_type = 'end'")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['C', 'B', 'A'], 'base_variables': ['C', 'B', 'A'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.value
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: B.value
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: C.value
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# Testing PERMUTE Patterns
#
# Test 1: Basic PERMUTE - Should match all sequences with A, B, C in any order
# Pattern value: 'PERMUTE(A, B, C)'
# Pattern value: 'PERMUTE(A, B, C)'
# Raw rows_per_match text: ONEROWPERMATCH
# Using rows_per_match mode: RowsPerMatch.ONE_ROW
# Measure semantics: {'pattern_var': 'FINAL', 'match_num': 'FINAL', 'a_value': 'RUNNING', 'b_value': 'RUNNING', 'c_value': 'RUNNING'}
# Match config: rows_per_match=RowsPerMatch.ONE_ROW, all_rows=False
# Creating transition for variable 'A' with condition: 'event_type = 'start''
# Creating transition for variable 'B' with condition: 'event_type = 'middle''
# Creating transition for variable 'C' with condition: 'event_type = 'end''
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['A', 'B']
# Testing row 2, data: {'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['A', 'B', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 3, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 3, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to C from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting a_value to 100 from evaluator
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting b_value to 200 from evaluator
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting c_value to 300 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'A': [0], 'B': [1], 'C': [2]}
#
# Result row:
# pattern_var: C
# match_num: 1
# a_value: 100
# b_value: 200
# c_value: 300
# Find matches completed in 0.003003 seconds
# Creating transition for variable 'A' with condition: 'event_type = 'start''
# Creating transition for variable 'B' with condition: 'event_type = 'middle''
# Creating transition for variable 'C' with condition: 'event_type = 'end''
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 0 to variable B
# Reached accepting state 2 at row 0
#   Current longest match: 0-0, vars: ['B']
# Testing row 1, data: {'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 1 to variable A
# Reached accepting state 1 at row 1
#   Current longest match: 0-1, vars: ['B', 'A']
# Testing row 2, data: {'id': 6, 'seq': 2, 'step': 3, 'event_type': 'end', 'value': 350}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['B', 'A', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 3, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 3, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to C from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting a_value to 150 from evaluator
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting b_value to 250 from evaluator
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting c_value to 350 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'B': [0], 'A': [1], 'C': [2]}
#
# Result row:
# pattern_var: C
# match_num: 1
# a_value: 150
# b_value: 250
# c_value: 350
# Find matches completed in 0.000691 seconds
# Creating transition for variable 'A' with condition: 'event_type = 'start''
# Creating transition for variable 'B' with condition: 'event_type = 'middle''
# Creating transition for variable 'C' with condition: 'event_type = 'end''
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 7, 'seq': 3, 'step': 1, 'event_type': 'start', 'value': 175}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 8, 'seq': 3, 'step': 2, 'event_type': 'end', 'value': 275}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 1 to variable C
# Reached accepting state 3 at row 1
#   Current longest match: 0-1, vars: ['A', 'C']
# Testing row 2, data: {'id': 9, 'seq': 3, 'step': 3, 'event_type': 'middle', 'value': 375}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 2 to variable B
# Reached accepting state 2 at row 2
#   Current longest match: 0-2, vars: ['A', 'C', 'B']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'C': [1], 'B': [2]}, 'state': 2, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'C': [1], 'B': [2]}, 'state': 2, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to B from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting a_value to 175 from evaluator
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting b_value to 375 from evaluator
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting c_value to 275 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'A': [0], 'C': [1], 'B': [2]}
#
# Result row:
# pattern_var: B
# match_num: 1
# a_value: 175
# b_value: 375
# c_value: 275
# Find matches completed in 0.000554 seconds
# Creating transition for variable 'A' with condition: 'event_type = 'start''
# Creating transition for variable 'B' with condition: 'event_type = 'middle''
# Creating transition for variable 'C' with condition: 'event_type = 'end''
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 10, 'seq': 4, 'step': 1, 'event_type': 'end', 'value': 225}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 0 to variable C
# Reached accepting state 3 at row 0
#   Current longest match: 0-0, vars: ['C']
# Testing row 1, data: {'id': 11, 'seq': 4, 'step': 2, 'event_type': 'middle', 'value': 325}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['C', 'B']
# Testing row 2, data: {'id': 12, 'seq': 4, 'step': 3, 'event_type': 'start', 'value': 425}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 2 to variable A
# Reached accepting state 1 at row 2
#   Current longest match: 0-2, vars: ['C', 'B', 'A']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'C': [0], 'B': [1], 'A': [2]}, 'state': 1, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'C': [0], 'B': [1], 'A': [2]}, 'state': 1, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to A from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting a_value to 425 from evaluator
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting b_value to 325 from evaluator
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting c_value to 225 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'C': [0], 'B': [1], 'A': [2]}
#
# Result row:
# pattern_var: A
# match_num: 1
# a_value: 425
# b_value: 325
# c_value: 225
# Find matches completed in 0.000680 seconds
#
# Match data:
# Match number: 1 (Partition: seq=1)
# Global indices - Start: 0, End: 2
# Local indices within partition - Start: 0, End: 2
# Variables: {'A': [0], 'B': [1], 'C': [2]}
#   Variable A assigned to rows (global indices): [0]
#     Row 0: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
#   Variable B assigned to rows (global indices): [1]
#     Row 1: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
#   Variable C assigned to rows (global indices): [2]
#     Row 2: {'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
# Match number: 1 (Partition: seq=2)
# Global indices - Start: 3, End: 5
# Local indices within partition - Start: 2, End: 4
# Variables: {'B': [3], 'A': [4], 'C': [5]}
#   Variable B assigned to rows (global indices): [3]
#     Row 3: {'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
#   Variable A assigned to rows (global indices): [4]
#     Row 4: {'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
#   Variable C assigned to rows (global indices): [5]
#     Row 5: {'id': 6, 'seq': 2, 'step': 3, 'event_type': 'end', 'value': 350}
# Match number: 1 (Partition: seq=3)
# Global indices - Start: 6, End: 8
# Local indices within partition - Start: 5, End: 7
# Variables: {'A': [6], 'C': [7], 'B': [8]}
#   Variable A assigned to rows (global indices): [6]
#     Row 6: {'id': 7, 'seq': 3, 'step': 1, 'event_type': 'start', 'value': 175}
#   Variable C assigned to rows (global indices): [7]
#     Row 7: {'id': 8, 'seq': 3, 'step': 2, 'event_type': 'end', 'value': 275}
#   Variable B assigned to rows (global indices): [8]
#     Row 8: {'id': 9, 'seq': 3, 'step': 3, 'event_type': 'middle', 'value': 375}
# Match number: 1 (Partition: seq=4)
# Global indices - Start: 9, End: 11
# Local indices within partition - Start: 8, End: 10
# Variables: {'C': [9], 'B': [10], 'A': [11]}
#   Variable C assigned to rows (global indices): [9]
#     Row 9: {'id': 10, 'seq': 4, 'step': 1, 'event_type': 'end', 'value': 225}
#   Variable B assigned to rows (global indices): [10]
#     Row 10: {'id': 11, 'seq': 4, 'step': 2, 'event_type': 'middle', 'value': 325}
#   Variable A assigned to rows (global indices): [11]
#     Row 11: {'id': 12, 'seq': 4, 'step': 3, 'event_type': 'start', 'value': 425}
# PERMUTE pattern detected, validating navigation functions...
# After filtering: 4 valid matches
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Setting pattern_var to C from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Setting a_value to 100 from evaluator
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Setting b_value to 200 from evaluator
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Setting c_value to 300 from evaluator
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Setting pattern_var to C from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Setting match_num to 1 from evaluator
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Setting a_value to 150 from evaluator
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Setting b_value to 250 from evaluator
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Setting c_value to 350 from evaluator
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Setting pattern_var to B from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Setting match_num to 1 from evaluator
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Setting a_value to 175 from evaluator
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Setting b_value to 375 from evaluator
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Setting c_value to 275 from evaluator
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Setting pattern_var to A from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Setting match_num to 1 from evaluator
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Setting a_value to 425 from evaluator
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Setting b_value to 325 from evaluator
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Setting c_value to 225 from evaluator
# Sorting by sequence column: 'seq'
# Pattern variable column found: 'pattern_var'
# Sorting by pattern variable first, then by sequence
# Sorting by columns: ['seq']
#    seq pattern_var  match_num  a_value  b_value  c_value
# 0    1           C          1      100      200      300
# 1    2           C          1      150      250      350
# 2    3           B          1      175      375      275
# 3    4           A          1      425      325      225

# %%
import pandas as pd
from src.executor.match_recognize import match_recognize

# Create test data with different permutation patterns
data = [
    # Sequence 1: Has A-B-C pattern
    {"id": 1, "seq": 1, "step": 1, "event_type": "start", "value": 100},  # A
    {"id": 2, "seq": 1, "step": 2, "event_type": "middle", "value": 200}, # B
    {"id": 3, "seq": 1, "step": 3, "event_type": "end", "value": 300},    # C
    
    # Sequence 2: Has B-A-C pattern
    {"id": 4, "seq": 2, "step": 1, "event_type": "middle", "value": 250}, # B
    {"id": 5, "seq": 2, "step": 2, "event_type": "start", "value": 150},  # A
    {"id": 6, "seq": 2, "step": 3, "event_type": "end", "value": 350},    # C
    
    # Sequence 3: Has A-C-B pattern
    {"id": 7, "seq": 3, "step": 1, "event_type": "start", "value": 175},  # A
    {"id": 8, "seq": 3, "step": 2, "event_type": "end", "value": 275},    # C
    {"id": 9, "seq": 3, "step": 3, "event_type": "middle", "value": 375}, # B
    
    # Sequence 4: Has C-B-A pattern
    {"id": 10, "seq": 4, "step": 1, "event_type": "end", "value": 225},   # C
    {"id": 11, "seq": 4, "step": 2, "event_type": "middle", "value": 325}, # B
    {"id": 12, "seq": 4, "step": 3, "event_type": "start", "value": 425},  # A
]

df = pd.DataFrame(data)

print("Testing PERMUTE Patterns\n")
# Test 5: Nested PERMUTE patterns
query_nested_permute = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        A.value AS a_value,
        B.value AS b_value,
        C.value AS c_value
    ALL ROWs PER MATCH
    PATTERN (PERMUTE(A, PERMUTE(B, C)))
    DEFINE 
        A AS event_type = 'start',
        B AS event_type = 'middle',
        C AS event_type = 'end'
);
"""

print("Test 5: Nested PERMUTE - Testing nested permutation patterns")
output_df = match_recognize(query_nested_permute, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, A.value AS a_value, B.value AS b_value, C.value AS c_value ALL ROWs PER MATCH PATTERN (PERMUTE(A, PERMUTE(B, C))) DEFINE A AS event_type = 'start', B AS event_type = 'middle', C AS event_type = 'end' );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='A.value', alias='a_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='B.value', alias='b_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='C.value', alias='c_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALLROWsPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['C', 'B', 'A'], 'base_variables': ['C', 'B', 'A'], 'permute': True, 'nested_permute': True}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, PERMUTE(B, C))
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, PERMUTE(B, C))', metadata={'variables': ['A', 'PERMUTE(B', 'C'], 'base_variables': ['A', 'PERMUTE(B', 'C'], 'permute': True, 'nested_permute': True})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start'"), Define(variable='B', condition="event_type = 'middle'"), Define(variable='C', condition="event_type = 'end'")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['C', 'B', 'A'], 'base_variables': ['C', 'B', 'A'], 'permute': True, 'nested_permute': True}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, PERMUTE(B, C))
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.value
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: B.value
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: C.value
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# Testing PERMUTE Patterns
#
# Test 5: Nested PERMUTE - Testing nested permutation patterns
# Pattern value: 'PERMUTE(A, PERMUTE(B, C))'
# Pattern value: 'PERMUTE(A, PERMUTE(B, C))'
# Creating transition for variable 'A' with condition: 'event_type = 'start''
# Creating transition for variable 'B' with condition: 'event_type = 'middle''
# Creating transition for variable 'C' with condition: 'event_type = 'end''
# Find matches with all_rows=True, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['A', 'B']
# Testing row 2, data: {'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['A', 'B', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 3, 'is_empty': False}
# Processing match 1 with ALL ROWS PER MATCH
# Variables in exclusion pattern: set()
# Processing match 1, included indices: [0, 1, 2]
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure pattern_var for row 0 with RUNNING semantics: A
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure match_num for row 0 with RUNNING semantics: 1
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure a_value for row 0 with RUNNING semantics: 100
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure b_value for row 0 with RUNNING semantics: 200
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure c_value for row 0 with RUNNING semantics: 300
# Added row 0 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure pattern_var for row 1 with RUNNING semantics: B
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure match_num for row 1 with RUNNING semantics: 1
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure a_value for row 1 with RUNNING semantics: 100
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure b_value for row 1 with RUNNING semantics: 200
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure c_value for row 1 with RUNNING semantics: 300
# Added row 1 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure pattern_var for row 2 with RUNNING semantics: C
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure match_num for row 2 with RUNNING semantics: 1
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure a_value for row 2 with RUNNING semantics: 100
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure b_value for row 2 with RUNNING semantics: 200
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure c_value for row 2 with RUNNING semantics: 300
# Added row 2 to results
# Measure evaluation timings:
#   pattern_var: 0.000087 seconds
#   match_num: 0.000052 seconds
#   a_value: 0.000053 seconds
#   b_value: 0.000050 seconds
#   c_value: 0.000049 seconds
# Find matches completed in 0.000630 seconds
# Find matches with all_rows=True, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 0 to variable B
# Reached accepting state 2 at row 0
#   Current longest match: 0-0, vars: ['B']
# Testing row 1, data: {'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 1 to variable A
# Reached accepting state 1 at row 1
#   Current longest match: 0-1, vars: ['B', 'A']
# Testing row 2, data: {'id': 6, 'seq': 2, 'step': 3, 'event_type': 'end', 'value': 350}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['B', 'A', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 3, 'is_empty': False}
# Processing match 1 with ALL ROWS PER MATCH
# Variables in exclusion pattern: set()
# Processing match 1, included indices: [0, 1, 2]
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure pattern_var for row 0 with RUNNING semantics: B
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure match_num for row 0 with RUNNING semantics: 1
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure a_value for row 0 with RUNNING semantics: 150
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure b_value for row 0 with RUNNING semantics: 250
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure c_value for row 0 with RUNNING semantics: 350
# Added row 0 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure pattern_var for row 1 with RUNNING semantics: A
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure match_num for row 1 with RUNNING semantics: 1
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure a_value for row 1 with RUNNING semantics: 150
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure b_value for row 1 with RUNNING semantics: 250
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure c_value for row 1 with RUNNING semantics: 350
# Added row 1 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure pattern_var for row 2 with RUNNING semantics: C
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure match_num for row 2 with RUNNING semantics: 1
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure a_value for row 2 with RUNNING semantics: 150
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure b_value for row 2 with RUNNING semantics: 250
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure c_value for row 2 with RUNNING semantics: 350
# Added row 2 to results
# Measure evaluation timings:
#   pattern_var: 0.000063 seconds
#   match_num: 0.000053 seconds
#   a_value: 0.000054 seconds
#   b_value: 0.000054 seconds
#   c_value: 0.000053 seconds
# Find matches completed in 0.000594 seconds
# Find matches with all_rows=True, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 7, 'seq': 3, 'step': 1, 'event_type': 'start', 'value': 175}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 8, 'seq': 3, 'step': 2, 'event_type': 'end', 'value': 275}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 1 to variable C
# Reached accepting state 3 at row 1
#   Current longest match: 0-1, vars: ['A', 'C']
# Testing row 2, data: {'id': 9, 'seq': 3, 'step': 3, 'event_type': 'middle', 'value': 375}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 2 to variable B
# Reached accepting state 2 at row 2
#   Current longest match: 0-2, vars: ['A', 'C', 'B']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'C': [1], 'B': [2]}, 'state': 2, 'is_empty': False}
# Processing match 1 with ALL ROWS PER MATCH
# Variables in exclusion pattern: set()
# Processing match 1, included indices: [0, 1, 2]
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure pattern_var for row 0 with RUNNING semantics: A
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure match_num for row 0 with RUNNING semantics: 1
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure a_value for row 0 with RUNNING semantics: 175
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure b_value for row 0 with RUNNING semantics: 375
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure c_value for row 0 with RUNNING semantics: 275
# Added row 0 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure pattern_var for row 1 with RUNNING semantics: C
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure match_num for row 1 with RUNNING semantics: 1
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure a_value for row 1 with RUNNING semantics: 175
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure b_value for row 1 with RUNNING semantics: 375
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure c_value for row 1 with RUNNING semantics: 275
# Added row 1 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure pattern_var for row 2 with RUNNING semantics: B
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure match_num for row 2 with RUNNING semantics: 1
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure a_value for row 2 with RUNNING semantics: 175
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure b_value for row 2 with RUNNING semantics: 375
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure c_value for row 2 with RUNNING semantics: 275
# Added row 2 to results
# Measure evaluation timings:
#   pattern_var: 0.000072 seconds
#   match_num: 0.000057 seconds
#   a_value: 0.000056 seconds
#   b_value: 0.000053 seconds
#   c_value: 0.000051 seconds
# Find matches completed in 0.000558 seconds
# Find matches with all_rows=True, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 10, 'seq': 4, 'step': 1, 'event_type': 'end', 'value': 225}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 0 to variable C
# Reached accepting state 3 at row 0
#   Current longest match: 0-0, vars: ['C']
# Testing row 1, data: {'id': 11, 'seq': 4, 'step': 2, 'event_type': 'middle', 'value': 325}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['C', 'B']
# Testing row 2, data: {'id': 12, 'seq': 4, 'step': 3, 'event_type': 'start', 'value': 425}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 2 to variable A
# Reached accepting state 1 at row 2
#   Current longest match: 0-2, vars: ['C', 'B', 'A']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'C': [0], 'B': [1], 'A': [2]}, 'state': 1, 'is_empty': False}
# Processing match 1 with ALL ROWS PER MATCH
# Variables in exclusion pattern: set()
# Processing match 1, included indices: [0, 1, 2]
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure pattern_var for row 0 with RUNNING semantics: C
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure match_num for row 0 with RUNNING semantics: 1
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure a_value for row 0 with RUNNING semantics: 425
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure b_value for row 0 with RUNNING semantics: 325
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure c_value for row 0 with RUNNING semantics: 225
# Added row 0 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure pattern_var for row 1 with RUNNING semantics: B
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure match_num for row 1 with RUNNING semantics: 1
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure a_value for row 1 with RUNNING semantics: 425
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure b_value for row 1 with RUNNING semantics: 325
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure c_value for row 1 with RUNNING semantics: 225
# Added row 1 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure pattern_var for row 2 with RUNNING semantics: A
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure match_num for row 2 with RUNNING semantics: 1
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure a_value for row 2 with RUNNING semantics: 425
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure b_value for row 2 with RUNNING semantics: 325
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure c_value for row 2 with RUNNING semantics: 225
# Added row 2 to results
# Measure evaluation timings:
#   pattern_var: 0.000070 seconds
#   match_num: 0.000055 seconds
#   a_value: 0.000055 seconds
#   b_value: 0.000052 seconds
#   c_value: 0.000051 seconds
# Find matches completed in 0.000629 seconds
# Rejecting match with sequence ['B', 'A', 'C']: inner variables ['B', 'C'] are not adjacent
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 0
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 0
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 0
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 1
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 1
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 1
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 1
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 6
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 6
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 6
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 7
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 7
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 7
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 7
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 9
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 9
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 9
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 10
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 10
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 10
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 10
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Query execution metrics: {'parsing_time': 0.011455297470092773, 'automata_build_time': 0.0005474090576171875, 'matching_time': 0.005431175231933594, 'result_processing_time': 0.0016162395477294922, 'total_time': 0.019403934478759766, 'partition_count': 4, 'match_count': 3}
#    seq  step pattern_var  match_num  a_value  b_value  c_value  id event_type  \
# 0    1     1           A          1    100.0      NaN      NaN   1      start
# 1    1     2           B          1    100.0    200.0      NaN   2     middle
# 2    1     3           C          1    100.0    200.0    300.0   3        end
# 3    3     1           A          1    175.0      NaN      NaN   7      start
# 4    3     2           C          1    175.0      NaN    275.0   8        end
# 5    3     3           B          1    175.0    375.0    275.0   9     middle
# 6    4     1           C          1      NaN      NaN    225.0  10        end
# 7    4     2           B          1      NaN    325.0    225.0  11     middle
# 8    4     3           A          1    425.0    325.0    225.0  12      start
#
#    value
# 0    100
# 1    200
# 2    300
# 3    175
# 4    275
# 5    375
# 6    225
# 7    325
# 8    425

# %%
# Test 4: PERMUTE with Subset Variables
query_permute_subset = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        X.value AS x_value,
        Y.value AS y_value
    all ROWs PER MATCH
    PATTERN (PERMUTE(A, B, C))
    SUBSET
        X = (A, B),
        Y = (B, C)
    DEFINE 
        A AS event_type = 'start',
        B AS event_type = 'middle',
        C AS event_type = 'end'
);
"""

print("Test 4: PERMUTE with Subset Variables - Using subset groupings")
output_df = match_recognize(query_permute_subset, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, X.value AS x_value, Y.value AS y_value all ROWs PER MATCH PATTERN (PERMUTE(A, B, C)) SUBSET X = (A, B), Y = (B, C) DEFINE A AS event_type = 'start', B AS event_type = 'middle', C AS event_type = 'end' );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='X.value', alias='x_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='Y.value', alias='y_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: allROWsPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['C', 'B', 'A'], 'base_variables': ['C', 'B', 'A'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B, C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C'], 'permute': True, 'nested_permute': False})
# DEBUG:src.parser.match_recognize_extractor:Extracted SUBSET: [SubsetClause(subset_text='X = (A, B)'), SubsetClause(subset_text='Y = (B, C)')]
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start'"), Define(variable='B', condition="event_type = 'middle'"), Define(variable='C', condition="event_type = 'end'")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['C', 'B', 'A'], 'base_variables': ['C', 'B', 'A'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: X.value
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: Y.value
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# Test 4: PERMUTE with Subset Variables - Using subset groupings
# Pattern value: 'PERMUTE(A, B, C)'
# Extracted subset definition: X = (A, B)
# Extracted subset definition: Y = (B, C)
# Pattern value: 'PERMUTE(A, B, C)'
# Creating transition for variable 'A' with condition: 'event_type = 'start''
# Creating transition for variable 'B' with condition: 'event_type = 'middle''
# Creating transition for variable 'C' with condition: 'event_type = 'end''
# Find matches with all_rows=True, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['A', 'B']
# Testing row 2, data: {'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['A', 'B', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 3, 'is_empty': False}
# Processing match 1 with ALL ROWS PER MATCH
# Variables in exclusion pattern: set()
# Processing match 1, included indices: [0, 1, 2]
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure pattern_var for row 0 with RUNNING semantics: A
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure match_num for row 0 with RUNNING semantics: 1
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure x_value for row 0 with RUNNING semantics: 200
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure y_value for row 0 with RUNNING semantics: 300
# Added row 0 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure pattern_var for row 1 with RUNNING semantics: B
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure match_num for row 1 with RUNNING semantics: 1
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure x_value for row 1 with RUNNING semantics: 200
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure y_value for row 1 with RUNNING semantics: 300
# Added row 1 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure pattern_var for row 2 with RUNNING semantics: C
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure match_num for row 2 with RUNNING semantics: 1
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure x_value for row 2 with RUNNING semantics: 200
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure y_value for row 2 with RUNNING semantics: 300
# Added row 2 to results
# Measure evaluation timings:
#   pattern_var: 0.000108 seconds
#   match_num: 0.000080 seconds
#   x_value: 0.000089 seconds
#   y_value: 0.000082 seconds
# Find matches completed in 0.000760 seconds
# Find matches with all_rows=True, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 0 to variable B
# Reached accepting state 2 at row 0
#   Current longest match: 0-0, vars: ['B']
# Testing row 1, data: {'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 1 to variable A
# Reached accepting state 1 at row 1
#   Current longest match: 0-1, vars: ['B', 'A']
# Testing row 2, data: {'id': 6, 'seq': 2, 'step': 3, 'event_type': 'end', 'value': 350}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['B', 'A', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 3, 'is_empty': False}
# Processing match 1 with ALL ROWS PER MATCH
# Variables in exclusion pattern: set()
# Processing match 1, included indices: [0, 1, 2]
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure pattern_var for row 0 with RUNNING semantics: B
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure match_num for row 0 with RUNNING semantics: 1
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure x_value for row 0 with RUNNING semantics: 150
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure y_value for row 0 with RUNNING semantics: 350
# Added row 0 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure pattern_var for row 1 with RUNNING semantics: A
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure match_num for row 1 with RUNNING semantics: 1
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure x_value for row 1 with RUNNING semantics: 150
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure y_value for row 1 with RUNNING semantics: 350
# Added row 1 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure pattern_var for row 2 with RUNNING semantics: C
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure match_num for row 2 with RUNNING semantics: 1
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure x_value for row 2 with RUNNING semantics: 150
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure y_value for row 2 with RUNNING semantics: 350
# Added row 2 to results
# Measure evaluation timings:
#   pattern_var: 0.000110 seconds
#   match_num: 0.000085 seconds
#   x_value: 0.000093 seconds
#   y_value: 0.000088 seconds
# Find matches completed in 0.000853 seconds
# Find matches with all_rows=True, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 7, 'seq': 3, 'step': 1, 'event_type': 'start', 'value': 175}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 8, 'seq': 3, 'step': 2, 'event_type': 'end', 'value': 275}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 1 to variable C
# Reached accepting state 3 at row 1
#   Current longest match: 0-1, vars: ['A', 'C']
# Testing row 2, data: {'id': 9, 'seq': 3, 'step': 3, 'event_type': 'middle', 'value': 375}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 2 to variable B
# Reached accepting state 2 at row 2
#   Current longest match: 0-2, vars: ['A', 'C', 'B']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'C': [1], 'B': [2]}, 'state': 2, 'is_empty': False}
# Processing match 1 with ALL ROWS PER MATCH
# Variables in exclusion pattern: set()
# Processing match 1, included indices: [0, 1, 2]
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure pattern_var for row 0 with RUNNING semantics: A
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure match_num for row 0 with RUNNING semantics: 1
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure x_value for row 0 with RUNNING semantics: 375
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure y_value for row 0 with RUNNING semantics: 375
# Added row 0 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure pattern_var for row 1 with RUNNING semantics: C
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure match_num for row 1 with RUNNING semantics: 1
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure x_value for row 1 with RUNNING semantics: 375
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure y_value for row 1 with RUNNING semantics: 375
# Added row 1 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure pattern_var for row 2 with RUNNING semantics: B
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure match_num for row 2 with RUNNING semantics: 1
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure x_value for row 2 with RUNNING semantics: 375
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure y_value for row 2 with RUNNING semantics: 375
# Added row 2 to results
# Measure evaluation timings:
#   pattern_var: 0.000098 seconds
#   match_num: 0.000084 seconds
#   x_value: 0.000095 seconds
#   y_value: 0.000093 seconds
# Find matches completed in 0.000768 seconds
# Find matches with all_rows=True, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 10, 'seq': 4, 'step': 1, 'event_type': 'end', 'value': 225}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 0 to variable C
# Reached accepting state 3 at row 0
#   Current longest match: 0-0, vars: ['C']
# Testing row 1, data: {'id': 11, 'seq': 4, 'step': 2, 'event_type': 'middle', 'value': 325}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['C', 'B']
# Testing row 2, data: {'id': 12, 'seq': 4, 'step': 3, 'event_type': 'start', 'value': 425}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 2 to variable A
# Reached accepting state 1 at row 2
#   Current longest match: 0-2, vars: ['C', 'B', 'A']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'C': [0], 'B': [1], 'A': [2]}, 'state': 1, 'is_empty': False}
# Processing match 1 with ALL ROWS PER MATCH
# Variables in exclusion pattern: set()
# Processing match 1, included indices: [0, 1, 2]
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure pattern_var for row 0 with RUNNING semantics: C
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure match_num for row 0 with RUNNING semantics: 1
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure x_value for row 0 with RUNNING semantics: 425
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure y_value for row 0 with RUNNING semantics: 325
# Added row 0 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure pattern_var for row 1 with RUNNING semantics: B
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure match_num for row 1 with RUNNING semantics: 1
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure x_value for row 1 with RUNNING semantics: 425
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure y_value for row 1 with RUNNING semantics: 325
# Added row 1 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure pattern_var for row 2 with RUNNING semantics: A
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure match_num for row 2 with RUNNING semantics: 1
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure x_value for row 2 with RUNNING semantics: 425
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure y_value for row 2 with RUNNING semantics: 325
# Added row 2 to results
# Measure evaluation timings:
#   pattern_var: 0.000111 seconds
#   match_num: 0.000087 seconds
#   x_value: 0.000095 seconds
#   y_value: 0.000092 seconds
# Find matches completed in 0.000946 seconds
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 0
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 0
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 1
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 1
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 3
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 3
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 4
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 4
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 6
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 6
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 7
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 7
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 9
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 9
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 10
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 10
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Query execution metrics: {'parsing_time': 0.013485193252563477, 'automata_build_time': 0.0004210472106933594, 'matching_time': 0.006775617599487305, 'result_processing_time': 0.0026907920837402344, 'total_time': 0.02386951446533203, 'partition_count': 4, 'match_count': 4}
#     seq  step pattern_var  match_num x_value y_value  id event_type  value
# 0     1     1           A          1    None    None   1      start    100
# 1     1     2           B          1    None    None   2     middle    200
# 2     1     3           C          1    None    None   3        end    300
# 3     2     1           B          1    None    None   4     middle    250
# 4     2     2           A          1    None    None   5      start    150
# 5     2     3           C          1    None    None   6        end    350
# 6     3     1           A          1    None    None   7      start    175
# 7     3     2           C          1    None    None   8        end    275
# 8     3     3           B          1    None    None   9     middle    375
# 9     4     1           C          1    None    None  10        end    225
# 10    4     2           B          1    None    None  11     middle    325
# 11    4     3           A          1    None    None  12      start    425

# %%
# Test 2: PERMUTE with Quantifier
query_permute_quantifier = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        FIRST(A.value) AS first_a_value,
        LAST(C.value) AS last_c_value
    ONE ROW PER MATCH
    PATTERN (PERMUTE(A, B, C)+)
    DEFINE 
        A AS event_type = 'start',
        B AS event_type = 'middle',
        C AS event_type = 'end'
);
"""

print("Test 2: PERMUTE with Quantifier - Should match one or more occurrences of permutations")
output_df = match_recognize(query_permute_quantifier, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, FIRST(A.value) AS first_a_value, LAST(C.value) AS last_c_value ONE ROW PER MATCH PATTERN (PERMUTE(A, B, C)+) DEFINE A AS event_type = 'start', B AS event_type = 'middle', C AS event_type = 'end' );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='FIRST(A.value)', alias='first_a_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(C.value)', alias='last_c_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['C', 'B', 'A'], 'base_variables': ['C', 'B', 'A'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B, C)+', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C'], 'permute': True, 'nested_permute': False})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start'"), Define(variable='B', condition="event_type = 'middle'"), Define(variable='C', condition="event_type = 'end'")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['C', 'B', 'A'], 'base_variables': ['C', 'B', 'A'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)+
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: FIRST(A.value)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(C.value)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# Test 2: PERMUTE with Quantifier - Should match one or more occurrences of permutations
# Pattern value: 'PERMUTE(A, B, C)+'
# Pattern value: 'PERMUTE(A, B, C)+'
# Raw rows_per_match text: ONEROWPERMATCH
# Using rows_per_match mode: RowsPerMatch.ONE_ROW
# Measure semantics: {'pattern_var': 'FINAL', 'match_num': 'FINAL', 'first_a_value': 'RUNNING', 'last_c_value': 'RUNNING'}
# Match config: rows_per_match=RowsPerMatch.ONE_ROW, all_rows=False
# Creating transition for variable 'A' with condition: 'event_type = 'start''
# Creating transition for variable 'B' with condition: 'event_type = 'middle''
# Creating transition for variable 'C' with condition: 'event_type = 'end''
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['A', 'B']
# Testing row 2, data: {'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['A', 'B', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 3, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 3, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to C from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: FIRST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: FIRST(A.value)
# Function: FIRST, Args: ['A.value']
# Setting first_a_value to 100 from evaluator
# Evaluating expression: LAST(C.value) with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: LAST(C.value)
# Function: LAST, Args: ['C.value']
# Setting last_c_value to 300 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'A': [0], 'B': [1], 'C': [2]}
#
# Result row:
# pattern_var: C
# match_num: 1
# first_a_value: 100
# last_c_value: 300
# Find matches completed in 0.000609 seconds
# Creating transition for variable 'A' with condition: 'event_type = 'start''
# Creating transition for variable 'B' with condition: 'event_type = 'middle''
# Creating transition for variable 'C' with condition: 'event_type = 'end''
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 0 to variable B
# Reached accepting state 2 at row 0
#   Current longest match: 0-0, vars: ['B']
# Testing row 1, data: {'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 1 to variable A
# Reached accepting state 1 at row 1
#   Current longest match: 0-1, vars: ['B', 'A']
# Testing row 2, data: {'id': 6, 'seq': 2, 'step': 3, 'event_type': 'end', 'value': 350}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['B', 'A', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 3, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 3, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to C from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: FIRST(A.value) with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: FIRST(A.value)
# Function: FIRST, Args: ['A.value']
# Setting first_a_value to 150 from evaluator
# Evaluating expression: LAST(C.value) with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: LAST(C.value)
# Function: LAST, Args: ['C.value']
# Setting last_c_value to 350 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'B': [0], 'A': [1], 'C': [2]}
#
# Result row:
# pattern_var: C
# match_num: 1
# first_a_value: 150
# last_c_value: 350
# Find matches completed in 0.000858 seconds
# Creating transition for variable 'A' with condition: 'event_type = 'start''
# Creating transition for variable 'B' with condition: 'event_type = 'middle''
# Creating transition for variable 'C' with condition: 'event_type = 'end''
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 7, 'seq': 3, 'step': 1, 'event_type': 'start', 'value': 175}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 8, 'seq': 3, 'step': 2, 'event_type': 'end', 'value': 275}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 1 to variable C
# Reached accepting state 3 at row 1
#   Current longest match: 0-1, vars: ['A', 'C']
# Testing row 2, data: {'id': 9, 'seq': 3, 'step': 3, 'event_type': 'middle', 'value': 375}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 2 to variable B
# Reached accepting state 2 at row 2
#   Current longest match: 0-2, vars: ['A', 'C', 'B']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'C': [1], 'B': [2]}, 'state': 2, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'C': [1], 'B': [2]}, 'state': 2, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to B from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: FIRST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: FIRST(A.value)
# Function: FIRST, Args: ['A.value']
# Setting first_a_value to 175 from evaluator
# Evaluating expression: LAST(C.value) with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: LAST(C.value)
# Function: LAST, Args: ['C.value']
# Setting last_c_value to 275 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'A': [0], 'C': [1], 'B': [2]}
#
# Result row:
# pattern_var: B
# match_num: 1
# first_a_value: 175
# last_c_value: 275
# Find matches completed in 0.000495 seconds
# Creating transition for variable 'A' with condition: 'event_type = 'start''
# Creating transition for variable 'B' with condition: 'event_type = 'middle''
# Creating transition for variable 'C' with condition: 'event_type = 'end''
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 10, 'seq': 4, 'step': 1, 'event_type': 'end', 'value': 225}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 0 to variable C
# Reached accepting state 3 at row 0
#   Current longest match: 0-0, vars: ['C']
# Testing row 1, data: {'id': 11, 'seq': 4, 'step': 2, 'event_type': 'middle', 'value': 325}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['C', 'B']
# Testing row 2, data: {'id': 12, 'seq': 4, 'step': 3, 'event_type': 'start', 'value': 425}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 2 to variable A
# Reached accepting state 1 at row 2
#   Current longest match: 0-2, vars: ['C', 'B', 'A']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'C': [0], 'B': [1], 'A': [2]}, 'state': 1, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'C': [0], 'B': [1], 'A': [2]}, 'state': 1, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to A from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: FIRST(A.value) with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: FIRST(A.value)
# Function: FIRST, Args: ['A.value']
# Setting first_a_value to 425 from evaluator
# Evaluating expression: LAST(C.value) with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: LAST(C.value)
# Function: LAST, Args: ['C.value']
# Setting last_c_value to 225 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'C': [0], 'B': [1], 'A': [2]}
#
# Result row:
# pattern_var: A
# match_num: 1
# first_a_value: 425
# last_c_value: 225
# Find matches completed in 0.000732 seconds
#
# Match data:
# Match number: 1 (Partition: seq=1)
# Global indices - Start: 0, End: 2
# Local indices within partition - Start: 0, End: 2
# Variables: {'A': [0], 'B': [1], 'C': [2]}
#   Variable A assigned to rows (global indices): [0]
#     Row 0: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
#   Variable B assigned to rows (global indices): [1]
#     Row 1: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
#   Variable C assigned to rows (global indices): [2]
#     Row 2: {'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
# Match number: 1 (Partition: seq=2)
# Global indices - Start: 3, End: 5
# Local indices within partition - Start: 2, End: 4
# Variables: {'B': [3], 'A': [4], 'C': [5]}
#   Variable B assigned to rows (global indices): [3]
#     Row 3: {'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
#   Variable A assigned to rows (global indices): [4]
#     Row 4: {'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
#   Variable C assigned to rows (global indices): [5]
#     Row 5: {'id': 6, 'seq': 2, 'step': 3, 'event_type': 'end', 'value': 350}
# Match number: 1 (Partition: seq=3)
# Global indices - Start: 6, End: 8
# Local indices within partition - Start: 5, End: 7
# Variables: {'A': [6], 'C': [7], 'B': [8]}
#   Variable A assigned to rows (global indices): [6]
#     Row 6: {'id': 7, 'seq': 3, 'step': 1, 'event_type': 'start', 'value': 175}
#   Variable C assigned to rows (global indices): [7]
#     Row 7: {'id': 8, 'seq': 3, 'step': 2, 'event_type': 'end', 'value': 275}
#   Variable B assigned to rows (global indices): [8]
#     Row 8: {'id': 9, 'seq': 3, 'step': 3, 'event_type': 'middle', 'value': 375}
# Match number: 1 (Partition: seq=4)
# Global indices - Start: 9, End: 11
# Local indices within partition - Start: 8, End: 10
# Variables: {'C': [9], 'B': [10], 'A': [11]}
#   Variable C assigned to rows (global indices): [9]
#     Row 9: {'id': 10, 'seq': 4, 'step': 1, 'event_type': 'end', 'value': 225}
#   Variable B assigned to rows (global indices): [10]
#     Row 10: {'id': 11, 'seq': 4, 'step': 2, 'event_type': 'middle', 'value': 325}
#   Variable A assigned to rows (global indices): [11]
#     Row 11: {'id': 12, 'seq': 4, 'step': 3, 'event_type': 'start', 'value': 425}
# PERMUTE pattern detected, validating navigation functions...
# After filtering: 4 valid matches
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Setting pattern_var to C from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: FIRST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating navigation function: FIRST(A.value)
# Function: FIRST, Args: ['A.value']
# Setting first_a_value to 100 from evaluator
# Evaluating expression: LAST(C.value) with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating navigation function: LAST(C.value)
# Function: LAST, Args: ['C.value']
# Setting last_c_value to 300 from evaluator
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Setting pattern_var to C from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Setting match_num to 1 from evaluator
# Evaluating expression: FIRST(A.value) with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Evaluating navigation function: FIRST(A.value)
# Function: FIRST, Args: ['A.value']
# Setting first_a_value to 150 from evaluator
# Evaluating expression: LAST(C.value) with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Evaluating navigation function: LAST(C.value)
# Function: LAST, Args: ['C.value']
# Setting last_c_value to 350 from evaluator
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Setting pattern_var to B from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Setting match_num to 1 from evaluator
# Evaluating expression: FIRST(A.value) with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating navigation function: FIRST(A.value)
# Function: FIRST, Args: ['A.value']
# Setting first_a_value to 175 from evaluator
# Evaluating expression: LAST(C.value) with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating navigation function: LAST(C.value)
# Function: LAST, Args: ['C.value']
# Setting last_c_value to 275 from evaluator
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Setting pattern_var to A from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Setting match_num to 1 from evaluator
# Evaluating expression: FIRST(A.value) with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating navigation function: FIRST(A.value)
# Function: FIRST, Args: ['A.value']
# Setting first_a_value to 425 from evaluator
# Evaluating expression: LAST(C.value) with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating navigation function: LAST(C.value)
# Function: LAST, Args: ['C.value']
# Setting last_c_value to 225 from evaluator
# Sorting by sequence column: 'seq'
# Pattern variable column found: 'pattern_var'
# Sorting by pattern variable first, then by sequence
# Sorting by columns: ['seq']
#    seq pattern_var  match_num  first_a_value  last_c_value
# 0    1           C          1            100           300
# 1    2           C          1            150           350
# 2    3           B          1            175           275
# 3    4           A          1            425           225

# %%
# Test 3: PERMUTE with ALL ROWS PER MATCH
query_permute_all_rows = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        RUNNING LAST(A.value) AS running_a_value
    ALL ROWS PER MATCH
    PATTERN (PERMUTE(A, B, C))
    DEFINE 
        A AS event_type = 'start',
        B AS event_type = 'middle',
        C AS event_type = 'end'
);
"""

print("Test 3: PERMUTE with ALL ROWS PER MATCH - Shows all matched rows")
output_df = match_recognize(query_permute_all_rows, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, RUNNING LAST(A.value) AS running_a_value ALL ROWS PER MATCH PATTERN (PERMUTE(A, B, C)) DEFINE A AS event_type = 'start', B AS event_type = 'middle', C AS event_type = 'end' );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='LAST(A.value)', alias='running_a_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALLROWSPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ALL ROWS PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['C', 'B', 'A'], 'base_variables': ['C', 'B', 'A'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B, C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C'], 'permute': True, 'nested_permute': False})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start'"), Define(variable='B', condition="event_type = 'middle'"), Define(variable='C', condition="event_type = 'end'")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['C', 'B', 'A'], 'base_variables': ['C', 'B', 'A'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.value)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# Test 3: PERMUTE with ALL ROWS PER MATCH - Shows all matched rows
# Pattern value: 'PERMUTE(A, B, C)'
# Pattern value: 'PERMUTE(A, B, C)'
# Creating transition for variable 'A' with condition: 'event_type = 'start''
# Creating transition for variable 'B' with condition: 'event_type = 'middle''
# Creating transition for variable 'C' with condition: 'event_type = 'end''
# Find matches with all_rows=True, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['A', 'B']
# Testing row 2, data: {'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['A', 'B', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 3, 'is_empty': False}
# Processing match 1 with ALL ROWS PER MATCH
# Variables in exclusion pattern: set()
# Processing match 1, included indices: [0, 1, 2]
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure pattern_var for row 0 with RUNNING semantics: A
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure match_num for row 0 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluating navigation function: LAST(A.value)
# Function: LAST, Args: ['A.value']
# Evaluated measure running_a_value for row 0 with RUNNING semantics: 100
# Added row 0 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure pattern_var for row 1 with RUNNING semantics: B
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure match_num for row 1 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluating navigation function: LAST(A.value)
# Function: LAST, Args: ['A.value']
# Evaluated measure running_a_value for row 1 with RUNNING semantics: 100
# Added row 1 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure pattern_var for row 2 with RUNNING semantics: C
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure match_num for row 2 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: LAST(A.value)
# Function: LAST, Args: ['A.value']
# Evaluated measure running_a_value for row 2 with RUNNING semantics: 100
# Added row 2 to results
# Measure evaluation timings:
#   pattern_var: 0.000070 seconds
#   match_num: 0.000062 seconds
#   running_a_value: 0.000090 seconds
# Find matches completed in 0.000520 seconds
# Find matches with all_rows=True, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 0 to variable B
# Reached accepting state 2 at row 0
#   Current longest match: 0-0, vars: ['B']
# Testing row 1, data: {'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 1 to variable A
# Reached accepting state 1 at row 1
#   Current longest match: 0-1, vars: ['B', 'A']
# Testing row 2, data: {'id': 6, 'seq': 2, 'step': 3, 'event_type': 'end', 'value': 350}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['B', 'A', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 3, 'is_empty': False}
# Processing match 1 with ALL ROWS PER MATCH
# Variables in exclusion pattern: set()
# Processing match 1, included indices: [0, 1, 2]
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure pattern_var for row 0 with RUNNING semantics: B
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure match_num for row 0 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 0
# Evaluating navigation function: LAST(A.value)
# Function: LAST, Args: ['A.value']
# Evaluated measure running_a_value for row 0 with RUNNING semantics: None
# Added row 0 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure pattern_var for row 1 with RUNNING semantics: A
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure match_num for row 1 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 1
# Evaluating navigation function: LAST(A.value)
# Function: LAST, Args: ['A.value']
# Evaluated measure running_a_value for row 1 with RUNNING semantics: 150
# Added row 1 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure pattern_var for row 2 with RUNNING semantics: C
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure match_num for row 2 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: LAST(A.value)
# Function: LAST, Args: ['A.value']
# Evaluated measure running_a_value for row 2 with RUNNING semantics: 150
# Added row 2 to results
# Measure evaluation timings:
#   pattern_var: 0.000064 seconds
#   match_num: 0.000054 seconds
#   running_a_value: 0.000093 seconds
# Find matches completed in 0.000483 seconds
# Find matches with all_rows=True, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 7, 'seq': 3, 'step': 1, 'event_type': 'start', 'value': 175}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 8, 'seq': 3, 'step': 2, 'event_type': 'end', 'value': 275}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 1 to variable C
# Reached accepting state 3 at row 1
#   Current longest match: 0-1, vars: ['A', 'C']
# Testing row 2, data: {'id': 9, 'seq': 3, 'step': 3, 'event_type': 'middle', 'value': 375}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 2 to variable B
# Reached accepting state 2 at row 2
#   Current longest match: 0-2, vars: ['A', 'C', 'B']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'C': [1], 'B': [2]}, 'state': 2, 'is_empty': False}
# Processing match 1 with ALL ROWS PER MATCH
# Variables in exclusion pattern: set()
# Processing match 1, included indices: [0, 1, 2]
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure pattern_var for row 0 with RUNNING semantics: A
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure match_num for row 0 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 0
# Evaluating navigation function: LAST(A.value)
# Function: LAST, Args: ['A.value']
# Evaluated measure running_a_value for row 0 with RUNNING semantics: 175
# Added row 0 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure pattern_var for row 1 with RUNNING semantics: C
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure match_num for row 1 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 1
# Evaluating navigation function: LAST(A.value)
# Function: LAST, Args: ['A.value']
# Evaluated measure running_a_value for row 1 with RUNNING semantics: 175
# Added row 1 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure pattern_var for row 2 with RUNNING semantics: B
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure match_num for row 2 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: LAST(A.value)
# Function: LAST, Args: ['A.value']
# Evaluated measure running_a_value for row 2 with RUNNING semantics: 175
# Added row 2 to results
# Measure evaluation timings:
#   pattern_var: 0.000070 seconds
#   match_num: 0.000056 seconds
#   running_a_value: 0.000116 seconds
# Find matches completed in 0.000483 seconds
# Find matches with all_rows=True, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 10, 'seq': 4, 'step': 1, 'event_type': 'end', 'value': 225}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 0 to variable C
# Reached accepting state 3 at row 0
#   Current longest match: 0-0, vars: ['C']
# Testing row 1, data: {'id': 11, 'seq': 4, 'step': 2, 'event_type': 'middle', 'value': 325}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['C', 'B']
# Testing row 2, data: {'id': 12, 'seq': 4, 'step': 3, 'event_type': 'start', 'value': 425}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 2 to variable A
# Reached accepting state 1 at row 2
#   Current longest match: 0-2, vars: ['C', 'B', 'A']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'C': [0], 'B': [1], 'A': [2]}, 'state': 1, 'is_empty': False}
# Processing match 1 with ALL ROWS PER MATCH
# Variables in exclusion pattern: set()
# Processing match 1, included indices: [0, 1, 2]
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure pattern_var for row 0 with RUNNING semantics: C
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 0
# Evaluated measure match_num for row 0 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 0
# Evaluating navigation function: LAST(A.value)
# Function: LAST, Args: ['A.value']
# Evaluated measure running_a_value for row 0 with RUNNING semantics: None
# Added row 0 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure pattern_var for row 1 with RUNNING semantics: B
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 1
# Evaluated measure match_num for row 1 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 1
# Evaluating navigation function: LAST(A.value)
# Function: LAST, Args: ['A.value']
# Evaluated measure running_a_value for row 1 with RUNNING semantics: None
# Added row 1 to results
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure pattern_var for row 2 with RUNNING semantics: A
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Evaluated measure match_num for row 2 with RUNNING semantics: 1
# Evaluating expression: LAST(A.value) with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: LAST(A.value)
# Function: LAST, Args: ['A.value']
# Evaluated measure running_a_value for row 2 with RUNNING semantics: 425
# Added row 2 to results
# Measure evaluation timings:
#   pattern_var: 0.000069 seconds
#   match_num: 0.000055 seconds
#   running_a_value: 0.000091 seconds
# Find matches completed in 0.000565 seconds
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 0
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 0
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 1
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 1
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 3
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 3
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 4
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 4
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 6
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 6
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 7
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 7
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 9
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 9
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 10
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 10
# Evaluating expression: CLASSIFIER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: MATCH_NUMBER() with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Query execution metrics: {'parsing_time': 0.009536504745483398, 'automata_build_time': 0.002085447311401367, 'matching_time': 0.005310773849487305, 'result_processing_time': 0.0012748241424560547, 'total_time': 0.018499374389648438, 'partition_count': 4, 'match_count': 4}
#     seq  step pattern_var  match_num running_a_value  id event_type  value
# 0     1     1           A          1            None   1      start    100
# 1     1     2           B          1            None   2     middle    200
# 2     1     3           C          1            None   3        end    300
# 3     2     1           B          1            None   4     middle    250
# 4     2     2           A          1            None   5      start    150
# 5     2     3           C          1            None   6        end    350
# 6     3     1           A          1            None   7      start    175
# 7     3     2           C          1            None   8        end    275
# 8     3     3           B          1            None   9     middle    375
# 9     4     1           C          1            None  10        end    225
# 10    4     2           B          1            None  11     middle    325
# 11    4     3           A          1            None  12      start    425

# %%
# Test 4: PERMUTE with Subset Variables
query_permute_subset = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        X.value AS x_value,
        Y.value AS y_value
    ONE ROW PER MATCH
    PATTERN (PERMUTE(A, B, C))
    SUBSET
        X = (A, B),
        Y = (B, C)
    DEFINE 
        A AS event_type = 'start',
        B AS event_type = 'middle',
        C AS event_type = 'end'
);
"""

print("Test 4: PERMUTE with Subset Variables - Using subset groupings")
output_df = match_recognize(query_permute_subset, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, X.value AS x_value, Y.value AS y_value ONE ROW PER MATCH PATTERN (PERMUTE(A, B, C)) SUBSET X = (A, B), Y = (B, C) DEFINE A AS event_type = 'start', B AS event_type = 'middle', C AS event_type = 'end' );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='X.value', alias='x_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='Y.value', alias='y_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['C', 'B', 'A'], 'base_variables': ['C', 'B', 'A'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B, C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C'], 'permute': True, 'nested_permute': False})
# DEBUG:src.parser.match_recognize_extractor:Extracted SUBSET: [SubsetClause(subset_text='X = (A, B)'), SubsetClause(subset_text='Y = (B, C)')]
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start'"), Define(variable='B', condition="event_type = 'middle'"), Define(variable='C', condition="event_type = 'end'")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['C', 'B', 'A'], 'base_variables': ['C', 'B', 'A'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: X.value
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: Y.value
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# Test 4: PERMUTE with Subset Variables - Using subset groupings
# Pattern value: 'PERMUTE(A, B, C)'
# Extracted subset definition: X = (A, B)
# Extracted subset definition: Y = (B, C)
# Pattern value: 'PERMUTE(A, B, C)'
# Creating transition for variable 'A' with condition: 'event_type = 'start''
# Creating transition for variable 'B' with condition: 'event_type = 'middle''
# Creating transition for variable 'C' with condition: 'event_type = 'end''
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['A', 'B']
# Testing row 2, data: {'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['A', 'B', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 3, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 3, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to C from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting x_value to 200 from evaluator
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting y_value to 300 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'A': [0], 'B': [1], 'C': [2]}
#
# Result row:
# pattern_var: C
# match_num: 1
# x_value: 200
# y_value: 300
# Find matches completed in 0.000376 seconds
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 0 to variable B
# Reached accepting state 2 at row 0
#   Current longest match: 0-0, vars: ['B']
# Testing row 1, data: {'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 1 to variable A
# Reached accepting state 1 at row 1
#   Current longest match: 0-1, vars: ['B', 'A']
# Testing row 2, data: {'id': 6, 'seq': 2, 'step': 3, 'event_type': 'end', 'value': 350}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['B', 'A', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 3, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 3, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to C from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting x_value to 150 from evaluator
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting y_value to 350 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'B': [0], 'A': [1], 'C': [2]}
#
# Result row:
# pattern_var: C
# match_num: 1
# x_value: 150
# y_value: 350
# Find matches completed in 0.000441 seconds
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 7, 'seq': 3, 'step': 1, 'event_type': 'start', 'value': 175}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 8, 'seq': 3, 'step': 2, 'event_type': 'end', 'value': 275}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 1 to variable C
# Reached accepting state 3 at row 1
#   Current longest match: 0-1, vars: ['A', 'C']
# Testing row 2, data: {'id': 9, 'seq': 3, 'step': 3, 'event_type': 'middle', 'value': 375}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 2 to variable B
# Reached accepting state 2 at row 2
#   Current longest match: 0-2, vars: ['A', 'C', 'B']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'C': [1], 'B': [2]}, 'state': 2, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'C': [1], 'B': [2]}, 'state': 2, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to B from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting x_value to 375 from evaluator
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting y_value to 375 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'A': [0], 'C': [1], 'B': [2]}
#
# Result row:
# pattern_var: B
# match_num: 1
# x_value: 375
# y_value: 375
# Find matches completed in 0.000325 seconds
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 10, 'seq': 4, 'step': 1, 'event_type': 'end', 'value': 225}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 0 to variable C
# Reached accepting state 3 at row 0
#   Current longest match: 0-0, vars: ['C']
# Testing row 1, data: {'id': 11, 'seq': 4, 'step': 2, 'event_type': 'middle', 'value': 325}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['C', 'B']
# Testing row 2, data: {'id': 12, 'seq': 4, 'step': 3, 'event_type': 'start', 'value': 425}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 2 to variable A
# Reached accepting state 1 at row 2
#   Current longest match: 0-2, vars: ['C', 'B', 'A']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'C': [0], 'B': [1], 'A': [2]}, 'state': 1, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'C': [0], 'B': [1], 'A': [2]}, 'state': 1, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to A from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting x_value to 425 from evaluator
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting y_value to 325 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'C': [0], 'B': [1], 'A': [2]}
#
# Result row:
# pattern_var: A
# match_num: 1
# x_value: 425
# y_value: 325
# Find matches completed in 0.000437 seconds
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: X.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: Y.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Query execution metrics: {'parsing_time': 0.014382123947143555, 'automata_build_time': 0.00042939186096191406, 'matching_time': 0.0042498111724853516, 'result_processing_time': 0.0019125938415527344, 'total_time': 0.02123236656188965, 'partition_count': 4, 'match_count': 4}
#    seq pattern_var  match_num  x_value  y_value
# 0    1           C          1      200      300
# 1    2           C          1      150      350
# 2    3           B          1      375      375
# 3    4           A          1      425      325

# %%
# Test 5: Nested PERMUTE patterns
query_nested_permute = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        A.value AS a_value,
        B.value AS b_value,
        C.value AS c_value
    ONE ROW PER MATCH
    PATTERN (PERMUTE(A, PERMUTE(B, C)))
    DEFINE 
        A AS event_type = 'start',
        B AS event_type = 'middle',
        C AS event_type = 'end'
);
"""

print("Test 5: Nested PERMUTE - Testing nested permutation patterns")
output_df = match_recognize(query_nested_permute, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, A.value AS a_value, B.value AS b_value, C.value AS c_value ONE ROW PER MATCH PATTERN (PERMUTE(A, PERMUTE(B, C))) DEFINE A AS event_type = 'start', B AS event_type = 'middle', C AS event_type = 'end' );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='A.value', alias='a_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='B.value', alias='b_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='C.value', alias='c_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['C', 'B', 'A'], 'base_variables': ['C', 'B', 'A'], 'permute': True, 'nested_permute': True}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, PERMUTE(B, C))
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, PERMUTE(B, C))', metadata={'variables': ['A', 'PERMUTE(B', 'C'], 'base_variables': ['A', 'PERMUTE(B', 'C'], 'permute': True, 'nested_permute': True})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start'"), Define(variable='B', condition="event_type = 'middle'"), Define(variable='C', condition="event_type = 'end'")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['C', 'B', 'A'], 'base_variables': ['C', 'B', 'A'], 'permute': True, 'nested_permute': True}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, PERMUTE(B, C))
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.value
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: B.value
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: C.value
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# Test 5: Nested PERMUTE - Testing nested permutation patterns
# Pattern value: 'PERMUTE(A, PERMUTE(B, C))'
# Pattern value: 'PERMUTE(A, PERMUTE(B, C))'
# Creating transition for variable 'A' with condition: 'event_type = 'start''
# Creating transition for variable 'B' with condition: 'event_type = 'middle''
# Creating transition for variable 'C' with condition: 'event_type = 'end''
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['A', 'B']
# Testing row 2, data: {'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['A', 'B', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 3, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 3, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to C from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting a_value to 100 from evaluator
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting b_value to 200 from evaluator
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting c_value to 300 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'A': [0], 'B': [1], 'C': [2]}
#
# Result row:
# pattern_var: C
# match_num: 1
# a_value: 100
# b_value: 200
# c_value: 300
# Find matches completed in 0.000576 seconds
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 0 to variable B
# Reached accepting state 2 at row 0
#   Current longest match: 0-0, vars: ['B']
# Testing row 1, data: {'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 1 to variable A
# Reached accepting state 1 at row 1
#   Current longest match: 0-1, vars: ['B', 'A']
# Testing row 2, data: {'id': 6, 'seq': 2, 'step': 3, 'event_type': 'end', 'value': 350}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['B', 'A', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 3, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 3, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to C from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting a_value to 150 from evaluator
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting b_value to 250 from evaluator
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting c_value to 350 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'B': [0], 'A': [1], 'C': [2]}
#
# Result row:
# pattern_var: C
# match_num: 1
# a_value: 150
# b_value: 250
# c_value: 350
# Find matches completed in 0.000587 seconds
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 7, 'seq': 3, 'step': 1, 'event_type': 'start', 'value': 175}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 8, 'seq': 3, 'step': 2, 'event_type': 'end', 'value': 275}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 1 to variable C
# Reached accepting state 3 at row 1
#   Current longest match: 0-1, vars: ['A', 'C']
# Testing row 2, data: {'id': 9, 'seq': 3, 'step': 3, 'event_type': 'middle', 'value': 375}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 2 to variable B
# Reached accepting state 2 at row 2
#   Current longest match: 0-2, vars: ['A', 'C', 'B']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'C': [1], 'B': [2]}, 'state': 2, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'C': [1], 'B': [2]}, 'state': 2, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to B from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting a_value to 175 from evaluator
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting b_value to 375 from evaluator
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting c_value to 275 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'A': [0], 'C': [1], 'B': [2]}
#
# Result row:
# pattern_var: B
# match_num: 1
# a_value: 175
# b_value: 375
# c_value: 275
# Find matches completed in 0.000565 seconds
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 10, 'seq': 4, 'step': 1, 'event_type': 'end', 'value': 225}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 0 to variable C
# Reached accepting state 3 at row 0
#   Current longest match: 0-0, vars: ['C']
# Testing row 1, data: {'id': 11, 'seq': 4, 'step': 2, 'event_type': 'middle', 'value': 325}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['C', 'B']
# Testing row 2, data: {'id': 12, 'seq': 4, 'step': 3, 'event_type': 'start', 'value': 425}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 2 to variable A
# Reached accepting state 1 at row 2
#   Current longest match: 0-2, vars: ['C', 'B', 'A']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'C': [0], 'B': [1], 'A': [2]}, 'state': 1, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'C': [0], 'B': [1], 'A': [2]}, 'state': 1, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to A from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting a_value to 425 from evaluator
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting b_value to 325 from evaluator
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting c_value to 225 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'C': [0], 'B': [1], 'A': [2]}
#
# Result row:
# pattern_var: A
# match_num: 1
# a_value: 425
# b_value: 325
# c_value: 225
# Find matches completed in 0.000639 seconds
# Rejecting match with sequence ['B', 'A', 'C']: inner variables ['B', 'C'] are not adjacent
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Query execution metrics: {'parsing_time': 0.013253211975097656, 'automata_build_time': 0.0004673004150390625, 'matching_time': 0.005599260330200195, 'result_processing_time': 0.0028333663940429688, 'total_time': 0.022535085678100586, 'partition_count': 4, 'match_count': 3}
#    seq pattern_var  match_num  a_value  b_value  c_value
# 0    1           C          1      100      200      300
# 1    3           B          1      175      375      275
# 2    4           A          1      425      325      225

# %%
# Test 6: PERMUTE with Complex Conditions
query_permute_complex = """
SELECT * FROM memory.default.op2 MATCH_RECOGNIZE(
    PARTITION BY seq
    ORDER BY step
    MEASURES 
        CLASSIFIER() AS pattern_var,
        MATCH_NUMBER() AS match_num,
        A.value AS start_value,
        B.value AS middle_value,
        C.value AS end_value
    ONE ROW PER MATCH
    PATTERN (PERMUTE(A, B, C))
    DEFINE 
        A AS event_type = 'start' AND A.value < NEXT(A.value),
        B AS event_type = 'middle' AND B.value > PREV(B.value),
        C AS event_type = 'end' AND C.value > FIRST(A.value)
);
"""

print("Test 6: PERMUTE with Complex Conditions - Testing complex pattern definitions")
output_df = match_recognize(query_permute_complex, df)
print(output_df)
print("\n")
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM memory.default.op2 MATCH_RECOGNIZE( PARTITION BY seq ORDER BY step MEASURES CLASSIFIER() AS pattern_var, MATCH_NUMBER() AS match_num, A.value AS start_value, B.value AS middle_value, C.value AS end_value ONE ROW PER MATCH PATTERN (PERMUTE(A, B, C)) DEFINE A AS event_type = 'start' AND A.value < NEXT(A.value), B AS event_type = 'middle' AND B.value > PREV(B.value), C AS event_type = 'end' AND C.value > FIRST(A.value) );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='memory')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['seq'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='step', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='CLASSIFIER()', alias='pattern_var', metadata={'semantics': 'RUNNING'}, is_classifier=True, is_match_number=False), Measure(expression='MATCH_NUMBER()', alias='match_num', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=True), Measure(expression='A.value', alias='start_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='B.value', alias='middle_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='C.value', alias='end_value', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['C', 'B', 'A'], 'base_variables': ['C', 'B', 'A'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='PERMUTE(A, B, C)', metadata={'variables': ['A', 'B', 'C'], 'base_variables': ['A', 'B', 'C'], 'permute': True, 'nested_permute': False})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition="event_type = 'start' AND A.value < NEXT(A.value)"), Define(variable='B', condition="event_type = 'middle' AND B.value > PREV(B.value)"), Define(variable='C', condition="event_type = 'end' AND C.value > FIRST(A.value)")])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['C', 'B', 'A'], 'base_variables': ['C', 'B', 'A'], 'permute': True, 'nested_permute': False}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: PERMUTE(A, B, C)
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:PERMUTE pattern detected - skipping variable validation
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: CLASSIFIER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: MATCH_NUMBER()
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: A.value
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: B.value
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: C.value
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# Test 6: PERMUTE with Complex Conditions - Testing complex pattern definitions
# Pattern value: 'PERMUTE(A, B, C)'
# Pattern value: 'PERMUTE(A, B, C)'
# Creating transition for variable 'A' with condition: 'event_type = 'start' AND A.value < NEXT(A.value)'
# Creating transition for variable 'B' with condition: 'event_type = 'middle' AND B.value > PREV(B.value)'
# Creating transition for variable 'C' with condition: 'event_type = 'end' AND C.value > FIRST(A.value)'
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 1, 'seq': 1, 'step': 1, 'event_type': 'start', 'value': 100}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 2, 'seq': 1, 'step': 2, 'event_type': 'middle', 'value': 200}
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['A', 'B']
# Testing row 2, data: {'id': 3, 'seq': 1, 'step': 3, 'event_type': 'end', 'value': 300}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['A', 'B', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 3, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'B': [1], 'C': [2]}, 'state': 3, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to C from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting start_value to 100 from evaluator
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting middle_value to 200 from evaluator
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting end_value to 300 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'A': [0], 'B': [1], 'C': [2]}
#
# Result row:
# pattern_var: C
# match_num: 1
# start_value: 100
# middle_value: 200
# end_value: 300
# Find matches completed in 0.000407 seconds
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 4, 'seq': 2, 'step': 1, 'event_type': 'middle', 'value': 250}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 0 to variable B
# Reached accepting state 2 at row 0
#   Current longest match: 0-0, vars: ['B']
# Testing row 1, data: {'id': 5, 'seq': 2, 'step': 2, 'event_type': 'start', 'value': 150}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 1 to variable A
# Reached accepting state 1 at row 1
#   Current longest match: 0-1, vars: ['B', 'A']
# Testing row 2, data: {'id': 6, 'seq': 2, 'step': 3, 'event_type': 'end', 'value': 350}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 2 to variable C
# Reached accepting state 3 at row 2
#   Current longest match: 0-2, vars: ['B', 'A', 'C']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 3, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'B': [0], 'A': [1], 'C': [2]}, 'state': 3, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to C from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting start_value to 150 from evaluator
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting middle_value to 250 from evaluator
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'B': [0], 'A': [1], 'C': [2]}
# Number of rows: 3
# Current index: 2
# Setting end_value to 350 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'B': [0], 'A': [1], 'C': [2]}
#
# Result row:
# pattern_var: C
# match_num: 1
# start_value: 150
# middle_value: 250
# end_value: 350
# Find matches completed in 0.000395 seconds
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 7, 'seq': 3, 'step': 1, 'event_type': 'start', 'value': 175}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 8, 'seq': 3, 'step': 2, 'event_type': 'end', 'value': 275}
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 1 to variable C
# Reached accepting state 3 at row 1
#   Current longest match: 0-1, vars: ['A', 'C']
# Testing row 2, data: {'id': 9, 'seq': 3, 'step': 3, 'event_type': 'middle', 'value': 375}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 2 to variable B
# Reached accepting state 2 at row 2
#   Current longest match: 0-2, vars: ['A', 'C', 'B']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'C': [1], 'B': [2]}, 'state': 2, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'A': [0], 'C': [1], 'B': [2]}, 'state': 2, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to B from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting start_value to 175 from evaluator
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting middle_value to 375 from evaluator
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [0], 'C': [1], 'B': [2]}
# Number of rows: 3
# Current index: 2
# Setting end_value to 275 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'A': [0], 'C': [1], 'B': [2]}
#
# Result row:
# pattern_var: B
# match_num: 1
# start_value: 175
# middle_value: 375
# end_value: 275
# Find matches completed in 0.000344 seconds
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A, B, C)
# Testing row 0, data: {'id': 10, 'seq': 4, 'step': 1, 'event_type': 'end', 'value': 225}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition failed for B
#   Evaluating condition for var: C
#     Condition passed for C
#   Assigned row 0 to variable C
# Reached accepting state 3 at row 0
#   Current longest match: 0-0, vars: ['C']
# Testing row 1, data: {'id': 11, 'seq': 4, 'step': 2, 'event_type': 'middle', 'value': 325}
#   Evaluating condition for var: A
#     Condition failed for A
#   Evaluating condition for var: B
#     Condition passed for B
#   Assigned row 1 to variable B
# Reached accepting state 2 at row 1
#   Current longest match: 0-1, vars: ['C', 'B']
# Testing row 2, data: {'id': 12, 'seq': 4, 'step': 3, 'event_type': 'start', 'value': 425}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 2 to variable A
# Reached accepting state 1 at row 2
#   Current longest match: 0-2, vars: ['C', 'B', 'A']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'C': [0], 'B': [1], 'A': [2]}, 'state': 1, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'C': [0], 'B': [1], 'A': [2]}, 'state': 1, 'is_empty': False, 'match_number': 1}
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting pattern_var to A from evaluator
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting match_num to 1 from evaluator
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting start_value to 425 from evaluator
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting middle_value to 325 from evaluator
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'C': [0], 'B': [1], 'A': [2]}
# Number of rows: 3
# Current index: 2
# Setting end_value to 225 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'C': [0], 'B': [1], 'A': [2]}
#
# Result row:
# pattern_var: A
# match_num: 1
# start_value: 425
# middle_value: 325
# end_value: 225
# Find matches completed in 0.000508 seconds
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [0], 'B': [1], 'C': [2]}
# Number of rows: 12
# Current index: 2
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'B': [3], 'A': [4], 'C': [5]}
# Number of rows: 12
# Current index: 5
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'A': [6], 'C': [7], 'B': [8]}
# Number of rows: 12
# Current index: 8
# Evaluating expression: CLASSIFIER() with FINAL semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: MATCH_NUMBER() with FINAL semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: A.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: B.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Evaluating expression: C.value with RUNNING semantics
# Context variables: {'C': [9], 'B': [10], 'A': [11]}
# Number of rows: 12
# Current index: 11
# Query execution metrics: {'parsing_time': 0.012449264526367188, 'automata_build_time': 0.0002665519714355469, 'matching_time': 0.003947019577026367, 'result_processing_time': 0.001659393310546875, 'total_time': 0.018553495407104492, 'partition_count': 4, 'match_count': 4}
#    seq pattern_var  match_num  start_value  middle_value  end_value
# 0    1           C          1          100           200        300
# 1    2           C          1          150           250        350
# 2    3           B          1          175           375        275
# 3    4           A          1          425           325        225
