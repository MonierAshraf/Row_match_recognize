# %%
import pandas as pd
from src.executor.match_recognize import match_recognize
# Example with your original query
data = [
    {"id": 1, "name": "Alice", "department": "Sales", "region": "West", 
     "hire_date": "2021-01-01", "salary": 1200},
    {"id": 2, "name": "Bob", "department": "Sales", "region": "West", 
     "hire_date": "2021-01-02", "salary": 1300},
    {"id": 3, "name": "Charlie", "department": "Sales", "region": "West", 
     "hire_date": "2021-01-03", "salary": 900},
    {"id": 4, "name": "Diana", "department": "Sales", "region": "West", 
     "hire_date": "2021-01-04", "salary": 1100},
    # Add more departments/regions
    {"id": 5, "name": "Eve", "department": "Sales", "region": "East", 
     "hire_date": "2021-01-01", "salary": 1250},
    {"id": 6, "name": "Frank", "department": "Marketing", "region": "West", 
     "hire_date": "2021-01-01", "salary": 1150},
]
df = pd.DataFrame(data)

query = """
SELECT id, name 
FROM employees 
MATCH_RECOGNIZE (
    PARTITION BY department, region
    ORDER BY hire_date
    MEASURES salary AS avg_salary
    PATTERN (A)
    DEFINE A AS salary > 1000
);
"""

result = match_recognize(query, df)
print("Match Recognize Output:")
print(result)
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT id, name FROM employees MATCH_RECOGNIZE ( PARTITION BY department, region ORDER BY hire_date MEASURES salary AS avg_salary PATTERN (A) DEFINE A AS salary > 1000 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=id, metadata={}), SelectItem(expression=name, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='employees')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['department', 'region'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='hire_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='salary', alias='avg_salary', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A', metadata={'variables': ['A'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='salary > 1000')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'salary': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: set()
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: salary
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# Pattern value: 'A'
# Pattern value: 'A'
# Using rows_per_match mode: RowsPerMatch.ONE_ROW
# Measure semantics: {'avg_salary': 'RUNNING'}
# Match config: rows_per_match=RowsPerMatch.ONE_ROW, all_rows=False
# Creating transition for variable 'A' with condition: 'salary > 1000'
# DFA state 0 has transitions for variables: ['A']
#   Added transition from state 0 to 1 for variable A
# DFA state 1 has transitions for variables: []
# Built DFA with 2 states
#   State 0: Non-accept, Variables: A, Excluded: None, Transitions: A → 1
#   State 1: Accept, Variables: None, Excluded: None, Transitions:
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# Testing row 0, data: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# No valid transition from accepting state 1 at row 1
# Found non-empty match: {'start': 0, 'end': 0, 'variables': {'A': [0]}, 'state': 1, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 0, 'variables': {'A': [0]}, 'state': 1, 'is_empty': False, 'match_number': 1}
# Evaluating expression: salary with RUNNING semantics
# Context variables: {'A': [0]}
# Number of rows: 4
# Current index: 0
# Setting avg_salary to 1200 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 0
# Variables: {'A': [0]}
#
# Result row:
# department: Sales
# region: West
# avg_salary: 1200
# Starting match at index 1, state: State 0 (Non-accept, Vars: A)
# Testing row 1, data: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 1 to variable A
# Reached accepting state 1 at row 1
#   Current longest match: 1-1, vars: ['A']
# Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
# No valid transition from accepting state 1 at row 2
# Found non-empty match: {'start': 1, 'end': 1, 'variables': {'A': [1]}, 'state': 1, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 1, 'end': 1, 'variables': {'A': [1]}, 'state': 1, 'is_empty': False, 'match_number': 2}
# Evaluating expression: salary with RUNNING semantics
# Context variables: {'A': [1]}
# Number of rows: 4
# Current index: 1
# Setting avg_salary to 1300 from evaluator
#
# Match information:
# Match number: 2
# Match start: 1, end: 1
# Variables: {'A': [1]}
#
# Result row:
# department: Sales
# region: West
# avg_salary: 1300
# Starting match at index 2, state: State 0 (Non-accept, Vars: A)
# Testing row 2, data: {'id': 3, 'name': 'Charlie', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-03', 'salary': 900}
#   Evaluating condition for var: A
#     Condition failed for A
# No valid transition from state 0 at row 2
# No match found starting at index 2
# Starting match at index 3, state: State 0 (Non-accept, Vars: A)
# Testing row 3, data: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 3 to variable A
# Reached accepting state 1 at row 3
#   Current longest match: 3-3, vars: ['A']
# Found non-empty match: {'start': 3, 'end': 3, 'variables': {'A': [3]}, 'state': 1, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 3, 'end': 3, 'variables': {'A': [3]}, 'state': 1, 'is_empty': False, 'match_number': 3}
# Evaluating expression: salary with RUNNING semantics
# Context variables: {'A': [3]}
# Number of rows: 4
# Current index: 3
# Setting avg_salary to 1100 from evaluator
#
# Match information:
# Match number: 3
# Match start: 3, end: 3
# Variables: {'A': [3]}
#
# Result row:
# department: Sales
# region: West
# avg_salary: 1100
# Find matches completed in 0.001428 seconds
# Creating transition for variable 'A' with condition: 'salary > 1000'
# DFA state 0 has transitions for variables: ['A']
#   Added transition from state 0 to 1 for variable A
# DFA state 1 has transitions for variables: []
# Built DFA with 2 states
#   State 0: Non-accept, Variables: A, Excluded: None, Transitions: A → 1
#   State 1: Accept, Variables: None, Excluded: None, Transitions:
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# Testing row 0, data: {'id': 5, 'name': 'Eve', 'department': 'Sales', 'region': 'East', 'hire_date': '2021-01-01', 'salary': 1250}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Found non-empty match: {'start': 0, 'end': 0, 'variables': {'A': [0]}, 'state': 1, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 0, 'variables': {'A': [0]}, 'state': 1, 'is_empty': False, 'match_number': 1}
# Evaluating expression: salary with RUNNING semantics
# Context variables: {'A': [0]}
# Number of rows: 1
# Current index: 0
# Setting avg_salary to 1250 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 0
# Variables: {'A': [0]}
#
# Result row:
# department: Sales
# region: East
# avg_salary: 1250
# Find matches completed in 0.000230 seconds
# Creating transition for variable 'A' with condition: 'salary > 1000'
# DFA state 0 has transitions for variables: ['A']
#   Added transition from state 0 to 1 for variable A
# DFA state 1 has transitions for variables: []
# Built DFA with 2 states
#   State 0: Non-accept, Variables: A, Excluded: None, Transitions: A → 1
#   State 1: Accept, Variables: None, Excluded: None, Transitions:
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# Testing row 0, data: {'id': 6, 'name': 'Frank', 'department': 'Marketing', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1150}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Found non-empty match: {'start': 0, 'end': 0, 'variables': {'A': [0]}, 'state': 1, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 0, 'variables': {'A': [0]}, 'state': 1, 'is_empty': False, 'match_number': 1}
# Evaluating expression: salary with RUNNING semantics
# Context variables: {'A': [0]}
# Number of rows: 1
# Current index: 0
# Setting avg_salary to 1150 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 0
# Variables: {'A': [0]}
#
# Result row:
# department: Marketing
# region: West
# avg_salary: 1150
# Find matches completed in 0.000251 seconds
#
# Match data:
# Match number: 1 (Partition: department=Sales, region=West)
# Global indices - Start: 0, End: 0
# Local indices within partition - Start: 0, End: 0
# Variables: {'A': [0]}
#   Variable A assigned to rows (global indices): [0]
#     Row 0: {'id': 1, 'name': 'Alice', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1200}
# Match number: 2 (Partition: department=Sales, region=West)
# Global indices - Start: 1, End: 1
# Local indices within partition - Start: 1, End: 1
# Variables: {'A': [1]}
#   Variable A assigned to rows (global indices): [1]
#     Row 1: {'id': 2, 'name': 'Bob', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-02', 'salary': 1300}
# Match number: 3 (Partition: department=Sales, region=West)
# Global indices - Start: 3, End: 3
# Local indices within partition - Start: 3, End: 3
# Variables: {'A': [3]}
#   Variable A assigned to rows (global indices): [3]
#     Row 3: {'id': 4, 'name': 'Diana', 'department': 'Sales', 'region': 'West', 'hire_date': '2021-01-04', 'salary': 1100}
# Match number: 1 (Partition: department=Sales, region=East)
# Global indices - Start: 4, End: 4
# Local indices within partition - Start: 4, End: 4
# Variables: {'A': [4]}
#   Variable A assigned to rows (global indices): [4]
#     Row 4: {'id': 5, 'name': 'Eve', 'department': 'Sales', 'region': 'East', 'hire_date': '2021-01-01', 'salary': 1250}
# Match number: 1 (Partition: department=Marketing, region=West)
# Global indices - Start: 5, End: 5
# Local indices within partition - Start: 4, End: 4
# Variables: {'A': [5]}
#   Variable A assigned to rows (global indices): [5]
#     Row 5: {'id': 6, 'name': 'Frank', 'department': 'Marketing', 'region': 'West', 'hire_date': '2021-01-01', 'salary': 1150}
# Evaluating expression: salary with RUNNING semantics
# Context variables: {'A': [0]}
# Number of rows: 6
# Current index: 0
# Setting avg_salary to 1200 from evaluator
# Evaluating expression: salary with RUNNING semantics
# Context variables: {'A': [1]}
# Number of rows: 6
# Current index: 1
# Setting avg_salary to 1300 from evaluator
# Evaluating expression: salary with RUNNING semantics
# Context variables: {'A': [3]}
# Number of rows: 6
# Current index: 3
# Setting avg_salary to 1100 from evaluator
# Evaluating expression: salary with RUNNING semantics
# Context variables: {'A': [4]}
# Number of rows: 6
# Current index: 4
# Setting avg_salary to 1250 from evaluator
# Evaluating expression: salary with RUNNING semantics
# Context variables: {'A': [5]}
# Number of rows: 6
# Current index: 5
# Setting avg_salary to 1150 from evaluator
# No sort columns identified, skipping sort operation
# Match Recognize Output:
#   department region  avg_salary
# 0      Sales   West        1200
# 1      Sales   West        1300
# 2      Sales   West        1100
# 3      Sales   East        1250
# 4  Marketing   West        1150

# %%
import pandas as pd
from src.executor.match_recognize import match_recognize
data = {
    'order_id': [1, 2, 3, 4, 5, 6],
    'customer_name': ['John', 'John', 'Mary', 'John', 'Mary', 'Mary'],
    'order_date': pd.to_datetime(['01-JAN-2023', '02-JAN-2023', '02-JAN-2023',
                                   '03-JAN-2023', '04-JAN-2023', '05-JAN-2023']),
    'order_amount': [100, 200, 150, 120, 180, 80]
}

df = pd.DataFrame(data)


query = """
SELECT *
FROM   orders
MATCH_RECOGNIZE (
  PARTITION BY customer_name
  ORDER BY order_date
  MEASURES
    FIRST(A.order_date) AS start_date,
    LAST(A.order_date) AS end_date,
    SUM(order_amount) AS total_amount,
    COUNT(*) AS order_count
  PATTERN (A+)
  DEFINE A AS A.order_amount > 0
);
"""

result = match_recognize(query, df)
print("Match Recognize Output:")
print(result)
# Out:
# /tmp/ipykernel_246745/3919794139.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   'order_date': pd.to_datetime(['01-JAN-2023', '02-JAN-2023', '02-JAN-2023',
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE ( PARTITION BY customer_name ORDER BY order_date MEASURES FIRST(A.order_date) AS start_date, LAST(A.order_date) AS end_date, SUM(order_amount) AS total_amount, COUNT(*) AS order_count PATTERN (A+) DEFINE A AS A.order_amount > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['customer_name'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='order_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='FIRST(A.order_date)', alias='start_date', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.order_date)', alias='end_date', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='SUM(order_amount)', alias='total_amount', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='COUNT(*)', alias='order_count', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A+', metadata={'variables': ['A+'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='A.order_amount > 0')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'FIRST(A.order_date)': ['A', 'A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(A.order_date)': ['A', 'A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'SUM(order_amount)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'COUNT(*)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: FIRST(A.order_date)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.order_date)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: SUM(order_amount)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: COUNT(*)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# Pattern value: 'A+'
# Pattern value: 'A+'
# Using rows_per_match mode: RowsPerMatch.ONE_ROW
# Measure semantics: {'start_date': 'RUNNING', 'end_date': 'RUNNING', 'total_amount': 'RUNNING', 'order_count': 'RUNNING'}
# Match config: rows_per_match=RowsPerMatch.ONE_ROW, all_rows=False
# Creating transition for variable 'A' with condition: 'A.order_amount > 0'
# DFA state 0 has transitions for variables: ['A']
#   Added transition from state 0 to 1 for variable A
# DFA state 1 has transitions for variables: ['A']
#   Added transition from state 1 to 1 for variable A
# Built DFA with 2 states
#   State 0: Non-accept, Variables: A, Excluded: None, Transitions: A → 1
#   State 1: Accept, Variables: A, Excluded: None, Transitions: A → 1
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# Testing row 0, data: {'order_id': 1, 'customer_name': 'John', 'order_date': Timestamp('2023-01-01 00:00:00'), 'order_amount': 100}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'order_id': 2, 'customer_name': 'John', 'order_date': Timestamp('2023-01-02 00:00:00'), 'order_amount': 200}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 1 to variable A
# Reached accepting state 1 at row 1
#   Current longest match: 0-1, vars: ['A']
# Testing row 2, data: {'order_id': 4, 'customer_name': 'John', 'order_date': Timestamp('2023-01-03 00:00:00'), 'order_amount': 120}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 2 to variable A
# Reached accepting state 1 at row 2
#   Current longest match: 0-2, vars: ['A']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0, 1, 2]}, 'state': 1, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'A': [0, 1, 2]}, 'state': 1, 'is_empty': False, 'match_number': 1}
# Evaluating expression: FIRST(A.order_date) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: FIRST(A.order_date)
# Function: FIRST, Args: ['A.order_date']
# Setting start_date to 2023-01-01 00:00:00 from evaluator
# Evaluating expression: LAST(A.order_date) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: LAST(A.order_date)
# Function: LAST, Args: ['A.order_date']
# Setting end_date to 2023-01-03 00:00:00 from evaluator
# Evaluating expression: SUM(order_amount) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Current index: 2
# Setting total_amount to 420 from evaluator
# Evaluating expression: COUNT(*) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Current index: 2
# Setting order_count to 3 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'A': [0, 1, 2]}
#
# Result row:
# start_date: 2023-01-01 00:00:00
# end_date: 2023-01-03 00:00:00
# total_amount: 420
# order_count: 3
# Find matches completed in 0.001148 seconds
# Creating transition for variable 'A' with condition: 'A.order_amount > 0'
# DFA state 0 has transitions for variables: ['A']
#   Added transition from state 0 to 1 for variable A
# DFA state 1 has transitions for variables: ['A']
#   Added transition from state 1 to 1 for variable A
# Built DFA with 2 states
#   State 0: Non-accept, Variables: A, Excluded: None, Transitions: A → 1
#   State 1: Accept, Variables: A, Excluded: None, Transitions: A → 1
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# Testing row 0, data: {'order_id': 3, 'customer_name': 'Mary', 'order_date': Timestamp('2023-01-02 00:00:00'), 'order_amount': 150}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'order_id': 5, 'customer_name': 'Mary', 'order_date': Timestamp('2023-01-04 00:00:00'), 'order_amount': 180}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 1 to variable A
# Reached accepting state 1 at row 1
#   Current longest match: 0-1, vars: ['A']
# Testing row 2, data: {'order_id': 6, 'customer_name': 'Mary', 'order_date': Timestamp('2023-01-05 00:00:00'), 'order_amount': 80}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 2 to variable A
# Reached accepting state 1 at row 2
#   Current longest match: 0-2, vars: ['A']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0, 1, 2]}, 'state': 1, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'A': [0, 1, 2]}, 'state': 1, 'is_empty': False, 'match_number': 1}
# Evaluating expression: FIRST(A.order_date) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: FIRST(A.order_date)
# Function: FIRST, Args: ['A.order_date']
# Setting start_date to 2023-01-02 00:00:00 from evaluator
# Evaluating expression: LAST(A.order_date) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: LAST(A.order_date)
# Function: LAST, Args: ['A.order_date']
# Setting end_date to 2023-01-05 00:00:00 from evaluator
# Evaluating expression: SUM(order_amount) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Current index: 2
# Setting total_amount to 410 from evaluator
# Evaluating expression: COUNT(*) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Current index: 2
# Setting order_count to 3 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'A': [0, 1, 2]}
#
# Result row:
# start_date: 2023-01-02 00:00:00
# end_date: 2023-01-05 00:00:00
# total_amount: 410
# order_count: 3
# Find matches completed in 0.000360 seconds
#
# Match data:
# Match number: 1 (Partition: customer_name=John)
# Global indices - Start: 0, End: 2
# Local indices within partition - Start: 0, End: 2
# Variables: {'A': [0, 1, 2]}
#   Variable A assigned to rows (global indices): [0, 1, 2]
#     Row 0: {'order_id': 1, 'customer_name': 'John', 'order_date': Timestamp('2023-01-01 00:00:00'), 'order_amount': 100}
#     Row 1: {'order_id': 2, 'customer_name': 'John', 'order_date': Timestamp('2023-01-02 00:00:00'), 'order_amount': 200}
#     Row 2: {'order_id': 4, 'customer_name': 'John', 'order_date': Timestamp('2023-01-03 00:00:00'), 'order_amount': 120}
# Match number: 1 (Partition: customer_name=Mary)
# Global indices - Start: 3, End: 5
# Local indices within partition - Start: 2, End: 4
# Variables: {'A': [3, 4, 5]}
#   Variable A assigned to rows (global indices): [3, 4, 5]
#     Row 3: {'order_id': 3, 'customer_name': 'Mary', 'order_date': Timestamp('2023-01-02 00:00:00'), 'order_amount': 150}
#     Row 4: {'order_id': 5, 'customer_name': 'Mary', 'order_date': Timestamp('2023-01-04 00:00:00'), 'order_amount': 180}
#     Row 5: {'order_id': 6, 'customer_name': 'Mary', 'order_date': Timestamp('2023-01-05 00:00:00'), 'order_amount': 80}
# Evaluating expression: FIRST(A.order_date) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 6
# Current index: 2
# Evaluating navigation function: FIRST(A.order_date)
# Function: FIRST, Args: ['A.order_date']
# Setting start_date to 2023-01-01 00:00:00 from evaluator
# Evaluating expression: LAST(A.order_date) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 6
# Current index: 2
# Evaluating navigation function: LAST(A.order_date)
# Function: LAST, Args: ['A.order_date']
# Setting end_date to 2023-01-03 00:00:00 from evaluator
# Evaluating expression: SUM(order_amount) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 6
# Current index: 2
# Setting total_amount to 420 from evaluator
# Evaluating expression: COUNT(*) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 6
# Current index: 2
# Setting order_count to 3 from evaluator
# Evaluating expression: FIRST(A.order_date) with RUNNING semantics
# Context variables: {'A': [3, 4, 5]}
# Number of rows: 6
# Current index: 5
# Evaluating navigation function: FIRST(A.order_date)
# Function: FIRST, Args: ['A.order_date']
# Setting start_date to 2023-01-02 00:00:00 from evaluator
# Evaluating expression: LAST(A.order_date) with RUNNING semantics
# Context variables: {'A': [3, 4, 5]}
# Number of rows: 6
# Current index: 5
# Evaluating navigation function: LAST(A.order_date)
# Function: LAST, Args: ['A.order_date']
# Setting end_date to 2023-01-05 00:00:00 from evaluator
# Evaluating expression: SUM(order_amount) with RUNNING semantics
# Context variables: {'A': [3, 4, 5]}
# Number of rows: 6
# Current index: 5
# Setting total_amount to 410 from evaluator
# Evaluating expression: COUNT(*) with RUNNING semantics
# Context variables: {'A': [3, 4, 5]}
# Number of rows: 6
# Current index: 5
# Setting order_count to 3 from evaluator
# No sort columns identified, skipping sort operation
# Match Recognize Output:
#   customer_name start_date   end_date  total_amount  order_count
# 0          John 2023-01-01 2023-01-03           420            3
# 1          Mary 2023-01-02 2023-01-05           410            3

# %%
import pandas as pd
from src.executor.match_recognize import match_recognize
data = {
    'order_id': [1, 2, 3, 4, 5, 6],
    'customer': ['John', 'John', 'Mary', 'John', 'Mary', 'Mary'],
    'order_date': pd.to_datetime(['01-JAN-2023', '02-JAN-2023', '02-JAN-2023',
                                   '03-JAN-2023', '04-JAN-2023', '05-JAN-2023']),
    'amount': [100, 200, 150, 120, 180, 80]
}

df = pd.DataFrame(data)

# Corrected query with proper column names and pattern variable prefixes
query = """
SELECT *
FROM   orders
MATCH_RECOGNIZE (
  PARTITION BY customer
  ORDER BY order_date
  MEASURES
    FIRST(A.order_date) AS start_date,
    LAST(A.order_date) AS end_date,
    SUM(A.amount) AS total_amount,
    COUNT(*) AS order_count
  PATTERN (A+)
  DEFINE A AS amount > 0
);
"""

result = match_recognize(query, df)
print("Match Recognize Output:")
print(result)
# Out:
# /tmp/ipykernel_231844/4122375284.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   'order_date': pd.to_datetime(['01-JAN-2023', '02-JAN-2023', '02-JAN-2023',
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE ( PARTITION BY customer ORDER BY order_date MEASURES FIRST(A.order_date) AS start_date, LAST(A.order_date) AS end_date, SUM(A.amount) AS total_amount, COUNT(*) AS order_count PATTERN (A+) DEFINE A AS amount > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['customer'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='order_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='FIRST(A.order_date)', alias='start_date', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.order_date)', alias='end_date', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='SUM(A.amount)', alias='total_amount', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='COUNT(*)', alias='order_count', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A+', metadata={'variables': ['A+'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='amount > 0')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'FIRST(A.order_date)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(A.order_date)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'SUM(A.amount)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'COUNT(*)': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: FIRST(A.order_date)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.order_date)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: SUM(A.amount)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: COUNT(*)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# Pattern value: 'A+'
# Pattern value: 'A+'
# Using rows_per_match mode: RowsPerMatch.ONE_ROW
# Measure semantics: {'start_date': 'RUNNING', 'end_date': 'RUNNING', 'total_amount': 'RUNNING', 'order_count': 'RUNNING'}
# Match config: rows_per_match=RowsPerMatch.ONE_ROW, all_rows=False
# Creating transition for variable 'A' with condition: 'amount > 0'
# DFA state 0 has transitions for variables: ['A']
#   Added transition from state 0 to 1 for variable A
# DFA state 1 has transitions for variables: ['A']
#   Added transition from state 1 to 1 for variable A
# Built DFA with 2 states
#   State 0: Non-accept, Variables: A, Excluded: None, Transitions: A → 1
#   State 1: Accept, Variables: A, Excluded: None, Transitions: A → 1
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# Testing row 0, data: {'order_id': 1, 'customer': 'John', 'order_date': Timestamp('2023-01-01 00:00:00'), 'amount': 100}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'order_id': 2, 'customer': 'John', 'order_date': Timestamp('2023-01-02 00:00:00'), 'amount': 200}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 1 to variable A
# Reached accepting state 1 at row 1
#   Current longest match: 0-1, vars: ['A']
# Testing row 2, data: {'order_id': 4, 'customer': 'John', 'order_date': Timestamp('2023-01-03 00:00:00'), 'amount': 120}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 2 to variable A
# Reached accepting state 1 at row 2
#   Current longest match: 0-2, vars: ['A']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0, 1, 2]}, 'state': 1, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'A': [0, 1, 2]}, 'state': 1, 'is_empty': False, 'match_number': 1}
# Evaluating expression: FIRST(A.order_date) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: FIRST(A.order_date)
# Function: FIRST, Args: ['A.order_date']
# Setting start_date to 2023-01-01 00:00:00 from evaluator
# Evaluating expression: LAST(A.order_date) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: LAST(A.order_date)
# Function: LAST, Args: ['A.order_date']
# Setting end_date to 2023-01-03 00:00:00 from evaluator
# Evaluating expression: SUM(A.amount) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Current index: 2
# Evaluating aggregate function: sum(A.amount)
# Setting total_amount to None from evaluator
# Evaluating expression: COUNT(*) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Current index: 2
# Evaluating aggregate function: count(*)
# Setting order_count to 3 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'A': [0, 1, 2]}
#
# Result row:
# start_date: 2023-01-01 00:00:00
# end_date: 2023-01-03 00:00:00
# total_amount: None
# order_count: 3
# Find matches completed in 0.001580 seconds
# Creating transition for variable 'A' with condition: 'amount > 0'
# DFA state 0 has transitions for variables: ['A']
#   Added transition from state 0 to 1 for variable A
# DFA state 1 has transitions for variables: ['A']
#   Added transition from state 1 to 1 for variable A
# Built DFA with 2 states
#   State 0: Non-accept, Variables: A, Excluded: None, Transitions: A → 1
#   State 1: Accept, Variables: A, Excluded: None, Transitions: A → 1
# Find matches with all_rows=False, show_empty=True, include_unmatched=False
# Starting match at index 0, state: State 0 (Non-accept, Vars: A)
# Testing row 0, data: {'order_id': 3, 'customer': 'Mary', 'order_date': Timestamp('2023-01-02 00:00:00'), 'amount': 150}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 0 to variable A
# Reached accepting state 1 at row 0
#   Current longest match: 0-0, vars: ['A']
# Testing row 1, data: {'order_id': 5, 'customer': 'Mary', 'order_date': Timestamp('2023-01-04 00:00:00'), 'amount': 180}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 1 to variable A
# Reached accepting state 1 at row 1
#   Current longest match: 0-1, vars: ['A']
# Testing row 2, data: {'order_id': 6, 'customer': 'Mary', 'order_date': Timestamp('2023-01-05 00:00:00'), 'amount': 80}
#   Evaluating condition for var: A
#     Condition passed for A
#   Assigned row 2 to variable A
# Reached accepting state 1 at row 2
#   Current longest match: 0-2, vars: ['A']
# Found non-empty match: {'start': 0, 'end': 2, 'variables': {'A': [0, 1, 2]}, 'state': 1, 'is_empty': False}
#
# Processing match with ONE ROW PER MATCH:
# Match: {'start': 0, 'end': 2, 'variables': {'A': [0, 1, 2]}, 'state': 1, 'is_empty': False, 'match_number': 1}
# Evaluating expression: FIRST(A.order_date) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: FIRST(A.order_date)
# Function: FIRST, Args: ['A.order_date']
# Setting start_date to 2023-01-02 00:00:00 from evaluator
# Evaluating expression: LAST(A.order_date) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Current index: 2
# Evaluating navigation function: LAST(A.order_date)
# Function: LAST, Args: ['A.order_date']
# Setting end_date to 2023-01-05 00:00:00 from evaluator
# Evaluating expression: SUM(A.amount) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Current index: 2
# Evaluating aggregate function: sum(A.amount)
# Setting total_amount to None from evaluator
# Evaluating expression: COUNT(*) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Current index: 2
# Evaluating aggregate function: count(*)
# Setting order_count to 3 from evaluator
#
# Match information:
# Match number: 1
# Match start: 0, end: 2
# Variables: {'A': [0, 1, 2]}
#
# Result row:
# start_date: 2023-01-02 00:00:00
# end_date: 2023-01-05 00:00:00
# total_amount: None
# order_count: 3
# Find matches completed in 0.000419 seconds
#
# Match data:
# Match number: 1 (Partition: customer=John)
# Global indices - Start: 0, End: 2
# Local indices within partition - Start: 0, End: 2
# Variables: {'A': [0, 1, 2]}
#   Variable A assigned to rows (global indices): [0, 1, 2]
#     Row 0: {'order_id': 1, 'customer': 'John', 'order_date': Timestamp('2023-01-01 00:00:00'), 'amount': 100}
#     Row 1: {'order_id': 2, 'customer': 'John', 'order_date': Timestamp('2023-01-02 00:00:00'), 'amount': 200}
#     Row 2: {'order_id': 4, 'customer': 'John', 'order_date': Timestamp('2023-01-03 00:00:00'), 'amount': 120}
# Match number: 1 (Partition: customer=Mary)
# Global indices - Start: 3, End: 5
# Local indices within partition - Start: 2, End: 4
# Variables: {'A': [3, 4, 5]}
#   Variable A assigned to rows (global indices): [3, 4, 5]
#     Row 3: {'order_id': 3, 'customer': 'Mary', 'order_date': Timestamp('2023-01-02 00:00:00'), 'amount': 150}
#     Row 4: {'order_id': 5, 'customer': 'Mary', 'order_date': Timestamp('2023-01-04 00:00:00'), 'amount': 180}
#     Row 5: {'order_id': 6, 'customer': 'Mary', 'order_date': Timestamp('2023-01-05 00:00:00'), 'amount': 80}
# Evaluating expression: FIRST(A.order_date) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 6
# Current index: 2
# Evaluating navigation function: FIRST(A.order_date)
# Function: FIRST, Args: ['A.order_date']
# Setting start_date to 2023-01-01 00:00:00 from evaluator
# Evaluating expression: LAST(A.order_date) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 6
# Current index: 2
# Evaluating navigation function: LAST(A.order_date)
# Function: LAST, Args: ['A.order_date']
# Setting end_date to 2023-01-03 00:00:00 from evaluator
# Evaluating expression: SUM(A.amount) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 6
# Current index: 2
# Evaluating aggregate function: sum(A.amount)
# Setting total_amount to None from evaluator
# Evaluating expression: COUNT(*) with RUNNING semantics
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 6
# Current index: 2
# Evaluating aggregate function: count(*)
# Setting order_count to 3 from evaluator
# Evaluating expression: FIRST(A.order_date) with RUNNING semantics
# Context variables: {'A': [3, 4, 5]}
# Number of rows: 6
# Current index: 5
# Evaluating navigation function: FIRST(A.order_date)
# Function: FIRST, Args: ['A.order_date']
# Setting start_date to 2023-01-02 00:00:00 from evaluator
# Evaluating expression: LAST(A.order_date) with RUNNING semantics
# Context variables: {'A': [3, 4, 5]}
# Number of rows: 6
# Current index: 5
# Evaluating navigation function: LAST(A.order_date)
# Function: LAST, Args: ['A.order_date']
# Setting end_date to 2023-01-05 00:00:00 from evaluator
# Evaluating expression: SUM(A.amount) with RUNNING semantics
# Context variables: {'A': [3, 4, 5]}
# Number of rows: 6
# Current index: 5
# Evaluating aggregate function: sum(A.amount)
# Setting total_amount to None from evaluator
# Evaluating expression: COUNT(*) with RUNNING semantics
# Context variables: {'A': [3, 4, 5]}
# Number of rows: 6
# Current index: 5
# Evaluating aggregate function: count(*)
# Setting order_count to 6 from evaluator
# No sort columns identified, skipping sort operation
# Match Recognize Output:
#   customer start_date   end_date total_amount  order_count
# 0     John 2023-01-01 2023-01-03         None            3
# 1     Mary 2023-01-02 2023-01-05         None            6

# %%
import pandas as pd
import numpy as np

# Create stock price data
np.random.seed(42)
dates = pd.date_range(start='2023-01-01', periods=20, freq='D')
prices = [100]

# Generate a realistic price series with some patterns
for i in range(1, 20):
    if i == 5:  # Sharp drop
        prices.append(prices[-1] * 0.9)  # 10% drop
    elif i == 6:  # Slight recovery
        prices.append(prices[-1] * 1.03)  # 3% up
    elif i == 10:  # Peak
        prices.append(prices[-1] * 1.05)  # 5% up
    elif i == 11 or i == 12:  # Double down
        prices.append(prices[-1] * 0.97)  # 3% down
    elif i == 13 or i == 14:  # Double up
        prices.append(prices[-1] * 1.04)  # 4% up
    else:
        # Random movement
        prices.append(prices[-1] * (1 + np.random.normal(0, 0.01)))  # 1% volatility

# Calculate daily returns
returns = [0] + [(prices[i] - prices[i-1]) / prices[i-1] for i in range(1, len(prices))]

# Create the dataframe
stock_data = pd.DataFrame({
    'date': dates,
    'price': prices,
    'volume': np.random.randint(1000, 5000, size=len(prices)),
    'return': returns,
    'stock': ['AAPL'] * 10 + ['GOOG'] * 10  # Two different stocks
})

# Show the dataframe
print(stock_data)
# Out:
#          date       price  volume    return stock
# 0  2023-01-01  100.000000    1459  0.000000  AAPL
# 1  2023-01-02  100.496714    4385  0.004967  AAPL
# 2  2023-01-03  100.357763    1021 -0.001383  AAPL
# 3  2023-01-04  101.007769    3300  0.006477  AAPL
# 4  2023-01-05  102.546147    1747  0.015230  AAPL
# 5  2023-01-06   92.291533    3904 -0.100000  AAPL
# 6  2023-01-07   95.060279    4632  0.030000  AAPL
# 7  2023-01-08   94.837692    1474 -0.002342  AAPL
# 8  2023-01-09   94.615642    2082 -0.002341  AAPL
# 9  2023-01-10   96.109824    3558  0.015792  AAPL
# 10 2023-01-11  100.915315    4753  0.050000  GOOG
# 11 2023-01-12   97.887856    3047 -0.030000  GOOG
# 12 2023-01-13   94.951220    4547 -0.030000  GOOG
# 13 2023-01-14   98.749269    3747  0.040000  GOOG
# 14 2023-01-15  102.699240    1975  0.040000  GOOG
# 15 2023-01-16  103.487389    2806  0.007674  GOOG
# 16 2023-01-17  103.001542    1189 -0.004695  GOOG
# 17 2023-01-18  103.560388    4005  0.005426  GOOG
# 18 2023-01-19  103.080470    3734 -0.004634  GOOG
# 19 2023-01-20  102.600394    4005 -0.004657  GOOG

# %%
import pandas as pd
from src.executor.match_recognize import match_recognize
data = {
    'order_id': [1, 2, 3, 4, 5, 6],
    'customer': ['John', 'John', 'Mary', 'John', 'Mary', 'Mary'],
    'order_date': pd.to_datetime(['01-JAN-2023', '02-JAN-2023', '02-JAN-2023',
                                   '03-JAN-2023', '04-JAN-2023', '05-JAN-2023']),
    'amount': [100, 200, 150, 120, 180, 80]
}

df = pd.DataFrame(data)

# Modified query to test multi-row pattern matching
query = """
SELECT *
FROM   orders
MATCH_RECOGNIZE (
  PARTITION BY customer
  ORDER BY order_date
  MEASURES
    FIRST(A.order_date) AS start_date,
    LAST(A.order_date) AS end_date,
    SUM(A.amount) AS total_amount,
    COUNT(*) AS order_count
  ONE ROW PER MATCH
  PATTERN (A+)
  DEFINE A AS amount > 0
);
"""

result = match_recognize(query, df)
print("Match Recognize Output:")
print(result)
# Out:
# /tmp/ipykernel_112179/4131321436.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   'order_date': pd.to_datetime(['01-JAN-2023', '02-JAN-2023', '02-JAN-2023',
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT * FROM orders MATCH_RECOGNIZE ( PARTITION BY customer ORDER BY order_date MEASURES FIRST(A.order_date) AS start_date, LAST(A.order_date) AS end_date, SUM(A.amount) AS total_amount, COUNT(*) AS order_count ONE ROW PER MATCH PATTERN (A+) DEFINE A AS amount > 0 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=*, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='orders')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['customer'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='order_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='FIRST(A.order_date)', alias='start_date', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='LAST(A.order_date)', alias='end_date', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='SUM(A.amount)', alias='total_amount', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False), Measure(expression='COUNT(*)', alias='order_count', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONEROWPERMATCH
# DEBUG:src.parser.match_recognize_extractor:Extracted ROWS PER MATCH: ONE ROW PER MATCH
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A+', metadata={'variables': ['A+'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='amount>0')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A+'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A+
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'FIRST(A.order_date)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'LAST(A.order_date)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'SUM(A.amount)': ['A']
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'COUNT(*)': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'amount>0': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Required variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: FIRST(A.order_date)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: LAST(A.order_date)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: SUM(A.amount)
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: COUNT(*)
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# Evaluating expression: FIRST(A.order_date)
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Evaluating navigation function: FIRST(A.order_date)
# Function: FIRST, Args: ['A.order_date']
# Evaluating expression: LAST(A.order_date)
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Evaluating navigation function: LAST(A.order_date)
# Function: LAST, Args: ['A.order_date']
# Evaluating expression: SUM(A.amount)
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Evaluating aggregate function: sum(A.amount)
# Evaluating expression: COUNT(*)
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Evaluating aggregate function: count(*)
# Evaluating expression: FIRST(A.order_date)
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Evaluating navigation function: FIRST(A.order_date)
# Function: FIRST, Args: ['A.order_date']
# Evaluating expression: LAST(A.order_date)
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Evaluating navigation function: LAST(A.order_date)
# Function: LAST, Args: ['A.order_date']
# Evaluating expression: SUM(A.amount)
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Evaluating aggregate function: sum(A.amount)
# Evaluating expression: COUNT(*)
# Context variables: {'A': [0, 1, 2]}
# Number of rows: 3
# Evaluating aggregate function: count(*)
# Match Recognize Output:
#    order_id customer order_date  amount start_date   end_date  total_amount  \
# 0         1     John 2023-01-01     100 2023-01-01 2023-01-03           420
# 1         3     Mary 2023-01-02     150 2023-01-02 2023-01-05           410
#
#    order_count  MATCH_NUMBER
# 0            3             1
# 1            3             1

# %%
# test_match_recognize.py

import pandas as pd
from src.executor.match_recognize import match_recognize

def test_basic_pattern():
    """Test basic pattern matching with A+ pattern."""
    data = [
        {"id": 1, "name": "Alice", "department": "Sales", "region": "West", "hire_date": "2021-01-01", "salary": 1200},
        {"id": 2, "name": "Bob", "department": "Sales", "region": "West", "hire_date": "2021-01-02", "salary": 1300},
        {"id": 3, "name": "Charlie", "department": "Sales", "region": "West", "hire_date": "2021-01-03", "salary": 900},
        {"id": 4, "name": "Diana", "department": "Sales", "region": "West", "hire_date": "2021-01-04", "salary": 1100},
    ]
    df = pd.DataFrame(data)
    
    query = """
    SELECT id, name 
    FROM employees 
    MATCH_RECOGNIZE (
        PARTITION BY department, region
        ORDER BY hire_date
        MEASURES salary AS avg_salary
        PATTERN (A)
        DEFINE A AS salary > 1000
    );
    """
    
    result = match_recognize(query, df)
    print("Basic Pattern Test:")
    print(result)

def test_price_trend():
    """Test price trend pattern (increasing then decreasing)."""
    data = [
        {"order_id": 1, "customer_id": "C1", "price": 100, "order_date": "2023-01-01"},
        {"order_id": 2, "customer_id": "C1", "price": 150, "order_date": "2023-01-02"},
        {"order_id": 3, "customer_id": "C1", "price": 200, "order_date": "2023-01-03"},
        {"order_id": 4, "customer_id": "C1", "price": 180, "order_date": "2023-01-04"},
        {"order_id": 5, "customer_id": "C1", "price": 160, "order_date": "2023-01-05"},
        {"order_id": 6, "customer_id": "C2", "price": 120, "order_date": "2023-01-01"},
        {"order_id": 7, "customer_id": "C2", "price": 140, "order_date": "2023-01-02"},
        {"order_id": 8, "customer_id": "C2", "price": 130, "order_date": "2023-01-03"},
    ]
    df = pd.DataFrame(data)
    
    query = """
    SELECT *
    FROM orders
    MATCH_RECOGNIZE (
        PARTITION BY customer_id
        ORDER BY order_date
        MEASURES 
            FIRST(A.price) AS start_price,
            LAST(A.price) AS peak_price,
            LAST(B.price) AS end_price
        ONE ROW PER MATCH
        AFTER MATCH SKIP TO NEXT ROW
        PATTERN (A+ B+)
        DEFINE
            A AS PREV(price) IS NULL OR price > PREV(price),
            B AS price < PREV(price)
    );
    """
    
    result = match_recognize(query, df)
    print("\nPrice Trend Test:")
    print(result)

def test_complex_pattern():
    """Test complex pattern with alternation and quantifiers."""
    data = [
        {"event_id": 1, "sequence": "A", "value": 10, "timestamp": "2023-01-01 10:00:00"},
        {"event_id": 2, "sequence": "B", "value": 20, "timestamp": "2023-01-01 10:01:00"},
        {"event_id": 3, "sequence": "A", "value": 30, "timestamp": "2023-01-01 10:02:00"},
        {"event_id": 4, "sequence": "C", "value": 40, "timestamp": "2023-01-01 10:03:00"},
        {"event_id": 5, "sequence": "B", "value": 50, "timestamp": "2023-01-01 10:04:00"},
        {"event_id": 6, "sequence": "A", "value": 60, "timestamp": "2023-01-01 10:05:00"},
    ]
    df = pd.DataFrame(data)
    
    query = """
    SELECT *
    FROM events
    MATCH_RECOGNIZE (
        ORDER BY timestamp
        MEASURES 
            FIRST(A.value) AS first_value,
            LAST(B.value) AS last_value,
            COUNT(*) AS pattern_length
        ALL ROWS PER MATCH
        PATTERN ((A B+) | (B A+))
        SUBSET U = (A, B)
        DEFINE
            A AS sequence = 'A',
            B AS sequence = 'B'
    );
    """
    
    result = match_recognize(query, df)
    print("\nComplex Pattern Test:")
    print(result)

def test_running_measures():
    """Test running measures and aggregations."""
    data = [
        {"id": 1, "metric": 100, "timestamp": "2023-01-01"},
        {"id": 2, "metric": 110, "timestamp": "2023-01-02"},
        {"id": 3, "metric": 120, "timestamp": "2023-01-03"},
        {"id": 4, "metric": 115, "timestamp": "2023-01-04"},
        {"id": 5, "metric": 125, "timestamp": "2023-01-05"},
    ]
    df = pd.DataFrame(data)
    
    query = """
    SELECT *
    FROM metrics
    MATCH_RECOGNIZE (
        ORDER BY timestamp
        MEASURES 
            RUNNING AVG(A.metric) AS running_avg,
            FINAL AVG(A.metric) AS final_avg,
            RUNNING COUNT(*) AS running_count
        ALL ROWS PER MATCH
        PATTERN (A+)
        DEFINE
            A AS PREV(metric) IS NULL OR metric >= PREV(metric)
    );
    """
    
    result = match_recognize(query, df)
    print("\nRunning Measures Test:")
    print(result)

def test_unmatched_rows():
    """Test handling of unmatched rows."""
    data = [
        {"id": 1, "value": 100, "category": "A"},
        {"id": 2, "value": 90, "category": "B"},
        {"id": 3, "value": 80, "category": "A"},
        {"id": 4, "value": 110, "category": "B"},
        {"id": 5, "value": 120, "category": "A"},
    ]
    df = pd.DataFrame(data)
    
    query = """
    SELECT *
    FROM data
    MATCH_RECOGNIZE (
        PARTITION BY category
        ORDER BY id
        MEASURES 
            FIRST(A.value) AS start_value,
            LAST(A.value) AS end_value
        ALL ROWS PER MATCH WITH UNMATCHED ROWS
        PATTERN (A+)
        DEFINE
            A AS PREV(value) IS NULL OR value > PREV(value)
    );
    """
    
    result = match_recognize(query, df)
    print("\nUnmatched Rows Test:")
    print(result)

if __name__ == "__main__":
    # Run all tests
    test_basic_pattern()
    test_price_trend()
    test_complex_pattern()
    test_running_measures()
    test_unmatched_rows()
# Out:
# DEBUG:src.parser.match_recognize_extractor:Full statement text: SELECT id, name FROM employees MATCH_RECOGNIZE ( PARTITION BY department, region ORDER BY hire_date MEASURES salary AS avg_salary PATTERN (A) DEFINE A AS salary > 1000 );
# DEBUG:src.parser.match_recognize_extractor:Extracted SELECT clause: SelectClause(items=[SelectItem(expression=id, metadata={}), SelectItem(expression=name, metadata={})])
# DEBUG:src.parser.match_recognize_extractor:Extracted FROM clause: FromClause(table='employees')
# DEBUG:src.parser.match_recognize_extractor:Visiting PatternRecognition context
# DEBUG:src.parser.match_recognize_extractor:Extracted PARTITION BY: PartitionByClause(columns=['department', 'region'])
# DEBUG:src.parser.match_recognize_extractor:Extracted ORDER BY: OrderByClause(sort_items=[SortItem(column='hire_date', ordering='ASC', nulls_ordering=None)])
# DEBUG:src.parser.match_recognize_extractor:Extracted MEASURES: MeasuresClause(measures=[Measure(expression='salary', alias='avg_salary', metadata={'semantics': 'RUNNING'}, is_classifier=False, is_match_number=False)])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A
# DEBUG:src.parser.match_recognize_extractor:Extracted Pattern: PatternClause(pattern='A', metadata={'variables': ['A'], 'base_variables': ['A']})
# DEBUG:src.parser.match_recognize_extractor:Extracted DEFINE: DefineClause(definitions=[Define(variable='A', condition='salary>1000')])
# DEBUG:src.parser.match_recognize_extractor:Updated Pattern tokens: {'variables': ['A'], 'base_variables': ['A']}
# DEBUG:src.parser.match_recognize_extractor:PATTERN clause validated successfully: A
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from measure 'salary': []
# DEBUG:src.parser.match_recognize_extractor:Extracted variables from define condition 'salary>1000': []
# DEBUG:src.parser.match_recognize_extractor:Pattern variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Referenced variables: set()
# DEBUG:src.parser.match_recognize_extractor:Required variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Defined variables: {'A'}
# DEBUG:src.parser.match_recognize_extractor:Subset variables: {}
# DEBUG:src.parser.match_recognize_extractor:Validated function usage for measure: salary
# DEBUG:src.parser.match_recognize_extractor:Extracted MATCH_RECOGNIZE clause via recursive search.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 167
#     163     print(result)
#     165 if __name__ == "__main__":
#     166     # Run all tests
# --> 167     test_basic_pattern()
#     168     test_price_trend()
#     169     test_complex_pattern()
#
# Cell In[1], line 28, in test_basic_pattern()
#      14 df = pd.DataFrame(data)
#      16 query = """
#      17 SELECT id, name
#      18 FROM employees
#    (...)
#      25 );
#      26 """
# ---> 28 result = match_recognize(query, df)
#      29 print("Basic Pattern Test:")
#      30 print(result)
#
# File ~/Desktop/llm/Row_match_recognize/src/executor/match_recognize.py:119, in match_recognize(query, df)
#     117 # Create matcher and find matches
#     118 matcher = EnhancedMatcher(dfa)
# --> 119 partition_results = matcher.find_matches(rows, config, measures)
#     121 # Add partition columns if needed
#     122 if partition_by:
#
# File ~/Desktop/llm/Row_match_recognize/src/matcher/matcher.py:48, in EnhancedMatcher.find_matches(self, rows, config, measures)
#      45 context = RowContext()
#      46 context.match_number = match_number
# ---> 48 match = self._find_single_match(rows, i, context)
#      50 if match:
#      51     start_idx, end_idx = match["start"], match["end"]
#
# File ~/Desktop/llm/Row_match_recognize/src/matcher/matcher.py:113, in EnhancedMatcher._find_single_match(self, rows, start_idx, context)
#     110 matched_var = None
#     112 for transition in self.dfa.states[state].transitions:
# --> 113     if transition.condition(row, context):
#     114         next_state = transition.target
#     115         matched_var = transition.variable
#
# AttributeError: 'dict' object has no attribute 'condition'
